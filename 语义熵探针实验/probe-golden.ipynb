# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("Start time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# 记录开始时间
from time import time
start = time()
# Out:
# Start time: 2024-12-10 18:11:38

# %% [markdown]
# # golden数据单独训练探针

# %%
# 全局变量
# 图片保存文件夹路径
FIG_DIR = "output/data/figures/golden"
# 采样类型
SAMPLE_TYPE = "golden"
# 模型层数
NUMBER_OF_LAYERS = 28 # Qwen2.5-7B共有28层

# %%
# %load_ext autoreload
# %autoreload 2

import json
import warnings
import os
import pickle
from tqdm import tqdm
import torch
from collections import defaultdict, Counter
import argparse
from core.models.entailment import EntailmentDeberta
from core.data.data_utils import load_ds_from_json
import numpy as np
import pandas as pd
import scipy
from matplotlib import pyplot as plt
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score, mean_squared_error
from sklearn.model_selection import train_test_split

warnings.filterwarnings("ignore")
plt.rcParams.update({'font.size': 12})
rng = np.random.default_rng(42)


def load_pickle_file(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

def save_pickle_file(file_path, data):
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

# %%
# Create Dataset class for easier attribute keeping
class Dataset:
    name = ''
    tbg_dataset = None
    slt_dataset = None
    entropy = None
    accuracies = None

    sample_type = ''
    model_name = ''
    dataset_name = ''
    split = ''
    def __init__(self, name, tbg_dataset, slt_dataset, entropy, accuracies, sample_type, model_name, dataset_name, split):
        self.name = name
        self.tbg_dataset = tbg_dataset
        self.slt_dataset = slt_dataset
        self.entropy = entropy
        self.accuracies = accuracies
        self.sample_type = sample_type
        self.model_name = model_name
        self.dataset_name = dataset_name
        self.split = split

all_data = load_pickle_file("output/data/all_data.pkl")


model_name = "Qwen/Qwen2.5-7B-Instruct"
dataset_names = ["squad", "triviaqa"]
split = "train"
sample_type = SAMPLE_TYPE

Ds = []
for dataset_name in dataset_names:
    ds = all_data[model_name][dataset_name][split][sample_type]
    Ds.append(ds)

for i, D in enumerate(Ds):
    # OOD-related
    D.other_ids = [j for j in range(len(Ds)) if j != i]
    D.other_names = [Ds[j].name for j in D.other_ids]

# 打印数据集信息
for ds in Ds:
    print(f"{ds.model_name} {ds.dataset_name} {ds.split}: {len(ds.accuracies)}")
# Out:
# Qwen/Qwen2.5-7B-Instruct squad train: 2000
# Qwen/Qwen2.5-7B-Instruct triviaqa train: 2000

# %% [markdown]
# ### Helper Methods

# %%
# Create train/val/test splits
def create_Xs_and_ys(datasets, scores, val_test_splits=[0.2, 0.1], test_only=False, no_val=False):
    # Data splitting for sklearn linear models
    X = np.array(datasets)
    y = np.array(scores)

    if test_only:
        X_tests, y_tests = [], []
        
        for i in range(X.shape[0]):
            X_tests.append(X[i])
            y_tests.append(y)
        return (None, None, X_tests, None, None, y_tests)
    
    valid_size = val_test_splits[0]
    test_size = val_test_splits[1]

    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = [], [], [], [], [], []

    for i in range(X.shape[0]):
        # Split data into train, validation, and test sets
        X_train_val, X_test, y_train_val, y_test = train_test_split(X[i], y, test_size=test_size, random_state=42)
        X_tests.append(X_test)
        y_tests.append(y_test)
        if no_val:
            X_trains.append(X_train_val)
            y_trains.append(y_train_val)
            continue
        X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=valid_size, random_state=42) 
        X_trains.append(X_train)
        y_trains.append(y_train)
        X_vals.append(X_val)
        y_vals.append(y_val)

    return X_trains, X_vals, X_tests, y_trains, y_vals, y_tests

# %%
# Bootstrapping methods from ../semantic_entropy/uncertainty/utils/eval_utils.py
def bootstrap_func(y_true, y_score, func):
    y_tuple = (y_true, y_score)
    
    metric_i = func(*y_tuple)
    metric_dict = {}
    metric_dict['mean'] = metric_i
    metric_dict['bootstrap'] = compatible_bootstrap(
        func, rng)(*y_tuple)  # a bit slow to run

    return metric_dict

def bootstrap(function, rng, n_resamples=1000):
    def inner(data):
        bs = scipy.stats.bootstrap(
            (data, ), function, n_resamples=n_resamples, confidence_level=0.9,
            random_state=rng)
        return {
            'std_err': bs.standard_error,
            'low': bs.confidence_interval.low,
            'high': bs.confidence_interval.high
        }
    return inner

def auroc(y_true, y_score):
    fpr, tpr, thresholds = metrics.roc_curve(y_true, y_score)
    del thresholds
    return metrics.auc(fpr, tpr)

def compatible_bootstrap(func, rng):
    def helper(y_true_y_score):
        # this function is called in the bootstrap
        y_true = np.array([i['y_true'] for i in y_true_y_score])
        y_score = np.array([i['y_score'] for i in y_true_y_score])
        out = func(y_true, y_score)
        return out

    def wrap_inputs(y_true, y_score):
        return [{'y_true': i, 'y_score': j} for i, j in zip(y_true, y_score)]

    def converted_func(y_true, y_score):
        y_true_y_score = wrap_inputs(y_true, y_score)
        return bootstrap(helper, rng=rng)(y_true_y_score)
    return converted_func

# %%
# Train and evaluation function.
def sklearn_train_and_evaluate(model, X_train, y_train, X_valid, y_valid, silent=False):
    model.fit(X_train, y_train)
    
    # Calculate training loss and score
    train_probs = model.predict_proba(X_train)
    train_loss = log_loss(y_train, train_probs)

    # Calculate validation loss
    valid_preds = model.predict(X_valid)
    valid_probs = model.predict_proba(X_valid)
    valid_loss = log_loss(y_valid, valid_probs)
    val_accuracy = np.mean((valid_preds == y_valid).astype(int))
    auroc_score = roc_auc_score(y_valid, valid_probs[:,1])
    if not silent:
        print(f"Validation Accuracy: {val_accuracy:.4f}, AUROC: {auroc_score:.4f}")
        print(f"Training Loss: {train_loss:.4f}, Validation Loss: {valid_loss:.4f}")

def sklearn_evaluate_on_test(model, X_test, y_test, silent=False, bootstrap=True):
    test_preds = model.predict(X_test)
    test_probs = model.predict_proba(X_test)
    test_loss = log_loss(y_test, test_probs)
    test_accuracy = np.mean((test_preds == y_test).astype(int))
    
    if bootstrap:
        auroc_score = bootstrap_func(y_test, test_probs[:,1], auroc)
        auroc_score_scalar = auroc_score['mean']
    else:
        auroc_score = auroc_score_scalar = roc_auc_score(y_test, test_probs[:, 1])
    
    if not silent:
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, AUROC: {auroc_score_scalar:.4f}")
    
    return test_loss, test_accuracy, auroc_score

def train_single_metric(D, token_type='tbg', metric='b_entropy'):
    """train and test on single metric (e.g. SE, Acc) on single dataset"""
    var_name = token_type[0] + metric[0] 
    # named as [te, se. ta, sa] for easy identification; t for tbg, s for slt (token positions)
    # e for entropy and a for accuracy (or model faithfulness)
    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = create_Xs_and_ys(
        getattr(D, f'{token_type}_dataset'), getattr(D, metric)
    )

    accs = []
    aucs = []
    models = []
    
    for i, (X_train, X_val, X_test, y_train, y_val, y_test) in enumerate(zip(X_trains, X_vals, X_tests, y_trains, y_vals, y_tests)):
        print(f"Training on {D.name}-{token_type.upper()}-{metric.upper()} {i+1}/{len(X_trains)}")
        model = LogisticRegression()
        sklearn_train_and_evaluate(model, X_train, y_train, X_val, y_val)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        accs.append(test_acc)
        aucs.append(test_auc)
        models.append(model)

    setattr(D, f'{var_name}_accs', accs)
    setattr(D, f'{var_name}_aucs', aucs)
    setattr(D, f'{var_name}_models', models)

# simple get-around for unpacking bootstrapping dicts
auc = lambda aucs : [ac['mean'] for ac in aucs] 
idf = lambda x : x  # identical function

# %%
# Plotting methods
def plot_metrics_ax(ax, test_metrics_list, model_names, title="", prep_func=auc, 
                    use_logarithm=False, preset_layer_indices=None, legend_outside=False):  # some simple gadgets
    """plot metrics along certain axis in a multi-axis plot (plt.subplots)"""
    if len(test_metrics_list) != len(model_names):
        raise ValueError("The length of test_metrics_list and model_names must be the same.")
    
    for test_metrics, model_name in zip(test_metrics_list, model_names):
        test_metrics = torch.tensor(prep_func(test_metrics), dtype=torch.float32)
        if use_logarithm:
            test_metrics = torch.log(test_metrics + 1e-6)
        if preset_layer_indices is not None:
            layer_indices = preset_layer_indices
        else:
            layer_indices = torch.arange(len(test_metrics)) + 1  # +1 if layer indexing starts at 1
        
        ax.plot(layer_indices, test_metrics, marker='o', linestyle='-', linewidth=2, markersize=5, label=model_name)
    
    ax.set_title(f'{title}', fontsize=14)
    ax.set_xlabel('Layer', fontsize=12)
    ax.set_ylabel(f'Test AUROC scores', fontsize=12)
    
    tick_interval = 5  # Change this value to display more or fewer ticks
    ax.set_xticks(layer_indices[::tick_interval].tolist())
    ax.set_xticklabels(layer_indices[::tick_interval].tolist())
    
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    
    if legend_outside:
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12)
    else:
        ax.legend(fontsize=12)

def save_fig(name):
    """save figure with timestamps"""
    dir_path = os.path.expanduser(FIG_DIR)
    os.makedirs(dir_path, exist_ok=True)
    full_path = os.path.join(dir_path, f'{name}.pdf')
    plt.savefig(full_path, format='pdf', dpi=300)

# %%
# Best split for SE binarization.
def best_split(entropy: torch.Tensor, label="Dx"):
    """
    Identify best split for minimizing reconstruction error via low and high SE mean estimates,
    as discussed in Section 4. Binarization of paper (ArXiv: 2406.15927)
    """
    ents = entropy.numpy()
    splits = np.linspace(1e-10, ents.max(), 100)
    split_mses = []
    for split in splits:
        low_idxs, high_idxs = ents < split, ents >= split
    
        low_mean = np.mean(ents[low_idxs])
        high_mean = np.mean(ents[high_idxs])
    
        mse = np.sum((ents[low_idxs] - low_mean)**2) + np.sum((ents[high_idxs] - high_mean)**2)
        mse = np.sum(mse)
    
        split_mses.append(mse)
    
    split_mses = np.array(split_mses)
    
    plt.plot(splits, split_mses, label=label)
    return splits[np.argmin(split_mses)]

def binarize_entropy(entropy, thres=0.0):  # 0.0 means even splits for normalized entropy scores
    """Binarize entropy scores into 0s and 1s"""
    binary_entropy = torch.full_like(entropy, -1, dtype=torch.float)
    binary_entropy[entropy < thres] = 0
    binary_entropy[entropy > thres] = 1

    return binary_entropy

# %% [markdown]
# ### 二值化语义熵

# %%
# Best universal split across datasets
split_method = 'best-universal-split'
all_entropy = torch.cat([D.entropy for D in Ds], dim=0)
split = best_split(all_entropy, "All datasets collective")
plt.legend()
plt.title('Sum of squared errors at different splits')
for D in Ds:
    D.b_entropy = binarize_entropy(D.entropy, split)
    print(f"Dummy accuracy for {D.name}: {max(torch.mean(D.b_entropy).item(), 1-torch.mean(D.b_entropy).item()):.4f}")
# Out:
# Dummy accuracy for squad-golden: 0.9185
# Dummy accuracy for triviaqa-golden: 0.7700

# %% [markdown]
# ### Train linear probes to predict Binarized SE

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'b_entropy')
    train_single_metric(D, 'slt', 'b_entropy')
# Out:
# Training on squad-golden-TBG-B_ENTROPY 1/29
# Validation Accuracy: 0.9083, AUROC: 0.5000
# Training Loss: 0.2868, Validation Loss: 0.3068
# Test Loss: 0.2069, Test Accuracy: 0.9500, AUROC: 0.5000
# Training on squad-golden-TBG-B_ENTROPY 2/29
# Validation Accuracy: 0.9083, AUROC: 0.6006
# Training Loss: 0.2327, Validation Loss: 0.3071
# Test Loss: 0.2048, Test Accuracy: 0.9500, AUROC: 0.6279
# Training on squad-golden-TBG-B_ENTROPY 3/29
# Validation Accuracy: 0.9056, AUROC: 0.5969
# Training Loss: 0.2046, Validation Loss: 0.3138
# Test Loss: 0.2038, Test Accuracy: 0.9450, AUROC: 0.6584
# Training on squad-golden-TBG-B_ENTROPY 4/29
# Validation Accuracy: 0.9056, AUROC: 0.6145
# Training Loss: 0.1779, Validation Loss: 0.3154
# Test Loss: 0.2260, Test Accuracy: 0.9250, AUROC: 0.6305
# Training on squad-golden-TBG-B_ENTROPY 5/29
# Validation Accuracy: 0.9083, AUROC: 0.6056
# Training Loss: 0.1599, Validation Loss: 0.3238
# Test Loss: 0.2253, Test Accuracy: 0.9400, AUROC: 0.6121
# Training on squad-golden-TBG-B_ENTROPY 6/29
# Validation Accuracy: 0.9000, AUROC: 0.5968
# Training Loss: 0.1147, Validation Loss: 0.3533
# Test Loss: 0.2605, Test Accuracy: 0.9300, AUROC: 0.5068
# Training on squad-golden-TBG-B_ENTROPY 7/29
# Validation Accuracy: 0.9000, AUROC: 0.5257
# Training Loss: 0.0954, Validation Loss: 0.4012
# Test Loss: 0.3115, Test Accuracy: 0.9200, AUROC: 0.4168
# Training on squad-golden-TBG-B_ENTROPY 8/29
# Validation Accuracy: 0.8917, AUROC: 0.5278
# Training Loss: 0.0872, Validation Loss: 0.4273
# Test Loss: 0.2935, Test Accuracy: 0.9150, AUROC: 0.4700
# Training on squad-golden-TBG-B_ENTROPY 9/29
# Validation Accuracy: 0.8917, AUROC: 0.5266
# Training Loss: 0.0755, Validation Loss: 0.4410
# Test Loss: 0.2885, Test Accuracy: 0.9250, AUROC: 0.5368
# Training on squad-golden-TBG-B_ENTROPY 10/29
# Validation Accuracy: 0.8833, AUROC: 0.5536
# Training Loss: 0.0604, Validation Loss: 0.4751
# Test Loss: 0.2950, Test Accuracy: 0.9250, AUROC: 0.5458
# Training on squad-golden-TBG-B_ENTROPY 11/29
# Validation Accuracy: 0.8889, AUROC: 0.5384
# Training Loss: 0.0647, Validation Loss: 0.4668
# Test Loss: 0.2695, Test Accuracy: 0.9250, AUROC: 0.5816
# Training on squad-golden-TBG-B_ENTROPY 12/29
# Validation Accuracy: 0.8889, AUROC: 0.5249
# Training Loss: 0.0623, Validation Loss: 0.4621
# Test Loss: 0.2927, Test Accuracy: 0.9250, AUROC: 0.5126
# Training on squad-golden-TBG-B_ENTROPY 13/29
# Validation Accuracy: 0.8861, AUROC: 0.5443
# Training Loss: 0.0453, Validation Loss: 0.4758
# Test Loss: 0.3249, Test Accuracy: 0.9200, AUROC: 0.4926
# Training on squad-golden-TBG-B_ENTROPY 14/29
# Validation Accuracy: 0.8889, AUROC: 0.5419
# Training Loss: 0.0455, Validation Loss: 0.4814
# Test Loss: 0.2826, Test Accuracy: 0.9250, AUROC: 0.5700
# Training on squad-golden-TBG-B_ENTROPY 15/29
# Validation Accuracy: 0.8917, AUROC: 0.6040
# Training Loss: 0.0438, Validation Loss: 0.4715
# Test Loss: 0.2839, Test Accuracy: 0.9300, AUROC: 0.5895
# Training on squad-golden-TBG-B_ENTROPY 16/29
# Validation Accuracy: 0.8889, AUROC: 0.6237
# Training Loss: 0.0508, Validation Loss: 0.4667
# Test Loss: 0.3268, Test Accuracy: 0.9000, AUROC: 0.5237
# Training on squad-golden-TBG-B_ENTROPY 17/29
# Validation Accuracy: 0.9056, AUROC: 0.6812
# Training Loss: 0.0286, Validation Loss: 0.4187
# Test Loss: 0.2548, Test Accuracy: 0.9300, AUROC: 0.7074
# Training on squad-golden-TBG-B_ENTROPY 18/29
# Validation Accuracy: 0.9056, AUROC: 0.6682
# Training Loss: 0.0225, Validation Loss: 0.4607
# Test Loss: 0.2685, Test Accuracy: 0.9250, AUROC: 0.7095
# Training on squad-golden-TBG-B_ENTROPY 19/29
# Validation Accuracy: 0.8889, AUROC: 0.7176
# Training Loss: 0.0169, Validation Loss: 0.4774
# Test Loss: 0.2795, Test Accuracy: 0.9300, AUROC: 0.7279
# Training on squad-golden-TBG-B_ENTROPY 20/29
# Validation Accuracy: 0.8750, AUROC: 0.7038
# Training Loss: 0.0072, Validation Loss: 0.6036
# Test Loss: 0.3591, Test Accuracy: 0.9200, AUROC: 0.7505
# Training on squad-golden-TBG-B_ENTROPY 21/29
# Validation Accuracy: 0.8861, AUROC: 0.6668
# Training Loss: 0.0038, Validation Loss: 0.6491
# Test Loss: 0.3232, Test Accuracy: 0.9150, AUROC: 0.7811
# Training on squad-golden-TBG-B_ENTROPY 22/29
# Validation Accuracy: 0.8944, AUROC: 0.7338
# Training Loss: 0.0020, Validation Loss: 0.5992
# Test Loss: 0.3861, Test Accuracy: 0.9100, AUROC: 0.7442
# Training on squad-golden-TBG-B_ENTROPY 23/29
# Validation Accuracy: 0.9056, AUROC: 0.7386
# Training Loss: 0.0012, Validation Loss: 0.5895
# Test Loss: 0.3540, Test Accuracy: 0.9300, AUROC: 0.7484
# Training on squad-golden-TBG-B_ENTROPY 24/29
# Validation Accuracy: 0.9139, AUROC: 0.7926
# Training Loss: 0.0007, Validation Loss: 0.5600
# Test Loss: 0.4342, Test Accuracy: 0.9300, AUROC: 0.6774
# Training on squad-golden-TBG-B_ENTROPY 25/29
# Validation Accuracy: 0.9139, AUROC: 0.7827
# Training Loss: 0.0005, Validation Loss: 0.5507
# Test Loss: 0.4626, Test Accuracy: 0.9250, AUROC: 0.7121
# Training on squad-golden-TBG-B_ENTROPY 26/29
# Validation Accuracy: 0.9111, AUROC: 0.7591
# Training Loss: 0.0003, Validation Loss: 0.5995
# Test Loss: 0.4346, Test Accuracy: 0.9250, AUROC: 0.7705
# Training on squad-golden-TBG-B_ENTROPY 27/29
# Validation Accuracy: 0.8972, AUROC: 0.7662
# Training Loss: 0.0002, Validation Loss: 0.6296
# Test Loss: 0.4783, Test Accuracy: 0.9250, AUROC: 0.7342
# Training on squad-golden-TBG-B_ENTROPY 28/29
# Validation Accuracy: 0.8972, AUROC: 0.7300
# Training Loss: 0.0001, Validation Loss: 0.7375
# Test Loss: 0.4980, Test Accuracy: 0.9100, AUROC: 0.7642
# Training on squad-golden-TBG-B_ENTROPY 29/29
# Validation Accuracy: 0.8889, AUROC: 0.7021
# Training Loss: 0.0002, Validation Loss: 0.8363
# Test Loss: 0.4760, Test Accuracy: 0.9100, AUROC: 0.7826
# Training on squad-golden-SLT-B_ENTROPY 1/29
# Validation Accuracy: 0.9083, AUROC: 0.6254
# Training Loss: 0.2390, Validation Loss: 0.2974
# Test Loss: 0.2050, Test Accuracy: 0.9500, AUROC: 0.5682
# Training on squad-golden-SLT-B_ENTROPY 2/29
# Validation Accuracy: 0.9194, AUROC: 0.6480
# Training Loss: 0.0345, Validation Loss: 0.4028
# Test Loss: 0.2991, Test Accuracy: 0.9350, AUROC: 0.5174
# Training on squad-golden-SLT-B_ENTROPY 3/29
# Validation Accuracy: 0.9139, AUROC: 0.7165
# Training Loss: 0.0213, Validation Loss: 0.3884
# Test Loss: 0.3093, Test Accuracy: 0.9150, AUROC: 0.5984
# Training on squad-golden-SLT-B_ENTROPY 4/29
# Validation Accuracy: 0.9111, AUROC: 0.7020
# Training Loss: 0.0123, Validation Loss: 0.4651
# Test Loss: 0.3409, Test Accuracy: 0.9400, AUROC: 0.5642
# Training on squad-golden-SLT-B_ENTROPY 5/29
# Validation Accuracy: 0.9056, AUROC: 0.7238
# Training Loss: 0.0082, Validation Loss: 0.4645
# Test Loss: 0.3492, Test Accuracy: 0.9400, AUROC: 0.5653
# Training on squad-golden-SLT-B_ENTROPY 6/29
# Validation Accuracy: 0.9111, AUROC: 0.7617
# Training Loss: 0.0053, Validation Loss: 0.4213
# Test Loss: 0.2779, Test Accuracy: 0.9500, AUROC: 0.6632
# Training on squad-golden-SLT-B_ENTROPY 7/29
# Validation Accuracy: 0.9111, AUROC: 0.7619
# Training Loss: 0.0043, Validation Loss: 0.4332
# Test Loss: 0.2985, Test Accuracy: 0.9450, AUROC: 0.6905
# Training on squad-golden-SLT-B_ENTROPY 8/29
# Validation Accuracy: 0.9083, AUROC: 0.7498
# Training Loss: 0.0033, Validation Loss: 0.4498
# Test Loss: 0.3735, Test Accuracy: 0.9350, AUROC: 0.5842
# Training on squad-golden-SLT-B_ENTROPY 9/29
# Validation Accuracy: 0.9139, AUROC: 0.7376
# Training Loss: 0.0029, Validation Loss: 0.4715
# Test Loss: 0.2980, Test Accuracy: 0.9450, AUROC: 0.6947
# Training on squad-golden-SLT-B_ENTROPY 10/29
# Validation Accuracy: 0.9111, AUROC: 0.7198
# Training Loss: 0.0023, Validation Loss: 0.5135
# Test Loss: 0.4104, Test Accuracy: 0.9350, AUROC: 0.5600
# Training on squad-golden-SLT-B_ENTROPY 11/29
# Validation Accuracy: 0.9083, AUROC: 0.7402
# Training Loss: 0.0024, Validation Loss: 0.4798
# Test Loss: 0.3399, Test Accuracy: 0.9250, AUROC: 0.6558
# Training on squad-golden-SLT-B_ENTROPY 12/29
# Validation Accuracy: 0.8917, AUROC: 0.7244
# Training Loss: 0.0022, Validation Loss: 0.5158
# Test Loss: 0.3490, Test Accuracy: 0.9400, AUROC: 0.6274
# Training on squad-golden-SLT-B_ENTROPY 13/29
# Validation Accuracy: 0.9000, AUROC: 0.6980
# Training Loss: 0.0021, Validation Loss: 0.5771
# Test Loss: 0.4025, Test Accuracy: 0.9300, AUROC: 0.5821
# Training on squad-golden-SLT-B_ENTROPY 14/29
# Validation Accuracy: 0.8972, AUROC: 0.7424
# Training Loss: 0.0020, Validation Loss: 0.5393
# Test Loss: 0.3404, Test Accuracy: 0.9400, AUROC: 0.6547
# Training on squad-golden-SLT-B_ENTROPY 15/29
# Validation Accuracy: 0.8889, AUROC: 0.7274
# Training Loss: 0.0018, Validation Loss: 0.5568
# Test Loss: 0.3699, Test Accuracy: 0.9200, AUROC: 0.6605
# Training on squad-golden-SLT-B_ENTROPY 16/29
# Validation Accuracy: 0.8889, AUROC: 0.7414
# Training Loss: 0.0017, Validation Loss: 0.5048
# Test Loss: 0.3563, Test Accuracy: 0.9300, AUROC: 0.6826
# Training on squad-golden-SLT-B_ENTROPY 17/29
# Validation Accuracy: 0.9083, AUROC: 0.7891
# Training Loss: 0.0014, Validation Loss: 0.4696
# Test Loss: 0.3404, Test Accuracy: 0.9350, AUROC: 0.7226
# Training on squad-golden-SLT-B_ENTROPY 18/29
# Validation Accuracy: 0.9194, AUROC: 0.7825
# Training Loss: 0.0012, Validation Loss: 0.4719
# Test Loss: 0.3313, Test Accuracy: 0.9400, AUROC: 0.7589
# Training on squad-golden-SLT-B_ENTROPY 19/29
# Validation Accuracy: 0.9139, AUROC: 0.7979
# Training Loss: 0.0011, Validation Loss: 0.4804
# Test Loss: 0.3556, Test Accuracy: 0.9350, AUROC: 0.6895
# Training on squad-golden-SLT-B_ENTROPY 20/29
# Validation Accuracy: 0.9056, AUROC: 0.8032
# Training Loss: 0.0010, Validation Loss: 0.4906
# Test Loss: 0.3455, Test Accuracy: 0.9400, AUROC: 0.7305
# Training on squad-golden-SLT-B_ENTROPY 21/29
# Validation Accuracy: 0.9056, AUROC: 0.8034
# Training Loss: 0.0007, Validation Loss: 0.4659
# Test Loss: 0.3578, Test Accuracy: 0.9350, AUROC: 0.7495
# Training on squad-golden-SLT-B_ENTROPY 22/29
# Validation Accuracy: 0.9194, AUROC: 0.8104
# Training Loss: 0.0005, Validation Loss: 0.4449
# Test Loss: 0.3362, Test Accuracy: 0.9400, AUROC: 0.7611
# Training on squad-golden-SLT-B_ENTROPY 23/29
# Validation Accuracy: 0.9167, AUROC: 0.8066
# Training Loss: 0.0004, Validation Loss: 0.4850
# Test Loss: 0.3443, Test Accuracy: 0.9350, AUROC: 0.7716
# Training on squad-golden-SLT-B_ENTROPY 24/29
# Validation Accuracy: 0.9056, AUROC: 0.7949
# Training Loss: 0.0003, Validation Loss: 0.5620
# Test Loss: 0.4226, Test Accuracy: 0.9400, AUROC: 0.7326
# Training on squad-golden-SLT-B_ENTROPY 25/29
# Validation Accuracy: 0.9139, AUROC: 0.8088
# Training Loss: 0.0002, Validation Loss: 0.5605
# Test Loss: 0.4330, Test Accuracy: 0.9300, AUROC: 0.6879
# Training on squad-golden-SLT-B_ENTROPY 26/29
# Validation Accuracy: 0.9028, AUROC: 0.8162
# Training Loss: 0.0001, Validation Loss: 0.6372
# Test Loss: 0.4085, Test Accuracy: 0.9500, AUROC: 0.7247
# Training on squad-golden-SLT-B_ENTROPY 27/29
# Validation Accuracy: 0.9083, AUROC: 0.8348
# Training Loss: 0.0001, Validation Loss: 0.5536
# Test Loss: 0.4782, Test Accuracy: 0.9300, AUROC: 0.6574
# Training on squad-golden-SLT-B_ENTROPY 28/29
# Validation Accuracy: 0.9139, AUROC: 0.8177
# Training Loss: 0.0001, Validation Loss: 0.5660
# Test Loss: 0.5682, Test Accuracy: 0.9300, AUROC: 0.5947
# Training on squad-golden-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.9167, AUROC: 0.7362
# Training Loss: 0.0001, Validation Loss: 0.6193
# Test Loss: 0.6203, Test Accuracy: 0.9350, AUROC: 0.5437
# Training on triviaqa-golden-TBG-B_ENTROPY 1/29
# Validation Accuracy: 0.7806, AUROC: 0.5000
# Training Loss: 0.5424, Validation Loss: 0.5267
# Test Loss: 0.5393, Test Accuracy: 0.7700, AUROC: 0.5000
# Training on triviaqa-golden-TBG-B_ENTROPY 2/29
# Validation Accuracy: 0.7750, AUROC: 0.5684
# Training Loss: 0.4530, Validation Loss: 0.5399
# Test Loss: 0.5285, Test Accuracy: 0.7750, AUROC: 0.6009
# Training on triviaqa-golden-TBG-B_ENTROPY 3/29
# Validation Accuracy: 0.7667, AUROC: 0.5654
# Training Loss: 0.4008, Validation Loss: 0.5561
# Test Loss: 0.5326, Test Accuracy: 0.7750, AUROC: 0.6060
# Training on triviaqa-golden-TBG-B_ENTROPY 4/29
# Validation Accuracy: 0.7639, AUROC: 0.5572
# Training Loss: 0.3523, Validation Loss: 0.5848
# Test Loss: 0.5709, Test Accuracy: 0.7600, AUROC: 0.5711
# Training on triviaqa-golden-TBG-B_ENTROPY 5/29
# Validation Accuracy: 0.7611, AUROC: 0.5603
# Training Loss: 0.3318, Validation Loss: 0.5967
# Test Loss: 0.9092, Test Accuracy: 0.7750, AUROC: 0.7451
# Training on triviaqa-golden-TBG-B_ENTROPY 19/29
# Validation Accuracy: 0.7694, AUROC: 0.7313
# Training Loss: 0.0474, Validation Loss: 0.8642
# Test Loss: 0.8715, Test Accuracy: 0.7850, AUROC: 0.7394
# Training on triviaqa-golden-TBG-B_ENTROPY 20/29
# Validation Accuracy: 0.7833, AUROC: 0.7567
# Training Loss: 0.0330, Validation Loss: 0.9196
# Test Loss: 1.3017, Test Accuracy: 0.7450, AUROC: 0.6612
# Training on triviaqa-golden-TBG-B_ENTROPY 21/29
# Validation Accuracy: 0.7778, AUROC: 0.7551
# Training Loss: 0.0114, Validation Loss: 1.0236
# Test Loss: 1.3337, Test Accuracy: 0.7400, AUROC: 0.6957
# Training on triviaqa-golden-TBG-B_ENTROPY 22/29
# Validation Accuracy: 0.7972, AUROC: 0.7691
# Training Loss: 0.0065, Validation Loss: 1.1359
# Test Loss: 1.3185, Test Accuracy: 0.7800, AUROC: 0.7318
# Training on triviaqa-golden-TBG-B_ENTROPY 23/29
# Validation Accuracy: 0.7611, AUROC: 0.7403
# Training Loss: 0.0036, Validation Loss: 1.1194
# Test Loss: 1.1888, Test Accuracy: 0.7800, AUROC: 0.7617
# Training on triviaqa-golden-TBG-B_ENTROPY 24/29
# Validation Accuracy: 0.7611, AUROC: 0.7338
# Training Loss: 0.0020, Validation Loss: 1.3966
# Test Loss: 1.2093, Test Accuracy: 0.7850, AUROC: 0.7873
# Training on triviaqa-golden-TBG-B_ENTROPY 25/29
# Validation Accuracy: 0.7944, AUROC: 0.7429
# Training Loss: 0.0011, Validation Loss: 1.3139
# Test Loss: 1.1415, Test Accuracy: 0.7900, AUROC: 0.7898
# Training on triviaqa-golden-TBG-B_ENTROPY 26/29
# Validation Accuracy: 0.7611, AUROC: 0.7381
# Training Loss: 0.0007, Validation Loss: 1.5925
# Test Loss: 1.3807, Test Accuracy: 0.7650, AUROC: 0.7794
# Training on triviaqa-golden-TBG-B_ENTROPY 27/29
# Validation Accuracy: 0.7806, AUROC: 0.7433
# Training Loss: 0.0005, Validation Loss: 1.5634
# Test Loss: 1.5967, Test Accuracy: 0.7400, AUROC: 0.7442
# Training on triviaqa-golden-TBG-B_ENTROPY 28/29
# Validation Accuracy: 0.7722, AUROC: 0.7317
# Training Loss: 0.0003, Validation Loss: 1.4831
# Test Loss: 1.6455, Test Accuracy: 0.7700, AUROC: 0.7554
# Training on triviaqa-golden-TBG-B_ENTROPY 29/29
# Validation Accuracy: 0.7833, AUROC: 0.7341
# Training Loss: 0.0006, Validation Loss: 1.7462
# Test Loss: 2.1668, Test Accuracy: 0.7750, AUROC: 0.7295
# Training on triviaqa-golden-SLT-B_ENTROPY 1/29
# Validation Accuracy: 0.7861, AUROC: 0.6786
# Training Loss: 0.4345, Validation Loss: 0.4927
# Test Loss: 0.4996, Test Accuracy: 0.7750, AUROC: 0.6730
# Training on triviaqa-golden-SLT-B_ENTROPY 2/29
# Validation Accuracy: 0.7778, AUROC: 0.6697
# Training Loss: 0.0851, Validation Loss: 0.6894
# Test Loss: 0.8038, Test Accuracy: 0.7600, AUROC: 0.6683
# Training on triviaqa-golden-SLT-B_ENTROPY 3/29
# Validation Accuracy: 0.7944, AUROC: 0.7023
# Training Loss: 0.0551, Validation Loss: 0.7282
# Test Loss: 0.8316, Test Accuracy: 0.7900, AUROC: 0.6924
# Training on triviaqa-golden-SLT-B_ENTROPY 4/29
# Validation Accuracy: 0.7722, AUROC: 0.7057
# Training Loss: 0.0396, Validation Loss: 0.8680
# Test Loss: 0.8709, Test Accuracy: 0.7650, AUROC: 0.7092
# Training on triviaqa-golden-SLT-B_ENTROPY 5/29
# Validation Accuracy: 0.7833, AUROC: 0.7009
# Training Loss: 0.0290, Validation Loss: 0.9757
# Test Loss: 0.8499, Test Accuracy: 0.7550, AUROC: 0.7300
# Training on triviaqa-golden-SLT-B_ENTROPY 6/29
# Validation Accuracy: 0.7917, AUROC: 0.7205
# Training Loss: 0.0184, Validation Loss: 0.9263
# Test Loss: 0.9165, Test Accuracy: 0.7550, AUROC: 0.7312
# Training on triviaqa-golden-SLT-B_ENTROPY 7/29
# Validation Accuracy: 0.7833, AUROC: 0.6789
# Training Loss: 0.0142, Validation Loss: 1.1017
# Test Loss: 0.8892, Test Accuracy: 0.8100, AUROC: 0.7472
# Training on triviaqa-golden-SLT-B_ENTROPY 8/29
# Validation Accuracy: 0.7833, AUROC: 0.6992
# Training Loss: 0.0118, Validation Loss: 1.1229
# Test Loss: 1.0314, Test Accuracy: 0.7850, AUROC: 0.7130
# Training on triviaqa-golden-SLT-B_ENTROPY 9/29
# Validation Accuracy: 0.7778, AUROC: 0.7087
# Training Loss: 0.0104, Validation Loss: 1.1639
# Test Loss: 1.0514, Test Accuracy: 0.7750, AUROC: 0.7338
# Training on triviaqa-golden-SLT-B_ENTROPY 10/29
# Validation Accuracy: 0.7917, AUROC: 0.7458
# Training Loss: 0.0077, Validation Loss: 1.0334
# Test Loss: 0.9926, Test Accuracy: 0.7900, AUROC: 0.7489
# Training on triviaqa-golden-SLT-B_ENTROPY 11/29
# Validation Accuracy: 0.7861, AUROC: 0.7222
# Training Loss: 0.0081, Validation Loss: 1.0832
# Test Loss: 1.1653, Test Accuracy: 0.7650, AUROC: 0.7225
# Training on triviaqa-golden-SLT-B_ENTROPY 12/29
# Validation Accuracy: 0.7889, AUROC: 0.7219
# Training Loss: 0.0081, Validation Loss: 1.0709
# Test Loss: 1.1805, Test Accuracy: 0.7550, AUROC: 0.7228
# Training on triviaqa-golden-SLT-B_ENTROPY 13/29
# Validation Accuracy: 0.8083, AUROC: 0.7422
# Training Loss: 0.0069, Validation Loss: 1.0815
# Test Loss: 1.0413, Test Accuracy: 0.7900, AUROC: 0.7616
# Training on triviaqa-golden-SLT-B_ENTROPY 14/29
# Validation Accuracy: 0.7972, AUROC: 0.7190
# Training Loss: 0.0064, Validation Loss: 1.2109
# Test Loss: 1.1954, Test Accuracy: 0.7700, AUROC: 0.7398
# Training on triviaqa-golden-SLT-B_ENTROPY 15/29
# Validation Accuracy: 0.7861, AUROC: 0.7198
# Validation Accuracy: 0.8333, AUROC: 0.7800
# Training Loss: 0.0001, Validation Loss: 1.3025
# Test Loss: 1.6347, Test Accuracy: 0.7700, AUROC: 0.7414
# Training on triviaqa-golden-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.8056, AUROC: 0.7732
# Training Loss: 0.0002, Validation Loss: 1.2340
# Test Loss: 1.7535, Test Accuracy: 0.7650, AUROC: 0.7149

# %%
# plot se probe
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.tb_aucs), auc(D.sb_aucs)], ["SE Probe on TBG token", "SE Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="se_both_tok")
plt.show()

# %% [markdown]
# ### Train linear probes to predict Accuracy

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'accuracies')
    train_single_metric(D, 'slt', 'accuracies')
# Out:
# Training on squad-golden-TBG-ACCURACIES 1/29
# Validation Accuracy: 0.8833, AUROC: 0.5000
# Training Loss: 0.3848, Validation Loss: 0.3609
# Test Loss: 0.3291, Test Accuracy: 0.9000, AUROC: 0.5000
# Training on squad-golden-TBG-ACCURACIES 2/29
# Validation Accuracy: 0.8833, AUROC: 0.5776
# Training Loss: 0.3145, Validation Loss: 0.3606
# Test Loss: 0.3256, Test Accuracy: 0.8950, AUROC: 0.6211
# Training on squad-golden-TBG-ACCURACIES 3/29
# Validation Accuracy: 0.8778, AUROC: 0.5847
# Training Loss: 0.2817, Validation Loss: 0.3673
# Test Loss: 0.3360, Test Accuracy: 0.8950, AUROC: 0.5250
# Training on squad-golden-TBG-ACCURACIES 4/29
# Validation Accuracy: 0.8778, AUROC: 0.6464
# Training Loss: 0.2466, Validation Loss: 0.3631
# Test Loss: 0.3517, Test Accuracy: 0.8950, AUROC: 0.5264
# Training on squad-golden-TBG-ACCURACIES 5/29
# Validation Accuracy: 0.8806, AUROC: 0.6087
# Training Loss: 0.2250, Validation Loss: 0.3749
# Test Loss: 0.3379, Test Accuracy: 0.9050, AUROC: 0.5603
# Training on squad-golden-TBG-ACCURACIES 6/29
# Validation Accuracy: 0.8667, AUROC: 0.6100
# Training Loss: 0.1768, Validation Loss: 0.3997
# Test Loss: 0.3410, Test Accuracy: 0.8850, AUROC: 0.6378
# Training on squad-golden-TBG-ACCURACIES 7/29
# Validation Accuracy: 0.8583, AUROC: 0.5526
# Training Loss: 0.1629, Validation Loss: 0.4349
# Test Loss: 0.3381, Test Accuracy: 0.8850, AUROC: 0.6422
# Training on squad-golden-TBG-ACCURACIES 8/29
# Validation Accuracy: 0.8556, AUROC: 0.5209
# Training Loss: 0.1280, Validation Loss: 0.4812
# Test Loss: 0.3325, Test Accuracy: 0.8900, AUROC: 0.6908
# Training on squad-golden-TBG-ACCURACIES 9/29
# Validation Accuracy: 0.8583, AUROC: 0.5307
# Training Loss: 0.1147, Validation Loss: 0.4949
# Test Loss: 0.3860, Test Accuracy: 0.8750, AUROC: 0.6208
# Training on squad-golden-TBG-ACCURACIES 10/29
# Validation Accuracy: 0.8389, AUROC: 0.5210
# Training Loss: 0.1131, Validation Loss: 0.5473
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.ta_aucs), auc(D.sa_aucs)], ["Acc Probe on TBG token", "Acc Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="acc_both_tok")
plt.show()

# %% [markdown]
# ### Use linear probe trained on Binarized SE to predict Accuracy
#
# We leverage trained probes on semantic entropy to predict model correctness on the same dataset.
#
# Note that we need to predict the error rate (1 minus accuracy) using SEPs due to the nature of semantic uncertainty.

# %%
for D in Ds:
    r_acc = 1 - D.accuracies
    
    # TBG
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.tbg_dataset, r_acc) 
    tab_accs = []
    tab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-TBG {i+1}/{len(X_tests)}")
        model = D.tb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        tab_accs.append(test_acc)
        tab_aucs.append(test_auc)

    D.tab_accs = tab_accs
    D.tab_aucs = tab_aucs

    # SLT t
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.slt_dataset, r_acc)     
    sab_accs = []
    sab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-SLT {i+1}/{len(X_tests)}")
        model = D.sb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        sab_accs.append(test_acc)
        sab_aucs.append(test_auc)

    D.sab_accs = sab_accs
    D.sab_aucs = sab_aucs
# Out:
# Testing on squad-golden-TBG 1/29
# Test Loss: 0.3268, Test Accuracy: 0.9000, AUROC: 0.5000
# Testing on squad-golden-TBG 2/29
# Test Loss: 0.3418, Test Accuracy: 0.9000, AUROC: 0.5019
# Testing on squad-golden-TBG 3/29
# Test Loss: 0.3483, Test Accuracy: 0.8950, AUROC: 0.5067
# Testing on squad-golden-TBG 4/29
# Test Loss: 0.3866, Test Accuracy: 0.8850, AUROC: 0.4767
# Testing on squad-golden-TBG 5/29
# Test Loss: 0.3801, Test Accuracy: 0.8900, AUROC: 0.5197
# Testing on squad-golden-TBG 6/29
# Test Loss: 0.3847, Test Accuracy: 0.9000, AUROC: 0.5450
# Testing on squad-golden-TBG 7/29
# Test Loss: 0.4448, Test Accuracy: 0.8900, AUROC: 0.5025
# Testing on squad-golden-TBG 8/29
# Test Loss: 0.4344, Test Accuracy: 0.8850, AUROC: 0.5158
# Testing on squad-golden-TBG 9/29
# Test Loss: 0.4658, Test Accuracy: 0.8850, AUROC: 0.5122
# Testing on squad-golden-TBG 10/29
# Test Loss: 0.5288, Test Accuracy: 0.8850, AUROC: 0.4636
# Testing on squad-golden-TBG 11/29
# Test Loss: 0.4776, Test Accuracy: 0.8850, AUROC: 0.5025
# Testing on squad-golden-TBG 12/29
# Test Loss: 0.4946, Test Accuracy: 0.8850, AUROC: 0.5158
# Testing on squad-golden-TBG 13/29
# Test Loss: 0.4710, Test Accuracy: 0.8900, AUROC: 0.5706
# Testing on squad-golden-TBG 14/29
# Test Loss: 0.4507, Test Accuracy: 0.8750, AUROC: 0.6175
# Testing on squad-golden-TBG 15/29
# Test Loss: 0.4912, Test Accuracy: 0.8800, AUROC: 0.6172
# Testing on squad-golden-TBG 16/29
# Test Loss: 0.4630, Test Accuracy: 0.8600, AUROC: 0.6639
# Testing on squad-golden-TBG 17/29
# Test Loss: 0.3959, Test Accuracy: 0.8900, AUROC: 0.7175
# Testing on squad-golden-TBG 18/29
# Test Loss: 0.4116, Test Accuracy: 0.9050, AUROC: 0.7306
# Testing on squad-golden-TBG 19/29
# Test Loss: 0.5319, Test Accuracy: 0.9000, AUROC: 0.7069
# Testing on squad-golden-TBG 20/29
# Test Loss: 0.5586, Test Accuracy: 0.9000, AUROC: 0.7336
# Testing on squad-golden-TBG 21/29
# Test Loss: 0.6366, Test Accuracy: 0.8850, AUROC: 0.6947
# Testing on squad-golden-TBG 22/29
# Test Loss: 0.6693, Test Accuracy: 0.8800, AUROC: 0.7075
# Testing on squad-golden-TBG 23/29
# Test Loss: 0.7496, Test Accuracy: 0.8700, AUROC: 0.6736
# Testing on squad-golden-TBG 24/29
# Test Loss: 0.7551, Test Accuracy: 0.8800, AUROC: 0.6992
# Testing on squad-golden-TBG 25/29
# Test Loss: 0.8394, Test Accuracy: 0.8850, AUROC: 0.7081
# Testing on squad-golden-TBG 26/29
# Test Loss: 0.7581, Test Accuracy: 0.8950, AUROC: 0.7711
# Testing on squad-golden-TBG 27/29
# Test Loss: 0.8115, Test Accuracy: 0.8750, AUROC: 0.7544
# Testing on squad-golden-TBG 28/29
# Test Loss: 0.8214, Test Accuracy: 0.8900, AUROC: 0.7581
# Testing on squad-golden-TBG 29/29
# Test Loss: 0.8205, Test Accuracy: 0.8900, AUROC: 0.7200
# Testing on squad-golden-SLT 1/29
# Test Loss: 0.3230, Test Accuracy: 0.9000, AUROC: 0.5596
# Testing on squad-golden-SLT 2/29
# Test Loss: 0.4201, Test Accuracy: 0.8950, AUROC: 0.6919
# Testing on squad-golden-SLT 3/29
# Test Loss: 0.4325, Test Accuracy: 0.8850, AUROC: 0.7242
# Testing on squad-golden-SLT 4/29
# Test Loss: 0.4784, Test Accuracy: 0.9000, AUROC: 0.6992
# Testing on squad-golden-SLT 5/29
# Test Loss: 0.5030, Test Accuracy: 0.9000, AUROC: 0.6942
# Testing on squad-golden-SLT 6/29
# Test Loss: 0.4684, Test Accuracy: 0.9000, AUROC: 0.7372
# Testing on squad-golden-SLT 7/29
# Test Loss: 0.5182, Test Accuracy: 0.8950, AUROC: 0.7083
# Testing on squad-golden-SLT 8/29
# Test Loss: 0.6089, Test Accuracy: 0.8850, AUROC: 0.7094
# Testing on squad-golden-SLT 9/29
# Test Loss: 0.5852, Test Accuracy: 0.8950, AUROC: 0.7058
# Testing on squad-golden-SLT 10/29
# Test Loss: 0.6376, Test Accuracy: 0.9050, AUROC: 0.6614
# Testing on squad-golden-SLT 11/29
# Test Loss: 0.6258, Test Accuracy: 0.8850, AUROC: 0.6717
# Testing on squad-golden-SLT 12/29
# Test Loss: 0.6244, Test Accuracy: 0.9000, AUROC: 0.6806
# Testing on squad-golden-SLT 13/29
# Test Loss: 0.7407, Test Accuracy: 0.8900, AUROC: 0.5983
# Testing on squad-golden-SLT 14/29
# Test Loss: 0.7302, Test Accuracy: 0.9000, AUROC: 0.5983
# Testing on squad-golden-SLT 15/29
# Test Loss: 0.7920, Test Accuracy: 0.8800, AUROC: 0.5839
# Testing on squad-golden-SLT 16/29
# Test Loss: 0.7438, Test Accuracy: 0.8900, AUROC: 0.6233
# Testing on squad-golden-SLT 17/29
# Test Loss: 0.7180, Test Accuracy: 0.8950, AUROC: 0.6622
# Testing on squad-golden-SLT 18/29
# Test Loss: 0.6769, Test Accuracy: 0.9100, AUROC: 0.6983
# Testing on squad-golden-SLT 19/29
# Test Loss: 0.6937, Test Accuracy: 0.9050, AUROC: 0.6717
# Testing on squad-golden-SLT 20/29
# Test Loss: 0.6508, Test Accuracy: 0.9000, AUROC: 0.7261
# Testing on squad-golden-SLT 21/29
# Test Loss: 0.6989, Test Accuracy: 0.8850, AUROC: 0.7256
# Testing on squad-golden-SLT 22/29
# Test Loss: 0.6789, Test Accuracy: 0.8900, AUROC: 0.7414
# Testing on squad-golden-SLT 23/29
# Test Loss: 0.7410, Test Accuracy: 0.8950, AUROC: 0.7075
# Testing on squad-golden-SLT 24/29
# Test Loss: 0.7875, Test Accuracy: 0.9100, AUROC: 0.7183
# Testing on squad-golden-SLT 25/29
# Test Loss: 0.7864, Test Accuracy: 0.9000, AUROC: 0.6850
# Testing on squad-golden-SLT 26/29
# Test Loss: 0.8175, Test Accuracy: 0.9100, AUROC: 0.6647
# Testing on squad-golden-SLT 27/29
# Test Loss: 0.9383, Test Accuracy: 0.9000, AUROC: 0.5964
# Testing on squad-golden-SLT 28/29
# Test Loss: 0.9602, Test Accuracy: 0.8900, AUROC: 0.6067
# Testing on squad-golden-SLT 29/29
# Test Loss: 1.0854, Test Accuracy: 0.8950, AUROC: 0.5675
# Testing on triviaqa-golden-TBG 1/29
# Test Loss: 0.4975, Test Accuracy: 0.8050, AUROC: 0.5000
# Testing on triviaqa-golden-TBG 2/29
# Test Loss: 0.4990, Test Accuracy: 0.8100, AUROC: 0.5582
# Testing on triviaqa-golden-TBG 3/29
# Test Loss: 0.5015, Test Accuracy: 0.8200, AUROC: 0.5557
# Testing on triviaqa-golden-TBG 4/29
# Test Loss: 0.5369, Test Accuracy: 0.8150, AUROC: 0.5230
# Testing on triviaqa-golden-TBG 5/29
# Test Loss: 0.5525, Test Accuracy: 0.7800, AUROC: 0.5421
# Testing on triviaqa-golden-TBG 6/29
# Test Loss: 0.6173, Test Accuracy: 0.7850, AUROC: 0.5517
# Testing on triviaqa-golden-TBG 7/29
# Test Loss: 0.6353, Test Accuracy: 0.7700, AUROC: 0.5697
# Testing on triviaqa-golden-TBG 8/29
# Test Loss: 0.7083, Test Accuracy: 0.7750, AUROC: 0.5431
# Testing on triviaqa-golden-TBG 9/29
# Test Loss: 0.7979, Test Accuracy: 0.7400, AUROC: 0.5205
# Testing on triviaqa-golden-TBG 10/29
# Test Loss: 0.8150, Test Accuracy: 0.7350, AUROC: 0.5843
# Testing on triviaqa-golden-SLT 8/29
# Test Loss: 0.7191, Test Accuracy: 0.8400, AUROC: 0.7804
# Testing on triviaqa-golden-SLT 9/29
# Test Loss: 0.8050, Test Accuracy: 0.8100, AUROC: 0.7672
# Testing on triviaqa-golden-SLT 10/29
# Test Loss: 0.7068, Test Accuracy: 0.8350, AUROC: 0.8130
# Testing on triviaqa-golden-SLT 11/29
# Test Loss: 0.8207, Test Accuracy: 0.8100, AUROC: 0.7982
# Testing on triviaqa-golden-SLT 12/29
# Test Loss: 0.9301, Test Accuracy: 0.8100, AUROC: 0.7621
# Testing on triviaqa-golden-SLT 13/29
# Test Loss: 0.9889, Test Accuracy: 0.8150, AUROC: 0.7571
# Testing on triviaqa-golden-SLT 14/29
# Test Loss: 0.8798, Test Accuracy: 0.8250, AUROC: 0.7942
# Testing on triviaqa-golden-SLT 15/29
# Test Loss: 0.7347, Test Accuracy: 0.8500, AUROC: 0.8121
# Testing on triviaqa-golden-SLT 16/29
# Test Loss: 0.7264, Test Accuracy: 0.8450, AUROC: 0.8151
# Testing on triviaqa-golden-SLT 17/29
# Test Loss: 0.7304, Test Accuracy: 0.8350, AUROC: 0.8347
# Testing on triviaqa-golden-SLT 18/29
# Test Loss: 0.6940, Test Accuracy: 0.8350, AUROC: 0.8447
# Testing on triviaqa-golden-SLT 19/29
# Test Loss: 0.7490, Test Accuracy: 0.8500, AUROC: 0.8457
# Testing on triviaqa-golden-SLT 20/29
# Test Loss: 0.7698, Test Accuracy: 0.8200, AUROC: 0.8194
# Testing on triviaqa-golden-SLT 21/29
# Test Loss: 0.9015, Test Accuracy: 0.8350, AUROC: 0.8046
# Testing on triviaqa-golden-SLT 22/29
# Test Loss: 0.9260, Test Accuracy: 0.8200, AUROC: 0.7917
# Testing on triviaqa-golden-SLT 23/29
# Test Loss: 0.9233, Test Accuracy: 0.8400, AUROC: 0.8047
# Testing on triviaqa-golden-SLT 24/29
# Test Loss: 1.0681, Test Accuracy: 0.8350, AUROC: 0.8097
# Testing on triviaqa-golden-SLT 25/29
# Test Loss: 1.0947, Test Accuracy: 0.8300, AUROC: 0.7914
# Testing on triviaqa-golden-SLT 26/29
# Test Loss: 1.1672, Test Accuracy: 0.8350, AUROC: 0.7821
# Testing on triviaqa-golden-SLT 27/29
# Test Loss: 1.2221, Test Accuracy: 0.8350, AUROC: 0.7715
# Testing on triviaqa-golden-SLT 28/29
# Test Loss: 1.1495, Test Accuracy: 0.8350, AUROC: 0.7982
# Testing on triviaqa-golden-SLT 29/29
# Test Loss: 1.1473, Test Accuracy: 0.8300, AUROC: 0.7842

# %%
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [D.sa_aucs, D.sab_aucs], ["LR trained and tested on Acc", "LR trained on SE, tested on Acc"], f"AUROC on {D.name.upper()}'s SLT")
plt.tight_layout()
save_fig(name="se_for_acc_slt")
plt.show()

# %%
# select best layer range (SLT)
def decide_layer_range(Ds, metric='entropy', limit=NUMBER_OF_LAYERS+1): # NOTE: set upperbound to be number of layers+1; e.g. for llama2-70b, it is 81.
    """
    simple logic: use ID average test AUROCs across layers to determine 
    which consecutive range of layers did the best. Do separately
    for SEP and Acc. Pr.
    """
    assert hasattr(Ds[0], 'sab_aucs') and hasattr(Ds[0], 'sa_aucs'), 'previous cells need to be run'
    if 'entropy' in metric:
        aucs = [np.array(auc(D.sab_aucs)) for D in Ds]  # test metrics for ID SEPs
    else:
        aucs = [np.array(auc(D.sa_aucs)) for D in Ds]  # test metrics for ID APs
    best_mean = -np.inf
    best_range = []
    average = lambda a,b : np.mean([np.mean(ac[a:b]) for ac in aucs])

    for i in range(limit):
        for j in range(i+1, limit):
            if j - i < 5: # must be more than 5 layers
                continue
            if average(i, j) > best_mean:
                best_mean = average(i, j)
                best_range = [i, j]

    return best_mean, best_range

emean, (e1, e2) = decide_layer_range(Ds, 'entropy')
amean, (a1, a2) = decide_layer_range(Ds, 'acc')
for D in Ds:
    D.sep_layer_range = (e1, e2)
    D.ap_layer_range = (a1, a2)
print(emean, (e1, e2), amean, (a1, a2))
# Out:
# 0.7669123400753834 (17, 22) 0.7701132876785051 (17, 22)

# %%
# BOOTSTRAP: select [xx-xx] layers for bootstrapping
def concat_Xs_and_ys(layer_range, X_trains, X_vals, X_tests, y_trains, y_vals, y_tests, 
                     no_val=False, test_only=False):
    """
    Concatenate @params{layer_range} hidden state layers on train/val/test sets.

    no_val: no validation (training set only).
    test_only: no train/validation set (test set only).
    """
    if not no_val:
        X_val_cc = np.concatenate(np.array(X_vals)[layer_range], axis=1)
        y_val_cc = y_vals[layer_range[0]]
    else:
        X_val_cc = y_val_cc = None

    if not test_only:
        X_train_cc = np.concatenate(np.array(X_trains)[layer_range], axis=1)
        y_train_cc = y_trains[layer_range[0]]
    else:
        X_train_cc = y_train_cc = None
    
    X_test_cc = np.concatenate(np.array(X_tests)[layer_range], axis=1)
    y_test_cc = y_tests[layer_range[0]]
    
    return X_train_cc, X_val_cc, X_test_cc, y_train_cc, y_val_cc, y_test_cc

def train_concat_SE(D, layer_range):
    """train model on single dataset SE with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_bmodel', model)

        print(f'{token_type.upper()} trained on {D.name} SE finished')
    
def train_concat_Acc(D, layer_range):
    """train model on single dataset Accuracy with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_amodel', model)

        print(f'{token_type.upper()} trained on {D.name} Acc finished')

def train_concat_SE_Acc_test_Acc(D, layer_ranges=[list(range(e1,e2)), list(range(a1,a2))]):
    """ID: train and test SEPs and Acc. Pr. on single dataset with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, no_val=True) 
        
        X_train_cc, _, _, y_train_cc, _, _ = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys, no_val=True)
        ab_accs = []
        ab_aucs = []
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)

        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies) 
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys) # fixed random seed ensures no data leakage
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, 1-y_test_cc) # SEP predicts error rate
        ab_accs.append(test_acc)
        ab_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}b_accs', ab_accs)  # i means IDß
        setattr(D, f'i{var_name}b_aucs', ab_aucs)

        print(f'{D.name.upper()}-{token_type.upper()} trainied on SE and tested on Acc finished')
        aa_accs = []
        aa_aucs = []
        X_train_cc, _, X_test_cc, y_train_cc, _, y_test_cc = concat_Xs_and_ys(layer_ranges[1], *all_Xs_and_ys, no_val=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, y_test_cc)
        aa_accs.append(test_acc)
        aa_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}a_accs', aa_accs)
        setattr(D, f'i{var_name}a_aucs', aa_aucs)
        print(f'{D.name.upper()}-{token_type.upper()} trainied on Acc and tested on Acc finished')

# %%
# ID: train SEPs and Acc. Pr. and test them on Acc. from the same dataset
# import warnings # uncomment to disable convergence warnings
# warnings.filterwarnings('ignore')

for D in Ds:
    train_concat_SE_Acc_test_Acc(D)
# Out:
# Test Loss: 0.7846, Test Accuracy: 0.9000, AUROC: 0.7164
# SQUAD-GOLDEN-SLT trainied on SE and tested on Acc finished
# Test Loss: 0.7168, Test Accuracy: 0.8950, AUROC: 0.6889
# SQUAD-GOLDEN-SLT trainied on Acc and tested on Acc finished
# Test Loss: 0.9722, Test Accuracy: 0.8050, AUROC: 0.8141
# TRIVIAQA-GOLDEN-SLT trainied on SE and tested on Acc finished
# Test Loss: 0.6490, Test Accuracy: 0.9000, AUROC: 0.8723
# TRIVIAQA-GOLDEN-SLT trainied on Acc and tested on Acc finished

# %%
# OOD: save model trained on individual datasets for OOD tests
for D in Ds:
    train_concat_SE(D, layer_range=list(range(e1,e2)))
    train_concat_Acc(D, layer_range=list(range(a1,a2)))
# outputs cleared for space concern
# Out:
# SLT trained on squad-golden SE finished
# SLT trained on squad-golden Acc finished
# SLT trained on triviaqa-golden SE finished
# SLT trained on triviaqa-golden Acc finished

# %% [markdown]
# ## Test probes trained with one dataset on others
#
# We generalize SE and Acc. probes to Out-of-Distribution settings (OOD).

# %%
# Train on one's Acc/SE and test on others' Acc
def test_one_on_n(D, token_type='slt', 
                  layer_range1=list(range(e1,e2)), 
                  layer_range2=list(range(a1,a2))):
    var_name = token_type[0]
    other_ids = D.other_ids
    other_names = D.other_names
    metric = 'accuracies'
    a_model = getattr(D, f'{var_name}_amodel')  # Acc. Probe
    b_model = getattr(D, f'{var_name}_bmodel')  # SE Probe

    print(f"Using probes trained on datasets {D.name.upper()}'s {token_type.upper()}-SE/Acc to predict {other_names}'s {token_type.upper()}-Acc")

    oa_accs = {}
    oa_aucs = {}
    ob_accs = {}
    ob_aucs = {}
    
    for id_ in D.other_ids:
        D_id = Ds[id_]
        print(f"Testing on {D_id.name.upper()}'s {token_type.upper()}-{metric.upper()}")
        if metric == 'accuracies':
            y_metric = 1 - getattr(D_id, metric)  # error rate
        else:
            y_metric = getattr(D_id, metric)
        
        ida_accs = []
        ida_aucs = []
        idb_accs = []
        idb_aucs = []

        # create test sets with accuracy labels
        all_Xs_and_ys = create_Xs_and_ys(getattr(D_id, f'{token_type}_dataset'), y_metric, test_only=True)

        # test on Acc. Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range2, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(a_model, X_test_cc, 1-y_test_cc, bootstrap=True)
        ida_accs.append(test_acc)
        ida_aucs.append(test_auc)
        
        # test on SE Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range1, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(b_model, X_test_cc, y_test_cc, bootstrap=True)
        idb_accs.append(test_acc)
        idb_aucs.append(test_auc)

        oa_accs[D_id.name] = ida_accs
        oa_aucs[D_id.name] = ida_aucs
        ob_accs[D_id.name] = idb_accs
        ob_aucs[D_id.name] = idb_aucs

    setattr(D, 'osa_accs', oa_accs) # o means OOD
    setattr(D, 'osa_aucs', oa_aucs)
    setattr(D, 'osb_accs', ob_accs)
    setattr(D, 'osb_aucs', ob_aucs)

    print(f"Using probes trained on dataset {D.name.upper()} testing complete.")

# %%
for D in Ds:
    test_one_on_n(D, 'slt')
# Out:
# Using probes trained on datasets SQUAD-GOLDEN's SLT-SE/Acc to predict ['triviaqa-golden']'s SLT-Acc
# Testing on TRIVIAQA-GOLDEN's SLT-ACCURACIES
# Test Loss: 1.0636, Test Accuracy: 0.8320, AUROC: 0.7632
# Test Loss: 1.1065, Test Accuracy: 0.8265, AUROC: 0.7349
# Using probes trained on dataset SQUAD-GOLDEN testing complete.
# Using probes trained on datasets TRIVIAQA-GOLDEN's SLT-SE/Acc to predict ['squad-golden']'s SLT-Acc
# Testing on SQUAD-GOLDEN's SLT-ACCURACIES
# Test Loss: 1.0064, Test Accuracy: 0.8000, AUROC: 0.6443
# Test Loss: 1.1922, Test Accuracy: 0.8235, AUROC: 0.6433
# Using probes trained on dataset TRIVIAQA-GOLDEN testing complete.

# %%
# compute the OOD average: mean([train on B-> test on A, train on C -> test on A, train on D-> test on A])
b_performances = defaultdict(list)
a_performances = defaultdict(list)
win_rate = []
for D in Ds:
    for name in D.other_names:
        b_performances[name].append(auc(D.osb_aucs[name]))
        a_performances[name].append(auc(D.osa_aucs[name]))
        if auc(D.osb_aucs[name]) > auc(D.osa_aucs[name]):
            win_rate.append(1)
        else:
            win_rate.append(0)

print(f"winning rate: {np.mean(win_rate)*100:.2f}%")

for D in Ds:
    D.sep_ood_avg = np.mean(b_performances[D.name])
    D.ap_ood_avg = np.mean(a_performances[D.name])
    print(f"Average performance on {D.name}: SE Probe - {D.sep_ood_avg}, Acc Probe - {D.ap_ood_avg}")
# Out:
# winning rate: 0.00%
# Average performance on squad-golden: SE Probe - 0.6432947599057299, Acc Probe - 0.6442567940786567
# Average performance on triviaqa-golden: SE Probe - 0.7349267156649635, Acc Probe - 0.7632260451350352

# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("End time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# 记录结束时间
end = time()
# 计算时间间隔，按照小时：分钟：秒的格式输出
elapsed_seconds = end - start
elapsed_hours = int(elapsed_seconds // 3600)
elapsed_minutes = int((elapsed_seconds % 3600) // 60)
elapsed_seconds = int(elapsed_seconds % 60)
print(f"Time elapsed: {elapsed_hours:02d}:{elapsed_minutes:02d}:{elapsed_seconds:02d}")
# Out:
# End time: 2024-12-10 18:19:12
# Time elapsed: 00:07:34
