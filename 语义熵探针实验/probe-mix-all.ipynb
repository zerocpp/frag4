# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("Start time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# 记录开始时间
from time import time
start = time()
# Out:
# Start time: 2024-12-11 16:13:15

# %% [markdown]
# # 合并golden、irrelevant、without三种数据一起训练探针
# 各取全部(2k)

# %%
# 全局变量
# 图片保存文件夹路径
FIG_DIR = "output/data/figures/mix-all"
# 模型层数
NUMBER_OF_LAYERS = 28 # Qwen2.5-7B共有28层

# %%
# %load_ext autoreload
# %autoreload 2

import json
import warnings
import os
import pickle
from tqdm import tqdm
import torch
from collections import defaultdict, Counter
import argparse
from core.models.entailment import EntailmentDeberta
from core.data.data_utils import load_ds_from_json
import numpy as np
import pandas as pd
import scipy
from matplotlib import pyplot as plt
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score, mean_squared_error
from sklearn.model_selection import train_test_split

warnings.filterwarnings("ignore")
plt.rcParams.update({'font.size': 12})
rng = np.random.default_rng(42)


def load_pickle_file(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

def save_pickle_file(file_path, data):
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

# %%
# Create Dataset class for easier attribute keeping
class Dataset:
    name = ''
    tbg_dataset = None
    slt_dataset = None
    entropy = None
    accuracies = None

    sample_type = ''
    model_name = ''
    dataset_name = ''
    split = ''
    def __init__(self, name, tbg_dataset, slt_dataset, entropy, accuracies, sample_type, model_name, dataset_name, split):
        self.name = name
        self.tbg_dataset = tbg_dataset
        self.slt_dataset = slt_dataset
        self.entropy = entropy
        self.accuracies = accuracies
        self.sample_type = sample_type
        self.model_name = model_name
        self.dataset_name = dataset_name
        self.split = split

all_data = load_pickle_file("output/data/all_data.pkl")


model_name = "Qwen/Qwen2.5-7B-Instruct"
dataset_names = ["squad", "triviaqa"]
split = "train"
sample_types = ['golden', 'irrelevant', 'without']

Ds = []
for dataset_name in dataset_names:
    Ds_sample_types = [] # 区分不同sample_types
    for sample_type in sample_types:
        Ds_sample_types.append(all_data[model_name][dataset_name][split][sample_type])
    tbg_datasets = [] # torch.Size([29, 2000, 3584])
    slt_datasets = [] # torch.Size([29, 2000, 3584])
    entropies = [] # torch.Size([2000])
    accuracies = [] # torch.Size([2000])
    
    # 合并不同sample_types
    for ds in Ds_sample_types:
        # 获取样本数量
        sample_size = ds.entropy.size(0)
        # 取全部样本
        tbg_datasets.append(ds.tbg_dataset[:, :sample_size//1, :])
        slt_datasets.append(ds.slt_dataset[:, :sample_size//1, :])
        entropies.append(ds.entropy[:sample_size//1])
        accuracies.append(ds.accuracies[:sample_size//1])

    tbg_dataset = torch.cat(tbg_datasets, dim=1)
    slt_dataset = torch.cat(slt_datasets, dim=1)
    entropy = torch.cat(entropies, dim=0)
    accuracy = torch.cat(accuracies, dim=0)
    ds = Dataset(name=dataset_name, 
                 tbg_dataset=tbg_dataset, 
                 slt_dataset=slt_dataset, 
                 entropy=entropy, 
                 accuracies=accuracy, 
                 sample_type="all", 
                 model_name=model_name, 
                 dataset_name=dataset_name, 
                 split=split)
    Ds.append(ds)

for i, D in enumerate(Ds):
    # OOD-related
    D.other_ids = [j for j in range(len(Ds)) if j != i]
    D.other_names = [Ds[j].name for j in D.other_ids]

# 打印数据集信息
for ds in Ds:
    print(f"{ds.model_name} {ds.dataset_name} {ds.split}: {len(ds.accuracies)}")
# Out:
# Qwen/Qwen2.5-7B-Instruct squad train: 6000
# Qwen/Qwen2.5-7B-Instruct triviaqa train: 5999

# %% [markdown]
# ### Helper Methods

# %%
# Create train/val/test splits
def create_Xs_and_ys(datasets, scores, val_test_splits=[0.2, 0.1], test_only=False, no_val=False):
    # Data splitting for sklearn linear models
    X = np.array(datasets)
    y = np.array(scores)

    if test_only:
        X_tests, y_tests = [], []
        
        for i in range(X.shape[0]):
            X_tests.append(X[i])
            y_tests.append(y)
        return (None, None, X_tests, None, None, y_tests)
    
    valid_size = val_test_splits[0]
    test_size = val_test_splits[1]

    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = [], [], [], [], [], []

    for i in range(X.shape[0]):
        # Split data into train, validation, and test sets
        X_train_val, X_test, y_train_val, y_test = train_test_split(X[i], y, test_size=test_size, random_state=42)
        X_tests.append(X_test)
        y_tests.append(y_test)
        if no_val:
            X_trains.append(X_train_val)
            y_trains.append(y_train_val)
            continue
        X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=valid_size, random_state=42) 
        X_trains.append(X_train)
        y_trains.append(y_train)
        X_vals.append(X_val)
        y_vals.append(y_val)

    return X_trains, X_vals, X_tests, y_trains, y_vals, y_tests

# %%
'''
这段代码的变量生命周期有些混乱，需要注意，例如rng是全局变量；
bootstrap_func和auroc方法会被调用，而bootstrap和compatible_bootstrap是内部方法，不会被外部调用
'''

# Bootstrapping methods from ../semantic_entropy/uncertainty/utils/eval_utils.py
def bootstrap_func(y_true, y_score, func):
    y_tuple = (y_true, y_score)
    
    metric_i = func(*y_tuple)
    metric_dict = {}
    metric_dict['mean'] = metric_i
    metric_dict['bootstrap'] = compatible_bootstrap(
        func, rng)(*y_tuple)  # a bit slow to run
    # 这里的rng是全局变量
    # note that the rng is a global variable
    return metric_dict

def bootstrap(function, rng, n_resamples=1000):
    def inner(data):
        bs = scipy.stats.bootstrap(
            (data, ), function, n_resamples=n_resamples, confidence_level=0.9,
            random_state=rng)
        return {
            'std_err': bs.standard_error,
            'low': bs.confidence_interval.low,
            'high': bs.confidence_interval.high
        }
    return inner

def auroc(y_true, y_score):
    fpr, tpr, thresholds = metrics.roc_curve(y_true, y_score)
    del thresholds
    return metrics.auc(fpr, tpr)

def compatible_bootstrap(func, rng):
    def helper(y_true_y_score):
        # this function is called in the bootstrap
        y_true = np.array([i['y_true'] for i in y_true_y_score])
        y_score = np.array([i['y_score'] for i in y_true_y_score])
        out = func(y_true, y_score)
        return out

    def wrap_inputs(y_true, y_score):
        return [{'y_true': i, 'y_score': j} for i, j in zip(y_true, y_score)]

    def converted_func(y_true, y_score):
        y_true_y_score = wrap_inputs(y_true, y_score)
        return bootstrap(helper, rng=rng)(y_true_y_score)
    return converted_func

# %%
# Train and evaluation function.
def sklearn_train_and_evaluate(model, X_train, y_train, X_valid, y_valid, silent=False):
    model.fit(X_train, y_train)
    
    # Calculate training loss and score
    train_probs = model.predict_proba(X_train)
    train_loss = log_loss(y_train, train_probs)

    # Calculate validation loss
    valid_preds = model.predict(X_valid)
    valid_probs = model.predict_proba(X_valid)
    valid_loss = log_loss(y_valid, valid_probs)
    val_accuracy = np.mean((valid_preds == y_valid).astype(int))
    auroc_score = roc_auc_score(y_valid, valid_probs[:,1])
    if not silent:
        print(f"Validation Accuracy: {val_accuracy:.4f}, AUROC: {auroc_score:.4f}")
        print(f"Training Loss: {train_loss:.4f}, Validation Loss: {valid_loss:.4f}")

def sklearn_evaluate_on_test(model, X_test, y_test, silent=False, bootstrap=True):
    test_preds = model.predict(X_test)
    test_probs = model.predict_proba(X_test)
    test_loss = log_loss(y_test, test_probs)
    test_accuracy = np.mean((test_preds == y_test).astype(int))
    
    if bootstrap:
        auroc_score = bootstrap_func(y_test, test_probs[:,1], auroc)
        auroc_score_scalar = auroc_score['mean']
    else:
        auroc_score = auroc_score_scalar = roc_auc_score(y_test, test_probs[:, 1])
    
    if not silent:
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, AUROC: {auroc_score_scalar:.4f}")
    
    return test_loss, test_accuracy, auroc_score

def train_single_metric(D, token_type='tbg', metric='b_entropy'):
    """train and test on single metric (e.g. SE, Acc) on single dataset"""
    var_name = token_type[0] + metric[0] 
    # named as [te, se. ta, sa] for easy identification; t for tbg, s for slt (token positions)
    # e for entropy and a for accuracy (or model faithfulness)
    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = create_Xs_and_ys(
        getattr(D, f'{token_type}_dataset'), getattr(D, metric)
    )

    accs = []
    aucs = []
    models = []
    
    for i, (X_train, X_val, X_test, y_train, y_val, y_test) in enumerate(zip(X_trains, X_vals, X_tests, y_trains, y_vals, y_tests)):
        print(f"Training on {D.name}-{token_type.upper()}-{metric.upper()} {i+1}/{len(X_trains)}")
        model = LogisticRegression()
        sklearn_train_and_evaluate(model, X_train, y_train, X_val, y_val)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        accs.append(test_acc)
        aucs.append(test_auc)
        models.append(model)

    setattr(D, f'{var_name}_accs', accs)
    setattr(D, f'{var_name}_aucs', aucs)
    setattr(D, f'{var_name}_models', models)

# simple get-around for unpacking bootstrapping dicts
auc = lambda aucs : [ac['mean'] for ac in aucs] 
idf = lambda x : x  # identical function

# %%
# Plotting methods
def plot_metrics_ax(ax, test_metrics_list, model_names, title="", prep_func=auc, 
                    use_logarithm=False, preset_layer_indices=None, legend_outside=False):  # some simple gadgets
    """plot metrics along certain axis in a multi-axis plot (plt.subplots)"""
    if len(test_metrics_list) != len(model_names):
        raise ValueError("The length of test_metrics_list and model_names must be the same.")
    
    for test_metrics, model_name in zip(test_metrics_list, model_names):
        test_metrics = torch.tensor(prep_func(test_metrics), dtype=torch.float32)
        if use_logarithm:
            test_metrics = torch.log(test_metrics + 1e-6)
        if preset_layer_indices is not None:
            layer_indices = preset_layer_indices
        else:
            layer_indices = torch.arange(len(test_metrics)) + 1  # +1 if layer indexing starts at 1
        
        ax.plot(layer_indices, test_metrics, marker='o', linestyle='-', linewidth=2, markersize=5, label=model_name)
    
    ax.set_title(f'{title}', fontsize=14)
    ax.set_xlabel('Layer', fontsize=12)
    ax.set_ylabel(f'Test AUROC scores', fontsize=12)
    
    tick_interval = 5  # Change this value to display more or fewer ticks
    ax.set_xticks(layer_indices[::tick_interval].tolist())
    ax.set_xticklabels(layer_indices[::tick_interval].tolist())
    
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    
    if legend_outside:
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12)
    else:
        ax.legend(fontsize=12)

def save_fig(name):
    """save figure with timestamps"""
    dir_path = os.path.expanduser(FIG_DIR)
    os.makedirs(dir_path, exist_ok=True)
    full_path = os.path.join(dir_path, f'{name}.pdf')
    plt.savefig(full_path, format='pdf', dpi=300)

# %%
# Best split for SE binarization.
def best_split(entropy: torch.Tensor, label="Dx"):
    """
    Identify best split for minimizing reconstruction error via low and high SE mean estimates,
    as discussed in Section 4. Binarization of paper (ArXiv: 2406.15927)
    """
    ents = entropy.numpy()
    splits = np.linspace(1e-10, ents.max(), 100)
    split_mses = []
    for split in splits:
        low_idxs, high_idxs = ents < split, ents >= split
    
        low_mean = np.mean(ents[low_idxs])
        high_mean = np.mean(ents[high_idxs])
    
        mse = np.sum((ents[low_idxs] - low_mean)**2) + np.sum((ents[high_idxs] - high_mean)**2)
        mse = np.sum(mse)
    
        split_mses.append(mse)
    
    split_mses = np.array(split_mses)
    
    plt.plot(splits, split_mses, label=label)
    return splits[np.argmin(split_mses)]

def binarize_entropy(entropy, thres=0.0):  # 0.0 means even splits for normalized entropy scores
    """Binarize entropy scores into 0s and 1s"""
    binary_entropy = torch.full_like(entropy, -1, dtype=torch.float)
    binary_entropy[entropy < thres] = 0
    binary_entropy[entropy > thres] = 1
    binary_entropy[entropy == thres] = 0  # fix by song: 或者根据需求设置为 1

    return binary_entropy

# %% [markdown]
# ### 二值化语义熵

# %%
# Best universal split across datasets
split_method = 'best-universal-split'
all_entropy = torch.cat([D.entropy for D in Ds], dim=0)
split = best_split(all_entropy, "All datasets collective")
plt.legend()
plt.title('Sum of squared errors at different splits')
for D in Ds:
    D.b_entropy = binarize_entropy(D.entropy, split)
    print(f"Dummy accuracy for {D.name}: {max(torch.mean(D.b_entropy).item(), 1-torch.mean(D.b_entropy).item()):.4f}")
# Out:
# Dummy accuracy for squad: 0.6165
# Dummy accuracy for triviaqa: 0.6636

# %% [markdown]
# ### Train linear probes to predict Binarized SE

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'b_entropy')
    train_single_metric(D, 'slt', 'b_entropy')
# Out:
# Training on squad-TBG-B_ENTROPY 1/29
# Validation Accuracy: 0.6463, AUROC: 0.5000
# Training Loss: 0.6717, Validation Loss: 0.6536
# Test Loss: 0.6486, Test Accuracy: 0.6583, AUROC: 0.5000
# Training on squad-TBG-B_ENTROPY 2/29
# Validation Accuracy: 0.6352, AUROC: 0.5850
# Training Loss: 0.6037, Validation Loss: 0.6447
# Test Loss: 0.6396, Test Accuracy: 0.6283, AUROC: 0.5925
# Training on squad-TBG-B_ENTROPY 3/29
# Validation Accuracy: 0.6889, AUROC: 0.7384
# Training Loss: 0.4851, Validation Loss: 0.5666
# Test Loss: 0.5665, Test Accuracy: 0.6583, AUROC: 0.7239
# Training on squad-TBG-B_ENTROPY 4/29
# Validation Accuracy: 0.6750, AUROC: 0.7289
# Training Loss: 0.4812, Validation Loss: 0.5932
# Test Loss: 0.5741, Test Accuracy: 0.6733, AUROC: 0.7303
# Training on squad-TBG-B_ENTROPY 5/29
# Validation Accuracy: 0.6935, AUROC: 0.7620
# Training Loss: 0.4427, Validation Loss: 0.5614
# Test Loss: 0.5494, Test Accuracy: 0.6833, AUROC: 0.7604
# Training on squad-TBG-B_ENTROPY 6/29
# Validation Accuracy: 0.6954, AUROC: 0.7745
# Training Loss: 0.4174, Validation Loss: 0.5614
# Test Loss: 0.5561, Test Accuracy: 0.6867, AUROC: 0.7743
# Training on squad-TBG-B_ENTROPY 7/29
# Validation Accuracy: 0.7130, AUROC: 0.7808
# Training Loss: 0.3870, Validation Loss: 0.5774
# Test Loss: 0.5720, Test Accuracy: 0.6967, AUROC: 0.7769
# Training on squad-TBG-B_ENTROPY 8/29
# Validation Accuracy: 0.7213, AUROC: 0.7920
# Training Loss: 0.3755, Validation Loss: 0.5646
# Test Loss: 0.5717, Test Accuracy: 0.6933, AUROC: 0.7730
# Training on squad-TBG-B_ENTROPY 9/29
# Validation Accuracy: 0.7120, AUROC: 0.7820
# Training Loss: 0.3364, Validation Loss: 0.6253
# Test Loss: 0.6343, Test Accuracy: 0.6900, AUROC: 0.7645
# Training on squad-TBG-B_ENTROPY 10/29
# Validation Accuracy: 0.6981, AUROC: 0.7705
# Training Loss: 0.3436, Validation Loss: 0.6412
# Test Loss: 0.6555, Test Accuracy: 0.6867, AUROC: 0.7532
# Training on squad-TBG-B_ENTROPY 11/29
# Validation Accuracy: 0.7352, AUROC: 0.7953
# Training Loss: 0.3618, Validation Loss: 0.5946
# Test Loss: 0.6054, Test Accuracy: 0.6983, AUROC: 0.7806
# Training on squad-TBG-B_ENTROPY 12/29
# Validation Accuracy: 0.7204, AUROC: 0.7892
# Training Loss: 0.3625, Validation Loss: 0.6036
# Test Loss: 0.6734, Test Accuracy: 0.6700, AUROC: 0.7562
# Training on squad-TBG-B_ENTROPY 13/29
# Validation Accuracy: 0.7222, AUROC: 0.7846
# Training Loss: 0.3546, Validation Loss: 0.6209
# Test Loss: 0.6588, Test Accuracy: 0.6900, AUROC: 0.7659
# Training on squad-TBG-B_ENTROPY 14/29
# Validation Accuracy: 0.7417, AUROC: 0.7988
# Training Loss: 0.3388, Validation Loss: 0.5871
# Test Loss: 0.6178, Test Accuracy: 0.7150, AUROC: 0.7851
# Training on squad-TBG-B_ENTROPY 15/29
# Validation Accuracy: 0.7324, AUROC: 0.7933
# Training Loss: 0.3236, Validation Loss: 0.6155
# Test Loss: 0.6214, Test Accuracy: 0.7300, AUROC: 0.7887
# Training on squad-TBG-B_ENTROPY 16/29
# Validation Accuracy: 0.7333, AUROC: 0.8003
# Training Loss: 0.3496, Validation Loss: 0.6023
# Test Loss: 0.6501, Test Accuracy: 0.7117, AUROC: 0.7825
# Training on squad-TBG-B_ENTROPY 17/29
# Validation Accuracy: 0.7269, AUROC: 0.8035
# Training Loss: 0.3062, Validation Loss: 0.6029
# Test Loss: 0.6683, Test Accuracy: 0.7100, AUROC: 0.7848
# Training on squad-TBG-B_ENTROPY 18/29
# Validation Accuracy: 0.7343, AUROC: 0.8163
# Training Loss: 0.3174, Validation Loss: 0.5677
# Test Loss: 0.6215, Test Accuracy: 0.7250, AUROC: 0.7927
# Training on squad-TBG-B_ENTROPY 19/29
# Validation Accuracy: 0.7426, AUROC: 0.8245
# Training Loss: 0.2981, Validation Loss: 0.5546
# Test Loss: 0.5712, Test Accuracy: 0.7367, AUROC: 0.8134
# Training on squad-TBG-B_ENTROPY 20/29
# Validation Accuracy: 0.7472, AUROC: 0.8193
# Training Loss: 0.2151, Validation Loss: 0.7747
# Test Loss: 0.8483, Test Accuracy: 0.7300, AUROC: 0.8121
# Training on squad-TBG-B_ENTROPY 21/29
# Validation Accuracy: 0.7352, AUROC: 0.8191
# Training Loss: 0.2037, Validation Loss: 0.8178
# Test Loss: 0.8020, Test Accuracy: 0.7033, AUROC: 0.8092
# Training on squad-TBG-B_ENTROPY 22/29
# Validation Accuracy: 0.7333, AUROC: 0.8125
# Training Loss: 0.1447, Validation Loss: 1.1317
# Test Loss: 1.1765, Test Accuracy: 0.7117, AUROC: 0.7994
# Training on squad-TBG-B_ENTROPY 23/29
# Validation Accuracy: 0.7306, AUROC: 0.7887
# Training Loss: 0.0527, Validation Loss: 2.5514
# Test Loss: 2.5569, Test Accuracy: 0.7100, AUROC: 0.7818
# Training on squad-TBG-B_ENTROPY 24/29
# Validation Accuracy: 0.7324, AUROC: 0.7965
# Training Loss: 0.0218, Validation Loss: 3.1846
# Test Loss: 3.3552, Test Accuracy: 0.7017, AUROC: 0.7733
# Training on squad-TBG-B_ENTROPY 25/29
# Validation Accuracy: 0.7213, AUROC: 0.7861
# Training Loss: 0.0167, Validation Loss: 3.3558
# Test Loss: 3.6694, Test Accuracy: 0.6633, AUROC: 0.7581
# Training on squad-TBG-B_ENTROPY 26/29
# Validation Accuracy: 0.7130, AUROC: 0.7737
# Training Loss: 0.0049, Validation Loss: 4.3294
# Test Loss: 4.4458, Test Accuracy: 0.6950, AUROC: 0.7605
# Training on squad-TBG-B_ENTROPY 27/29
# Validation Accuracy: 0.7296, AUROC: 0.7818
# Training Loss: 0.0036, Validation Loss: 4.1902
# Test Loss: 4.7374, Test Accuracy: 0.6817, AUROC: 0.7509
# Training on squad-TBG-B_ENTROPY 28/29
# Validation Accuracy: 0.7185, AUROC: 0.7794
# Training Loss: 0.0020, Validation Loss: 4.3372
# Test Loss: 4.4643, Test Accuracy: 0.7067, AUROC: 0.7693
# Training on squad-TBG-B_ENTROPY 29/29
# Validation Accuracy: 0.6935, AUROC: 0.7601
# Training Loss: 0.0028, Validation Loss: 4.3527
# Test Loss: 4.5966, Test Accuracy: 0.6850, AUROC: 0.7462
# Training on squad-SLT-B_ENTROPY 1/29
# Validation Accuracy: 0.6676, AUROC: 0.6693
# Training Loss: 0.5762, Validation Loss: 0.6112
# Test Loss: 0.6045, Test Accuracy: 0.6850, AUROC: 0.6790
# Training on squad-SLT-B_ENTROPY 2/29
# Validation Accuracy: 0.6657, AUROC: 0.6841
# Training Loss: 0.2138, Validation Loss: 0.9065
# Test Loss: 0.8221, Test Accuracy: 0.6883, AUROC: 0.7216
# Training on squad-SLT-B_ENTROPY 3/29
# Validation Accuracy: 0.7130, AUROC: 0.7565
# Training Loss: 0.1526, Validation Loss: 0.9229
# Test Loss: 0.9311, Test Accuracy: 0.7150, AUROC: 0.7547
# Training on squad-SLT-B_ENTROPY 4/29
# Validation Accuracy: 0.6713, AUROC: 0.7124
# Training Loss: 0.1163, Validation Loss: 1.2953
# Test Loss: 1.0960, Test Accuracy: 0.7050, AUROC: 0.7513
# Training on squad-SLT-B_ENTROPY 5/29
# Validation Accuracy: 0.6778, AUROC: 0.7150
# Training Loss: 0.0867, Validation Loss: 1.6039
# Test Loss: 1.4153, Test Accuracy: 0.6833, AUROC: 0.7354
# Training on squad-SLT-B_ENTROPY 6/29
# Validation Accuracy: 0.6907, AUROC: 0.7365
# Training Loss: 0.0676, Validation Loss: 1.6009
# Test Loss: 1.6098, Test Accuracy: 0.6967, AUROC: 0.7333
# Training on squad-SLT-B_ENTROPY 7/29
# Validation Accuracy: 0.6944, AUROC: 0.7379
# Training Loss: 0.0545, Validation Loss: 1.8719
# Test Loss: 1.7445, Test Accuracy: 0.6950, AUROC: 0.7386
# Training on squad-SLT-B_ENTROPY 8/29
# Validation Accuracy: 0.6944, AUROC: 0.7471
# Training Loss: 0.0486, Validation Loss: 1.8240
# Test Loss: 1.7908, Test Accuracy: 0.7000, AUROC: 0.7486
# Training on squad-SLT-B_ENTROPY 9/29
# Validation Accuracy: 0.7009, AUROC: 0.7444
# Training Loss: 0.0416, Validation Loss: 1.8814
# Test Loss: 1.7639, Test Accuracy: 0.7217, AUROC: 0.7582
# Training on squad-SLT-B_ENTROPY 10/29
# Validation Accuracy: 0.7130, AUROC: 0.7778
# Training Loss: 0.0348, Validation Loss: 1.9174
# Test Loss: 2.1184, Test Accuracy: 0.7067, AUROC: 0.7459
# Training on squad-SLT-B_ENTROPY 11/29
# Validation Accuracy: 0.7000, AUROC: 0.7597
# Training Loss: 0.0411, Validation Loss: 1.9548
# Test Loss: 2.1950, Test Accuracy: 0.7017, AUROC: 0.7284
# Training on squad-SLT-B_ENTROPY 12/29
# Validation Accuracy: 0.7185, AUROC: 0.7704
# Training Loss: 0.0397, Validation Loss: 1.8861
# Test Loss: 2.0390, Test Accuracy: 0.7067, AUROC: 0.7466
# Training on squad-SLT-B_ENTROPY 13/29
# Validation Accuracy: 0.7093, AUROC: 0.7573
# Training Loss: 0.0296, Validation Loss: 2.0004
# Test Loss: 1.9096, Test Accuracy: 0.7033, AUROC: 0.7560
# Training on squad-SLT-B_ENTROPY 14/29
# Validation Accuracy: 0.7056, AUROC: 0.7630
# Training Loss: 0.0318, Validation Loss: 2.0429
# Test Loss: 1.9895, Test Accuracy: 0.7067, AUROC: 0.7581
# Training on squad-SLT-B_ENTROPY 15/29
# Validation Accuracy: 0.7065, AUROC: 0.7593
# Training Loss: 0.0249, Validation Loss: 2.2661
# Test Loss: 2.3981, Test Accuracy: 0.7000, AUROC: 0.7475
# Training on squad-SLT-B_ENTROPY 16/29
# Validation Accuracy: 0.7065, AUROC: 0.7820
# Training Loss: 0.0252, Validation Loss: 2.0794
# Test Loss: 2.2502, Test Accuracy: 0.7117, AUROC: 0.7711
# Training on squad-SLT-B_ENTROPY 17/29
# Validation Accuracy: 0.7287, AUROC: 0.7858
# Training Loss: 0.0238, Validation Loss: 2.1078
# Test Loss: 2.1280, Test Accuracy: 0.7467, AUROC: 0.7928
# Training on squad-SLT-B_ENTROPY 18/29
# Validation Accuracy: 0.7611, AUROC: 0.8086
# Training Loss: 0.0196, Validation Loss: 1.9612
# Test Loss: 2.1539, Test Accuracy: 0.7300, AUROC: 0.7933
# Training on squad-SLT-B_ENTROPY 19/29
# Validation Accuracy: 0.7306, AUROC: 0.7975
# Training Loss: 0.0148, Validation Loss: 2.0369
# Test Loss: 2.1447, Test Accuracy: 0.7317, AUROC: 0.7965
# Training on squad-SLT-B_ENTROPY 20/29
# Validation Accuracy: 0.7352, AUROC: 0.7999
# Training Loss: 0.0110, Validation Loss: 2.2646
# Test Loss: 2.4975, Test Accuracy: 0.7267, AUROC: 0.7906
# Training on squad-SLT-B_ENTROPY 21/29
# Validation Accuracy: 0.7213, AUROC: 0.7966
# Training Loss: 0.0100, Validation Loss: 2.4233
# Test Loss: 2.2965, Test Accuracy: 0.7533, AUROC: 0.8040
# Training on squad-SLT-B_ENTROPY 22/29
# Validation Accuracy: 0.7222, AUROC: 0.7929
# Training Loss: 0.0071, Validation Loss: 2.8600
# Test Loss: 2.5843, Test Accuracy: 0.7267, AUROC: 0.8060
# Training on squad-SLT-B_ENTROPY 23/29
# Validation Accuracy: 0.7028, AUROC: 0.7783
# Training Loss: 0.0050, Validation Loss: 3.5708
# Test Loss: 3.0795, Test Accuracy: 0.7467, AUROC: 0.7967
# Training on squad-SLT-B_ENTROPY 24/29
# Validation Accuracy: 0.7204, AUROC: 0.7891
# Training Loss: 0.0037, Validation Loss: 3.3903
# Test Loss: 3.2513, Test Accuracy: 0.7417, AUROC: 0.7940
# Training on squad-SLT-B_ENTROPY 25/29
# Validation Accuracy: 0.7361, AUROC: 0.7868
# Training Loss: 0.0034, Validation Loss: 3.2700
# Test Loss: 3.2549, Test Accuracy: 0.7383, AUROC: 0.7918
# Training on squad-SLT-B_ENTROPY 26/29
# Validation Accuracy: 0.7241, AUROC: 0.7885
# Training Loss: 0.0025, Validation Loss: 3.6593
# Test Loss: 3.8072, Test Accuracy: 0.7217, AUROC: 0.7873
# Training on squad-SLT-B_ENTROPY 27/29
# Validation Accuracy: 0.7306, AUROC: 0.7946
# Training Loss: 0.0021, Validation Loss: 4.0710
# Test Loss: 4.5462, Test Accuracy: 0.7267, AUROC: 0.7677
# Training on squad-SLT-B_ENTROPY 28/29
# Validation Accuracy: 0.7454, AUROC: 0.7987
# Training Loss: 0.0018, Validation Loss: 3.8109
# Test Loss: 4.5448, Test Accuracy: 0.7017, AUROC: 0.7607
# Training on squad-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.7250, AUROC: 0.7773
# Training Loss: 0.0023, Validation Loss: 4.1883
# Test Loss: 4.6707, Test Accuracy: 0.6983, AUROC: 0.7504
# Training on triviaqa-TBG-B_ENTROPY 1/29
# Validation Accuracy: 0.6611, AUROC: 0.5000
# Training Loss: 0.6375, Validation Loss: 0.6403
# Test Loss: 0.6434, Test Accuracy: 0.6567, AUROC: 0.5000
# Training on triviaqa-TBG-B_ENTROPY 2/29
# Validation Accuracy: 0.6343, AUROC: 0.6177
# Training Loss: 0.5528, Validation Loss: 0.6254
# Test Loss: 0.6333, Test Accuracy: 0.6417, AUROC: 0.6084
# Training on triviaqa-TBG-B_ENTROPY 3/29
# Validation Accuracy: 0.6620, AUROC: 0.6793
# Training Loss: 0.4765, Validation Loss: 0.6190
# Test Loss: 0.5902, Test Accuracy: 0.6733, AUROC: 0.7120
# Training on triviaqa-TBG-B_ENTROPY 4/29
# Validation Accuracy: 0.6750, AUROC: 0.6890
# Training Loss: 0.4684, Validation Loss: 0.6157
# Test Loss: 0.5884, Test Accuracy: 0.7117, AUROC: 0.7150
# Training on triviaqa-TBG-B_ENTROPY 5/29
# Validation Accuracy: 0.6815, AUROC: 0.7073
# Training Loss: 0.4582, Validation Loss: 0.6221
# Test Loss: 0.6125, Test Accuracy: 0.6750, AUROC: 0.7149
# Training on triviaqa-TBG-B_ENTROPY 6/29
# Validation Accuracy: 0.6824, AUROC: 0.6981
# Training Loss: 0.4227, Validation Loss: 0.6476
# Test Loss: 0.6339, Test Accuracy: 0.6850, AUROC: 0.7088
# Training on triviaqa-TBG-B_ENTROPY 7/29
# Validation Accuracy: 0.6833, AUROC: 0.7081
# Training Loss: 0.3575, Validation Loss: 0.6681
# Test Loss: 0.6877, Test Accuracy: 0.6800, AUROC: 0.7001
# Training on triviaqa-TBG-B_ENTROPY 8/29
# Validation Accuracy: 0.6889, AUROC: 0.7193
# Training Loss: 0.3306, Validation Loss: 0.6713
# Test Loss: 0.6563, Test Accuracy: 0.6883, AUROC: 0.7185
# Training on triviaqa-TBG-B_ENTROPY 9/29
# Validation Accuracy: 0.6796, AUROC: 0.7123
# Training Loss: 0.3450, Validation Loss: 0.6893
# Test Loss: 0.6495, Test Accuracy: 0.7033, AUROC: 0.7204
# Training on triviaqa-TBG-B_ENTROPY 10/29
# Validation Accuracy: 0.6815, AUROC: 0.7179
# Training Loss: 0.3563, Validation Loss: 0.6970
# Test Loss: 0.6473, Test Accuracy: 0.7050, AUROC: 0.7427
# Training on triviaqa-TBG-B_ENTROPY 11/29
# Validation Accuracy: 0.6778, AUROC: 0.7132
# Training Loss: 0.3764, Validation Loss: 0.6631
# Test Loss: 0.6032, Test Accuracy: 0.7233, AUROC: 0.7540
# Training on triviaqa-TBG-B_ENTROPY 12/29
# Validation Accuracy: 0.6843, AUROC: 0.7188
# Training Loss: 0.3437, Validation Loss: 0.7170
# Test Loss: 0.6637, Test Accuracy: 0.7117, AUROC: 0.7479
# Training on triviaqa-TBG-B_ENTROPY 13/29
# Validation Accuracy: 0.6880, AUROC: 0.7349
# Test Loss: 4.0209, Test Accuracy: 0.7317, AUROC: 0.7575
# Training on triviaqa-TBG-B_ENTROPY 27/29
# Validation Accuracy: 0.7037, AUROC: 0.7350
# Training Loss: 0.0058, Validation Loss: 4.9809
# Test Loss: 4.4700, Test Accuracy: 0.7417, AUROC: 0.7537
# Training on triviaqa-TBG-B_ENTROPY 28/29
# Validation Accuracy: 0.7148, AUROC: 0.7398
# Training Loss: 0.0045, Validation Loss: 5.1039
# Test Loss: 5.1685, Test Accuracy: 0.7083, AUROC: 0.7301
# Training on triviaqa-TBG-B_ENTROPY 29/29
# Validation Accuracy: 0.7185, AUROC: 0.7417
# Training Loss: 0.0043, Validation Loss: 4.2149
# Test Loss: 4.4173, Test Accuracy: 0.7017, AUROC: 0.7201
# Training on triviaqa-SLT-B_ENTROPY 1/29
# Validation Accuracy: 0.6843, AUROC: 0.6909
# Training Loss: 0.5158, Validation Loss: 0.5907
# Test Loss: 0.5720, Test Accuracy: 0.7100, AUROC: 0.7203
# Training on triviaqa-SLT-B_ENTROPY 2/29
# Validation Accuracy: 0.6815, AUROC: 0.6986
# Training Loss: 0.1912, Validation Loss: 0.8936
# Test Loss: 0.7767, Test Accuracy: 0.7283, AUROC: 0.7381
# Training on triviaqa-SLT-B_ENTROPY 3/29
# Validation Accuracy: 0.7000, AUROC: 0.7015
# Training Loss: 0.1418, Validation Loss: 1.0701
# Test Loss: 0.9490, Test Accuracy: 0.7250, AUROC: 0.7360
# Training on triviaqa-SLT-B_ENTROPY 4/29
# Validation Accuracy: 0.6694, AUROC: 0.6786
# Training Loss: 0.1099, Validation Loss: 1.3987
# Test Loss: 1.2355, Test Accuracy: 0.7017, AUROC: 0.7128
# Training on triviaqa-SLT-B_ENTROPY 5/29
# Validation Accuracy: 0.6611, AUROC: 0.6573
# Training Loss: 0.0795, Validation Loss: 1.7093
# Test Loss: 1.3302, Test Accuracy: 0.7083, AUROC: 0.7333
# Training on triviaqa-SLT-B_ENTROPY 6/29
# Validation Accuracy: 0.6824, AUROC: 0.6807
# Training Loss: 0.0565, Validation Loss: 1.8911
# Test Loss: 1.5371, Test Accuracy: 0.7000, AUROC: 0.7430
# Training on triviaqa-SLT-B_ENTROPY 7/29
# Validation Accuracy: 0.6759, AUROC: 0.6786
# Training Loss: 0.0486, Validation Loss: 1.9238
# Test Loss: 1.6444, Test Accuracy: 0.7217, AUROC: 0.7278
# Training on triviaqa-SLT-B_ENTROPY 8/29
# Validation Accuracy: 0.6843, AUROC: 0.6913
# Training Loss: 0.0391, Validation Loss: 2.1734
# Test Loss: 1.8762, Test Accuracy: 0.7267, AUROC: 0.7470
# Training on triviaqa-SLT-B_ENTROPY 9/29
# Validation Accuracy: 0.7019, AUROC: 0.7074
# Training Loss: 0.0343, Validation Loss: 1.9974
# Test Loss: 1.7504, Test Accuracy: 0.7417, AUROC: 0.7579
# Training on triviaqa-SLT-B_ENTROPY 10/29
# Validation Accuracy: 0.6972, AUROC: 0.7137
# Training Loss: 0.0269, Validation Loss: 2.1833
# Test Loss: 2.5787, Test Accuracy: 0.7317, AUROC: 0.7846
# Training on triviaqa-SLT-B_ENTROPY 24/29
# Validation Accuracy: 0.7185, AUROC: 0.7681
# Training Loss: 0.0051, Validation Loss: 3.1606
# Test Loss: 2.6745, Test Accuracy: 0.7483, AUROC: 0.7905
# Training on triviaqa-SLT-B_ENTROPY 25/29
# Validation Accuracy: 0.7157, AUROC: 0.7645
# Training Loss: 0.0035, Validation Loss: 3.5949
# Test Loss: 3.1250, Test Accuracy: 0.7383, AUROC: 0.7892
# Training on triviaqa-SLT-B_ENTROPY 26/29
# Validation Accuracy: 0.7157, AUROC: 0.7544
# Training Loss: 0.0031, Validation Loss: 3.9200
# Test Loss: 3.4825, Test Accuracy: 0.7283, AUROC: 0.7894
# Training on triviaqa-SLT-B_ENTROPY 27/29
# Validation Accuracy: 0.7213, AUROC: 0.7628
# Training Loss: 0.0023, Validation Loss: 4.2950
# Test Loss: 4.0381, Test Accuracy: 0.7317, AUROC: 0.7805
# Training on triviaqa-SLT-B_ENTROPY 28/29
# Validation Accuracy: 0.7037, AUROC: 0.7484
# Training Loss: 0.0024, Validation Loss: 4.5633
# Test Loss: 3.7839, Test Accuracy: 0.7467, AUROC: 0.7954
# Training on triviaqa-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.6935, AUROC: 0.7273
# Training Loss: 0.0031, Validation Loss: 4.3522
# Test Loss: 3.5862, Test Accuracy: 0.7350, AUROC: 0.7810

# %%
# plot se probe
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.tb_aucs), auc(D.sb_aucs)], ["SE Probe on TBG token", "SE Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="se_both_tok")
plt.show()

# %% [markdown]
# ### Train linear probes to predict Accuracy

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'accuracies')
    train_single_metric(D, 'slt', 'accuracies')
# Out:
# Training on squad-TBG-ACCURACIES 1/29
# Validation Accuracy: 0.5565, AUROC: 0.5000
# Training Loss: 0.6756, Validation Loss: 0.6895
# Test Loss: 0.6832, Test Accuracy: 0.5733, AUROC: 0.5000
# Training on squad-TBG-ACCURACIES 2/29
# Validation Accuracy: 0.6000, AUROC: 0.6415
# Training Loss: 0.5830, Validation Loss: 0.6598
# Test Loss: 0.6466, Test Accuracy: 0.6300, AUROC: 0.6524
# Training on squad-TBG-ACCURACIES 3/29
# Validation Accuracy: 0.7639, AUROC: 0.8214
# Training Loss: 0.4371, Validation Loss: 0.5100
# Test Loss: 0.5195, Test Accuracy: 0.7633, AUROC: 0.8140
# Training on squad-TBG-ACCURACIES 4/29
# Validation Accuracy: 0.7713, AUROC: 0.8193
# Training Loss: 0.4041, Validation Loss: 0.5104
# Test Loss: 0.5130, Test Accuracy: 0.7733, AUROC: 0.8196
# Training on squad-TBG-ACCURACIES 5/29
# Validation Accuracy: 0.7926, AUROC: 0.8342
# Training Loss: 0.3654, Validation Loss: 0.4908
# Test Loss: 0.4929, Test Accuracy: 0.7917, AUROC: 0.8416
# Training on squad-TBG-ACCURACIES 6/29
# Validation Accuracy: 0.7852, AUROC: 0.8444
# Training Loss: 0.3055, Validation Loss: 0.5002
# Test Loss: 0.4809, Test Accuracy: 0.8117, AUROC: 0.8583
# Training on squad-TBG-ACCURACIES 7/29
# Validation Accuracy: 0.8019, AUROC: 0.8474
# Training Loss: 0.2877, Validation Loss: 0.5085
# Test Loss: 0.4705, Test Accuracy: 0.8100, AUROC: 0.8704
# Training on squad-TBG-ACCURACIES 8/29
# Validation Accuracy: 0.7843, AUROC: 0.8506
# Training Loss: 0.3036, Validation Loss: 0.5061
# Test Loss: 0.4754, Test Accuracy: 0.8050, AUROC: 0.8658
# Training on squad-TBG-ACCURACIES 9/29
# Validation Accuracy: 0.7981, AUROC: 0.8551
# Training Loss: 0.2863, Validation Loss: 0.5032
# Test Loss: 0.4700, Test Accuracy: 0.8083, AUROC: 0.8715
# Training on squad-TBG-ACCURACIES 10/29
# Validation Accuracy: 0.8019, AUROC: 0.8590
# Training Loss: 0.2994, Validation Loss: 0.4937
# Test Loss: 0.4701, Test Accuracy: 0.8000, AUROC: 0.8734
# Training on squad-TBG-ACCURACIES 11/29
# Validation Accuracy: 0.7991, AUROC: 0.8505
# Training Loss: 0.2945, Validation Loss: 0.5348
# Test Loss: 0.5026, Test Accuracy: 0.8217, AUROC: 0.8699
# Training on squad-TBG-ACCURACIES 12/29
# Validation Accuracy: 0.7991, AUROC: 0.8543
# Training Loss: 0.2786, Validation Loss: 0.5147
# Test Loss: 0.4729, Test Accuracy: 0.8383, AUROC: 0.8784
# Training on squad-TBG-ACCURACIES 13/29
# Validation Accuracy: 0.8000, AUROC: 0.8646
# Training Loss: 0.2583, Validation Loss: 0.5087
# Test Loss: 0.5025, Test Accuracy: 0.8150, AUROC: 0.8739
# Training on squad-TBG-ACCURACIES 14/29
# Validation Accuracy: 0.7972, AUROC: 0.8749
# Training Loss: 0.2204, Validation Loss: 0.5015
# Test Loss: 0.5058, Test Accuracy: 0.8200, AUROC: 0.8769
# Training on squad-TBG-ACCURACIES 15/29
# Validation Accuracy: 0.8120, AUROC: 0.8792
# Training Loss: 0.1975, Validation Loss: 0.5488
# Test Loss: 0.5807, Test Accuracy: 0.8150, AUROC: 0.8709
# Training on squad-TBG-ACCURACIES 16/29
# Validation Accuracy: 0.8074, AUROC: 0.8747
# Training Loss: 0.2188, Validation Loss: 0.5248
# Test Loss: 0.5384, Test Accuracy: 0.8033, AUROC: 0.8743
# Training on squad-TBG-ACCURACIES 17/29
# Validation Accuracy: 0.8139, AUROC: 0.8806
# Training Loss: 0.1862, Validation Loss: 0.5453
# Test Loss: 0.5488, Test Accuracy: 0.8100, AUROC: 0.8788
# Training on squad-TBG-ACCURACIES 18/29
# Validation Accuracy: 0.7954, AUROC: 0.8799
# Training Loss: 0.1587, Validation Loss: 0.6361
# Test Loss: 0.5904, Test Accuracy: 0.8250, AUROC: 0.8879
# Training on squad-TBG-ACCURACIES 19/29
# Validation Accuracy: 0.8019, AUROC: 0.8780
# Training Loss: 0.1246, Validation Loss: 0.6893
# Test Loss: 0.6671, Test Accuracy: 0.8133, AUROC: 0.8882
# Training on squad-TBG-ACCURACIES 20/29
# Validation Accuracy: 0.8009, AUROC: 0.8848
# Training Loss: 0.1267, Validation Loss: 0.6254
# Test Loss: 0.5725, Test Accuracy: 0.8167, AUROC: 0.9032
# Training on squad-TBG-ACCURACIES 21/29
# Validation Accuracy: 0.8046, AUROC: 0.8715
# Training Loss: 0.0798, Validation Loss: 0.8898
# Test Loss: 0.8240, Test Accuracy: 0.8200, AUROC: 0.8895
# Training on squad-TBG-ACCURACIES 22/29
# Validation Accuracy: 0.8000, AUROC: 0.8622
# Training Loss: 0.0137, Validation Loss: 1.5181
# Test Loss: 1.3243, Test Accuracy: 0.8250, AUROC: 0.8886
# Training on squad-TBG-ACCURACIES 23/29
# Validation Accuracy: 0.7954, AUROC: 0.8564
# Training Loss: 0.0051, Validation Loss: 1.9339
# Test Loss: 1.8360, Test Accuracy: 0.8217, AUROC: 0.8675
# Training on squad-TBG-ACCURACIES 24/29
# Validation Accuracy: 0.8019, AUROC: 0.8692
# Training Loss: 0.0026, Validation Loss: 1.7890
# Test Loss: 1.6582, Test Accuracy: 0.8300, AUROC: 0.8864
# Training on squad-TBG-ACCURACIES 25/29
# Validation Accuracy: 0.7954, AUROC: 0.8577
# Training Loss: 0.0021, Validation Loss: 1.9259
# Test Loss: 1.6293, Test Accuracy: 0.8267, AUROC: 0.8852
# Training on squad-TBG-ACCURACIES 26/29
# Validation Accuracy: 0.8000, AUROC: 0.8540
# Training Loss: 0.0014, Validation Loss: 2.2379
# Test Loss: 2.1144, Test Accuracy: 0.8300, AUROC: 0.8677
# Training on squad-TBG-ACCURACIES 27/29
# Validation Accuracy: 0.7870, AUROC: 0.8600
# Training Loss: 0.0006, Validation Loss: 2.0073
# Test Loss: 1.8764, Test Accuracy: 0.8233, AUROC: 0.8734
# Training on squad-TBG-ACCURACIES 28/29
# Validation Accuracy: 0.7991, AUROC: 0.8581
# Training Loss: 0.0005, Validation Loss: 2.3520
# Test Loss: 2.0919, Test Accuracy: 0.8267, AUROC: 0.8734
# Training on squad-TBG-ACCURACIES 29/29
# Validation Accuracy: 0.7935, AUROC: 0.8567
# Training Loss: 0.0007, Validation Loss: 2.2418
# Test Loss: 2.0043, Test Accuracy: 0.8167, AUROC: 0.8715
# Training on squad-SLT-ACCURACIES 1/29
# Validation Accuracy: 0.6352, AUROC: 0.7061
# Training Loss: 0.5490, Validation Loss: 0.6142
# Test Loss: 0.6179, Test Accuracy: 0.6300, AUROC: 0.6908
# Training on squad-SLT-ACCURACIES 2/29
# Validation Accuracy: 0.7278, AUROC: 0.7689
# Training Loss: 0.1459, Validation Loss: 0.8402
# Test Loss: 0.8018, Test Accuracy: 0.7083, AUROC: 0.7759
# Training on squad-SLT-ACCURACIES 3/29
# Validation Accuracy: 0.7556, AUROC: 0.8186
# Training Loss: 0.0885, Validation Loss: 0.8588
# Test Loss: 0.8646, Test Accuracy: 0.7517, AUROC: 0.8153
# Training on squad-SLT-ACCURACIES 4/29
# Validation Accuracy: 0.7481, AUROC: 0.8059
# Training Loss: 0.0663, Validation Loss: 1.0148
# Test Loss: 0.9833, Test Accuracy: 0.7483, AUROC: 0.8210
# Training on squad-SLT-ACCURACIES 5/29
# Validation Accuracy: 0.7556, AUROC: 0.8133
# Training Loss: 0.0440, Validation Loss: 1.1837
# Test Loss: 1.1941, Test Accuracy: 0.7433, AUROC: 0.8134
# Training on squad-SLT-ACCURACIES 6/29
# Validation Accuracy: 0.7759, AUROC: 0.8240
# Training Loss: 0.0287, Validation Loss: 1.2467
# Test Loss: 1.3134, Test Accuracy: 0.7700, AUROC: 0.8208
# Training on squad-SLT-ACCURACIES 7/29
# Validation Accuracy: 0.7713, AUROC: 0.8336
# Training Loss: 0.0213, Validation Loss: 1.2533
# Test Loss: 1.4901, Test Accuracy: 0.7733, AUROC: 0.8166
# Training on squad-SLT-ACCURACIES 8/29
# Validation Accuracy: 0.7667, AUROC: 0.8248
# Training Loss: 0.0204, Validation Loss: 1.3667
# Test Loss: 1.5442, Test Accuracy: 0.7633, AUROC: 0.8113
# Training on squad-SLT-ACCURACIES 9/29
# Validation Accuracy: 0.7815, AUROC: 0.8252
# Training Loss: 0.0134, Validation Loss: 1.4838
# Test Loss: 1.7623, Test Accuracy: 0.7483, AUROC: 0.7985
# Training on squad-SLT-ACCURACIES 10/29
# Validation Accuracy: 0.7759, AUROC: 0.8284
# Training Loss: 0.0104, Validation Loss: 1.4280
# Test Loss: 1.3117, Test Accuracy: 0.7950, AUROC: 0.8491
# Training on squad-SLT-ACCURACIES 11/29
# Validation Accuracy: 0.7639, AUROC: 0.8243
# Training Loss: 0.0102, Validation Loss: 1.5092
# Test Loss: 1.3010, Test Accuracy: 0.7717, AUROC: 0.8415
# Training on squad-SLT-ACCURACIES 12/29
# Validation Accuracy: 0.7657, AUROC: 0.8268
# Training Loss: 0.0106, Validation Loss: 1.5525
# Test Loss: 1.2588, Test Accuracy: 0.7900, AUROC: 0.8558
# Training on squad-SLT-ACCURACIES 13/29
# Validation Accuracy: 0.7713, AUROC: 0.8403
# Training Loss: 0.0089, Validation Loss: 1.4434
# Test Loss: 1.3493, Test Accuracy: 0.7983, AUROC: 0.8498
# Training on squad-SLT-ACCURACIES 14/29
# Validation Accuracy: 0.7907, AUROC: 0.8405
# Training Loss: 0.0093, Validation Loss: 1.4040
# Test Loss: 1.1768, Test Accuracy: 0.8017, AUROC: 0.8639
# Training on squad-SLT-ACCURACIES 15/29
# Validation Accuracy: 0.8009, AUROC: 0.8551
# Training Loss: 0.0077, Validation Loss: 1.3458
# Test Loss: 1.1970, Test Accuracy: 0.8117, AUROC: 0.8783
# Training on squad-SLT-ACCURACIES 16/29
# Validation Accuracy: 0.7870, AUROC: 0.8579
# Training Loss: 0.0082, Validation Loss: 1.4521
# Test Loss: 1.2972, Test Accuracy: 0.8250, AUROC: 0.8672
# Training on squad-SLT-ACCURACIES 17/29
# Validation Accuracy: 0.8046, AUROC: 0.8630
# Training Loss: 0.0069, Validation Loss: 1.3845
# Test Loss: 1.4081, Test Accuracy: 0.8033, AUROC: 0.8654
# Training on squad-SLT-ACCURACIES 18/29
# Validation Accuracy: 0.7954, AUROC: 0.8664
# Training Loss: 0.0053, Validation Loss: 1.3289
# Test Loss: 1.3269, Test Accuracy: 0.8183, AUROC: 0.8760
# Training on squad-SLT-ACCURACIES 19/29
# Validation Accuracy: 0.8019, AUROC: 0.8592
# Training Loss: 0.0046, Validation Loss: 1.3980
# Test Loss: 1.3360, Test Accuracy: 0.7967, AUROC: 0.8703
# Training on squad-SLT-ACCURACIES 20/29
# Validation Accuracy: 0.7981, AUROC: 0.8677
# Training Loss: 0.0043, Validation Loss: 1.3240
# Test Loss: 1.4978, Test Accuracy: 0.7867, AUROC: 0.8557
# Training on squad-SLT-ACCURACIES 21/29
# Validation Accuracy: 0.7963, AUROC: 0.8624
# Training Loss: 0.0032, Validation Loss: 1.4826
# Test Loss: 1.5603, Test Accuracy: 0.7750, AUROC: 0.8597
# Training on squad-SLT-ACCURACIES 22/29
# Validation Accuracy: 0.7926, AUROC: 0.8676
# Training Loss: 0.0029, Validation Loss: 1.4986
# Test Loss: 1.8182, Test Accuracy: 0.7783, AUROC: 0.8488
# Training on squad-SLT-ACCURACIES 23/29
# Validation Accuracy: 0.7935, AUROC: 0.8703
# Training Loss: 0.0019, Validation Loss: 1.5889
# Test Loss: 1.5047, Test Accuracy: 0.7917, AUROC: 0.8661
# Training on squad-SLT-ACCURACIES 24/29
# Validation Accuracy: 0.7944, AUROC: 0.8678
# Training Loss: 0.0011, Validation Loss: 1.6936
# Test Loss: 1.7155, Test Accuracy: 0.7817, AUROC: 0.8630
# Training on squad-SLT-ACCURACIES 25/29
# Validation Accuracy: 0.7954, AUROC: 0.8697
# Training Loss: 0.0008, Validation Loss: 1.8044
# Test Loss: 1.8218, Test Accuracy: 0.8050, AUROC: 0.8652
# Training on squad-SLT-ACCURACIES 26/29
# Validation Accuracy: 0.7917, AUROC: 0.8518
# Training Loss: 0.0006, Validation Loss: 2.1576
# Test Loss: 2.3453, Test Accuracy: 0.7700, AUROC: 0.8383
# Training on squad-SLT-ACCURACIES 27/29
# Validation Accuracy: 0.7759, AUROC: 0.8409
# Training Loss: 0.0005, Validation Loss: 2.3250
# Test Loss: 2.1688, Test Accuracy: 0.7800, AUROC: 0.8566
# Training on squad-SLT-ACCURACIES 28/29
# Validation Accuracy: 0.7750, AUROC: 0.8426
# Training Loss: 0.0004, Validation Loss: 2.4116
# Test Loss: 2.4086, Test Accuracy: 0.7933, AUROC: 0.8471
# Training on squad-SLT-ACCURACIES 29/29
# Validation Accuracy: 0.7611, AUROC: 0.8298
# Training Loss: 0.0005, Validation Loss: 2.2528
# Test Loss: 2.0291, Test Accuracy: 0.7483, AUROC: 0.8461
# Training on triviaqa-TBG-ACCURACIES 1/29
# Validation Accuracy: 0.6269, AUROC: 0.5000
# Training Loss: 0.6652, Validation Loss: 0.6608
# Test Loss: 0.6601, Test Accuracy: 0.6283, AUROC: 0.5000
# Training on triviaqa-TBG-ACCURACIES 2/29
# Validation Accuracy: 0.6593, AUROC: 0.6595
# Validation Accuracy: 0.7731, AUROC: 0.8214
# Training Loss: 0.0010, Validation Loss: 2.4325
# Test Loss: 2.6174, Test Accuracy: 0.7700, AUROC: 0.8125
# Training on triviaqa-SLT-ACCURACIES 27/29
# Validation Accuracy: 0.7778, AUROC: 0.8263
# Training Loss: 0.0005, Validation Loss: 2.3079
# Test Loss: 2.7211, Test Accuracy: 0.7467, AUROC: 0.8036
# Training on triviaqa-SLT-ACCURACIES 28/29
# Validation Accuracy: 0.7620, AUROC: 0.8102
# Training Loss: 0.0005, Validation Loss: 2.7213
# Test Loss: 2.6953, Test Accuracy: 0.7550, AUROC: 0.8124
# Training on triviaqa-SLT-ACCURACIES 29/29
# Validation Accuracy: 0.7509, AUROC: 0.7862
# Training Loss: 0.0008, Validation Loss: 3.0100
# Test Loss: 2.6801, Test Accuracy: 0.7383, AUROC: 0.7967

# %%
# plot acc probe
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.ta_aucs), auc(D.sa_aucs)], ["Acc Probe on TBG token", "Acc Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="acc_both_tok")
plt.show()

# %% [markdown]
# ### Use linear probe trained on Binarized SE to predict Accuracy
#
# We leverage trained probes on semantic entropy to predict model correctness on the same dataset.
#
# Note that we need to predict the error rate (1 minus accuracy) using SEPs due to the nature of semantic uncertainty.

# %%
for D in Ds:
    r_acc = 1 - D.accuracies
    
    # TBG
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.tbg_dataset, r_acc) 
    tab_accs = []
    tab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-TBG {i+1}/{len(X_tests)}")
        model = D.tb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        tab_accs.append(test_acc)
        tab_aucs.append(test_auc)

    D.tab_accs = tab_accs
    D.tab_aucs = tab_aucs

    # SLT t
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.slt_dataset, r_acc)     
    sab_accs = []
    sab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-SLT {i+1}/{len(X_tests)}")
        model = D.sb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        sab_accs.append(test_acc)
        sab_aucs.append(test_auc)

    D.sab_accs = sab_accs
    D.sab_aucs = sab_aucs
# Out:
# Testing on squad-TBG 1/29
# Test Loss: 0.7457, Test Accuracy: 0.4267, AUROC: 0.5000
# Testing on squad-TBG 2/29
# Test Loss: 0.7288, Test Accuracy: 0.5233, AUROC: 0.6311
# Testing on squad-TBG 3/29
# Test Loss: 0.6515, Test Accuracy: 0.6367, AUROC: 0.7873
# Testing on squad-TBG 4/29
# Test Loss: 0.6733, Test Accuracy: 0.6383, AUROC: 0.7923
# Testing on squad-TBG 5/29
# Test Loss: 0.6498, Test Accuracy: 0.6550, AUROC: 0.8134
# Testing on squad-TBG 6/29
# Test Loss: 0.6447, Test Accuracy: 0.6983, AUROC: 0.8424
# Testing on squad-TBG 7/29
# Test Loss: 0.6508, Test Accuracy: 0.6950, AUROC: 0.8492
# Testing on squad-TBG 8/29
# Test Loss: 0.6625, Test Accuracy: 0.7083, AUROC: 0.8450
# Testing on squad-TBG 9/29
# Test Loss: 0.7259, Test Accuracy: 0.7117, AUROC: 0.8345
# Testing on squad-TBG 10/29
# Test Loss: 0.7488, Test Accuracy: 0.6717, AUROC: 0.8195
# Testing on squad-TBG 11/29
# Test Loss: 0.7003, Test Accuracy: 0.6733, AUROC: 0.8385
# Testing on squad-TBG 12/29
# Test Loss: 0.7299, Test Accuracy: 0.6750, AUROC: 0.8264
# Testing on squad-TBG 13/29
# Test Loss: 0.7668, Test Accuracy: 0.6717, AUROC: 0.8175
# Testing on squad-TBG 14/29
# Test Loss: 0.7253, Test Accuracy: 0.6933, AUROC: 0.8381
# Testing on squad-TBG 15/29
# Test Loss: 0.7806, Test Accuracy: 0.6783, AUROC: 0.8264
# Testing on squad-TBG 16/29
# Test Loss: 0.7807, Test Accuracy: 0.6700, AUROC: 0.8331
# Testing on squad-TBG 17/29
# Test Loss: 0.8202, Test Accuracy: 0.6950, AUROC: 0.8351
# Testing on squad-TBG 18/29
# Test Loss: 0.7713, Test Accuracy: 0.6933, AUROC: 0.8447
# Testing on squad-TBG 19/29
# Test Loss: 0.7510, Test Accuracy: 0.6917, AUROC: 0.8564
# Testing on squad-TBG 20/29
# Test Loss: 1.2589, Test Accuracy: 0.6650, AUROC: 0.8408
# Testing on squad-TBG 21/29
# Test Loss: 1.2229, Test Accuracy: 0.6950, AUROC: 0.8435
# Testing on squad-TBG 22/29
# Test Loss: 1.5751, Test Accuracy: 0.7067, AUROC: 0.8528
# Testing on squad-TBG 23/29
# Test Loss: 3.3912, Test Accuracy: 0.6817, AUROC: 0.8202
# Testing on squad-TBG 24/29
# Test Loss: 4.4948, Test Accuracy: 0.6500, AUROC: 0.8069
# Testing on squad-TBG 25/29
# Test Loss: 4.4927, Test Accuracy: 0.6583, AUROC: 0.8022
# Testing on squad-TBG 26/29
# Test Loss: 5.4139, Test Accuracy: 0.6667, AUROC: 0.8082
# Testing on squad-TBG 27/29
# Test Loss: 5.7201, Test Accuracy: 0.6733, AUROC: 0.7962
# Testing on squad-TBG 28/29
# Test Loss: 5.8509, Test Accuracy: 0.6617, AUROC: 0.7969
# Testing on squad-TBG 29/29
# Test Loss: 5.2419, Test Accuracy: 0.6767, AUROC: 0.8049
# Testing on squad-SLT 1/29
# Test Loss: 0.6978, Test Accuracy: 0.5833, AUROC: 0.6902
# Testing on squad-SLT 2/29
# Test Loss: 1.1140, Test Accuracy: 0.6133, AUROC: 0.7125
# Testing on squad-SLT 3/29
# Test Loss: 1.1523, Test Accuracy: 0.6700, AUROC: 0.7784
# Testing on squad-SLT 4/29
# Test Loss: 1.4254, Test Accuracy: 0.6633, AUROC: 0.7704
# Testing on squad-SLT 5/29
# Test Loss: 1.6981, Test Accuracy: 0.6683, AUROC: 0.7700
# Testing on squad-SLT 6/29
# Test Loss: 1.8597, Test Accuracy: 0.6750, AUROC: 0.7762
# Testing on squad-SLT 7/29
# Test Loss: 2.1124, Test Accuracy: 0.6567, AUROC: 0.7716
# Testing on squad-SLT 8/29
# Test Loss: 2.4934, Test Accuracy: 0.6517, AUROC: 0.7447
# Testing on squad-SLT 9/29
# Test Loss: 2.6057, Test Accuracy: 0.6633, AUROC: 0.7609
# Testing on squad-SLT 10/29
# Test Loss: 2.8754, Test Accuracy: 0.6617, AUROC: 0.7631
# Testing on squad-SLT 11/29
# Test Loss: 2.7862, Test Accuracy: 0.6500, AUROC: 0.7623
# Testing on squad-SLT 12/29
# Test Loss: 2.9717, Test Accuracy: 0.6517, AUROC: 0.7592
# Testing on squad-SLT 13/29
# Test Loss: 2.6616, Test Accuracy: 0.6550, AUROC: 0.7814
# Testing on squad-SLT 14/29
# Test Loss: 2.3657, Test Accuracy: 0.6683, AUROC: 0.7963
# Testing on squad-SLT 15/29
# Test Loss: 3.0131, Test Accuracy: 0.6583, AUROC: 0.7870
# Testing on squad-SLT 16/29
# Test Loss: 2.9262, Test Accuracy: 0.6800, AUROC: 0.8034
# Testing on squad-SLT 17/29
# Test Loss: 2.8857, Test Accuracy: 0.7183, AUROC: 0.8207
# Testing on squad-SLT 18/29
# Test Loss: 2.9387, Test Accuracy: 0.6917, AUROC: 0.8227
# Testing on squad-SLT 19/29
# Test Loss: 2.8747, Test Accuracy: 0.7067, AUROC: 0.8221
# Testing on squad-SLT 20/29
# Test Loss: 3.3126, Test Accuracy: 0.6983, AUROC: 0.8281
# Testing on squad-SLT 21/29
# Test Loss: 3.3187, Test Accuracy: 0.7017, AUROC: 0.8260
# Testing on squad-SLT 22/29
# Test Loss: 3.3601, Test Accuracy: 0.7083, AUROC: 0.8404
# Testing on squad-SLT 23/29
# Test Loss: 3.9371, Test Accuracy: 0.7017, AUROC: 0.8364
# Testing on squad-SLT 24/29
# Test Loss: 4.1536, Test Accuracy: 0.6933, AUROC: 0.8264
# Testing on squad-SLT 25/29
# Test Loss: 4.3876, Test Accuracy: 0.6733, AUROC: 0.8015
# Testing on squad-SLT 26/29
# Test Loss: 4.7693, Test Accuracy: 0.6933, AUROC: 0.8074
# Testing on squad-SLT 27/29
# Test Loss: 4.9932, Test Accuracy: 0.6983, AUROC: 0.8113
# Testing on squad-SLT 28/29
# Test Loss: 4.8989, Test Accuracy: 0.7000, AUROC: 0.8089
# Testing on squad-SLT 29/29
# Test Loss: 5.1083, Test Accuracy: 0.6967, AUROC: 0.8003
# Testing on triviaqa-TBG 1/29
# Test Loss: 0.6628, Test Accuracy: 0.6283, AUROC: 0.5000
# Testing on triviaqa-TBG 2/29
# Test Loss: 0.6569, Test Accuracy: 0.6267, AUROC: 0.6008
# Testing on triviaqa-TBG 3/29
# Test Loss: 0.6417, Test Accuracy: 0.6383, AUROC: 0.6725
# Testing on triviaqa-TBG 4/29
# Test Loss: 0.6300, Test Accuracy: 0.6733, AUROC: 0.6906
# Testing on triviaqa-TBG 5/29
# Test Loss: 0.6502, Test Accuracy: 0.6733, AUROC: 0.6955
# Testing on triviaqa-TBG 6/29
# Test Loss: 0.6661, Test Accuracy: 0.6800, AUROC: 0.6998
# Testing on triviaqa-TBG 7/29
# Test Loss: 0.7037, Test Accuracy: 0.6983, AUROC: 0.7051
# Testing on triviaqa-TBG 8/29
# Test Loss: 0.6780, Test Accuracy: 0.7100, AUROC: 0.7287
# Testing on triviaqa-TBG 9/29
# Test Loss: 0.6468, Test Accuracy: 0.7017, AUROC: 0.7384
# Testing on triviaqa-TBG 10/29
# Test Loss: 0.6399, Test Accuracy: 0.7000, AUROC: 0.7551
# Testing on triviaqa-TBG 11/29
# Test Loss: 0.6015, Test Accuracy: 0.7450, AUROC: 0.7696
# Testing on triviaqa-TBG 12/29
# Test Loss: 0.6596, Test Accuracy: 0.7133, AUROC: 0.7628
# Testing on triviaqa-TBG 13/29
# Test Loss: 0.6240, Test Accuracy: 0.7383, AUROC: 0.7787
# Testing on triviaqa-TBG 14/29
# Test Loss: 0.6189, Test Accuracy: 0.7367, AUROC: 0.7806
# Testing on triviaqa-TBG 15/29
# Test Loss: 0.6938, Test Accuracy: 0.7267, AUROC: 0.7628
# Testing on triviaqa-TBG 16/29
# Test Loss: 0.6826, Test Accuracy: 0.7117, AUROC: 0.7641
# Testing on triviaqa-TBG 17/29
# Test Loss: 0.6168, Test Accuracy: 0.7283, AUROC: 0.7792
# Testing on triviaqa-TBG 18/29
# Test Loss: 0.6120, Test Accuracy: 0.7350, AUROC: 0.7916
# Testing on triviaqa-TBG 19/29
# Test Loss: 0.6296, Test Accuracy: 0.7383, AUROC: 0.7987
# Testing on triviaqa-TBG 20/29
# Test Loss: 0.8048, Test Accuracy: 0.7367, AUROC: 0.7971
# Testing on triviaqa-TBG 21/29
# Test Loss: 0.8633, Test Accuracy: 0.7200, AUROC: 0.7817
# Testing on triviaqa-TBG 22/29
# Test Loss: 1.7485, Test Accuracy: 0.7200, AUROC: 0.7712
# Testing on triviaqa-TBG 23/29
# Test Loss: 2.2376, Test Accuracy: 0.7050, AUROC: 0.7364
# Testing on triviaqa-TBG 24/29
# Test Loss: 2.9759, Test Accuracy: 0.7233, AUROC: 0.7581
# Testing on triviaqa-TBG 25/29
# Test Loss: 4.2704, Test Accuracy: 0.6817, AUROC: 0.7148
# Testing on triviaqa-TBG 26/29
# Test Loss: 4.7469, Test Accuracy: 0.7200, AUROC: 0.7271
# Testing on triviaqa-TBG 27/29
# Test Loss: 5.5982, Test Accuracy: 0.6933, AUROC: 0.6973
# Testing on triviaqa-TBG 28/29
# Test Loss: 5.5142, Test Accuracy: 0.6900, AUROC: 0.7188
# Testing on triviaqa-TBG 29/29
# Test Loss: 4.5944, Test Accuracy: 0.7100, AUROC: 0.7177
# Testing on triviaqa-SLT 1/29
# Test Loss: 0.6261, Test Accuracy: 0.6683, AUROC: 0.6581
# Testing on triviaqa-SLT 2/29
# Test Loss: 0.9788, Test Accuracy: 0.6767, AUROC: 0.6661
# Testing on triviaqa-SLT 3/29
# Test Loss: 1.1960, Test Accuracy: 0.6667, AUROC: 0.6624
# Testing on triviaqa-SLT 4/29
# Test Loss: 1.5376, Test Accuracy: 0.6667, AUROC: 0.6575
# Testing on triviaqa-SLT 5/29
# Test Loss: 1.7482, Test Accuracy: 0.6800, AUROC: 0.6676
# Testing on triviaqa-SLT 6/29
# Test Loss: 2.2593, Test Accuracy: 0.6517, AUROC: 0.6492
# Testing on triviaqa-SLT 7/29
# Test Loss: 1.9854, Test Accuracy: 0.6900, AUROC: 0.6956
# Testing on triviaqa-SLT 8/29
# Test Loss: 2.2615, Test Accuracy: 0.7017, AUROC: 0.7083
# Testing on triviaqa-SLT 9/29
# Test Loss: 2.0691, Test Accuracy: 0.6967, AUROC: 0.7232
# Testing on triviaqa-SLT 10/29
# Test Loss: 2.2380, Test Accuracy: 0.6917, AUROC: 0.7224
# Testing on triviaqa-SLT 11/29
# Test Loss: 2.1618, Test Accuracy: 0.7050, AUROC: 0.7277
# Testing on triviaqa-SLT 12/29
# Test Loss: 2.1739, Test Accuracy: 0.7083, AUROC: 0.7236
# Testing on triviaqa-SLT 13/29
# Test Loss: 2.1987, Test Accuracy: 0.6917, AUROC: 0.7096
# Testing on triviaqa-SLT 14/29
# Test Loss: 2.2213, Test Accuracy: 0.7000, AUROC: 0.7264
# Testing on triviaqa-SLT 15/29
# Test Loss: 2.2735, Test Accuracy: 0.7250, AUROC: 0.7400
# Testing on triviaqa-SLT 16/29
# Test Loss: 2.0209, Test Accuracy: 0.7450, AUROC: 0.7608
# Testing on triviaqa-SLT 17/29
# Test Loss: 2.4076, Test Accuracy: 0.7317, AUROC: 0.7507
# Testing on triviaqa-SLT 18/29
# Test Loss: 2.1831, Test Accuracy: 0.7367, AUROC: 0.7708
# Testing on triviaqa-SLT 19/29
# Test Loss: 2.4526, Test Accuracy: 0.7350, AUROC: 0.7642
# Testing on triviaqa-SLT 20/29
# Test Loss: 2.5056, Test Accuracy: 0.7250, AUROC: 0.7638
# Testing on triviaqa-SLT 21/29
# Test Loss: 2.6559, Test Accuracy: 0.7317, AUROC: 0.7763
# Testing on triviaqa-SLT 22/29
# Test Loss: 2.6052, Test Accuracy: 0.7167, AUROC: 0.7678
# Testing on triviaqa-SLT 23/29
# Test Loss: 2.9264, Test Accuracy: 0.6900, AUROC: 0.7592
# Testing on triviaqa-SLT 24/29
# Test Loss: 3.1195, Test Accuracy: 0.7067, AUROC: 0.7594
# Testing on triviaqa-SLT 25/29
# Test Loss: 3.8964, Test Accuracy: 0.7067, AUROC: 0.7443
# Testing on triviaqa-SLT 26/29
# Test Loss: 4.4358, Test Accuracy: 0.6833, AUROC: 0.7333
# Testing on triviaqa-SLT 27/29
# Test Loss: 4.8180, Test Accuracy: 0.6833, AUROC: 0.7414
# Testing on triviaqa-SLT 28/29
# Test Loss: 4.6830, Test Accuracy: 0.6917, AUROC: 0.7583
# Testing on triviaqa-SLT 29/29
# Test Loss: 4.3455, Test Accuracy: 0.7033, AUROC: 0.7439

# %%
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [D.sa_aucs, D.sab_aucs], ["LR trained and tested on Acc", "LR trained on SE, tested on Acc"], f"AUROC on {D.name.upper()}'s SLT")
plt.tight_layout()
save_fig(name="se_for_acc_slt")
plt.show()

# %%
# select best layer range (SLT)
def decide_layer_range(Ds, metric='entropy', limit=NUMBER_OF_LAYERS+1): # NOTE: set upperbound to be number of layers+1; e.g. for llama2-70b, it is 81.
    """
    simple logic: use ID average test AUROCs across layers to determine 
    which consecutive range of layers did the best. Do separately
    for SEP and Acc. Pr.
    """
    assert hasattr(Ds[0], 'sab_aucs') and hasattr(Ds[0], 'sa_aucs'), 'previous cells need to be run'
    if 'entropy' in metric:
        aucs = [np.array(auc(D.sab_aucs)) for D in Ds]  # test metrics for ID SEPs
    else:
        aucs = [np.array(auc(D.sa_aucs)) for D in Ds]  # test metrics for ID APs
    best_mean = -np.inf
    best_range = []
    average = lambda a,b : np.mean([np.mean(ac[a:b]) for ac in aucs])

    for i in range(limit):
        for j in range(i+1, limit):
            if j - i < 5: # must be more than 5 layers
                continue
            if average(i, j) > best_mean:
                best_mean = average(i, j)
                best_range = [i, j]

    return best_mean, best_range

emean, (e1, e2) = decide_layer_range(Ds, 'entropy')
amean, (a1, a2) = decide_layer_range(Ds, 'acc')
for D in Ds:
    D.sep_layer_range = (e1, e2)
    D.ap_layer_range = (a1, a2)
print(emean, (e1, e2), amean, (a1, a2))
# Out:
# 0.7984211046744811 (18, 23) 0.8537192632666113 (17, 23)

# %%
# BOOTSTRAP: select [xx-xx] layers for bootstrapping
def concat_Xs_and_ys(layer_range, X_trains, X_vals, X_tests, y_trains, y_vals, y_tests, 
                     no_val=False, test_only=False):
    """
    Concatenate @params{layer_range} hidden state layers on train/val/test sets.

    no_val: no validation (training set only).
    test_only: no train/validation set (test set only).
    """
    if not no_val:
        X_val_cc = np.concatenate(np.array(X_vals)[layer_range], axis=1)
        y_val_cc = y_vals[layer_range[0]]
    else:
        X_val_cc = y_val_cc = None

    if not test_only:
        X_train_cc = np.concatenate(np.array(X_trains)[layer_range], axis=1)
        y_train_cc = y_trains[layer_range[0]]
    else:
        X_train_cc = y_train_cc = None
    
    X_test_cc = np.concatenate(np.array(X_tests)[layer_range], axis=1)
    y_test_cc = y_tests[layer_range[0]]
    
    return X_train_cc, X_val_cc, X_test_cc, y_train_cc, y_val_cc, y_test_cc

def train_concat_SE(D, layer_range):
    """train model on single dataset SE with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_bmodel', model)

        print(f'{token_type.upper()} trained on {D.name} SE finished')
    
def train_concat_Acc(D, layer_range):
    """train model on single dataset Accuracy with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_amodel', model)

        print(f'{token_type.upper()} trained on {D.name} Acc finished')

def train_concat_SE_Acc_test_Acc(D, layer_ranges=[list(range(e1,e2)), list(range(a1,a2))]):
    """ID: train and test SEPs and Acc. Pr. on single dataset with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, no_val=True) 
        
        X_train_cc, _, _, y_train_cc, _, _ = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys, no_val=True)
        ab_accs = []
        ab_aucs = []
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)

        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies) 
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys) # fixed random seed ensures no data leakage
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, 1-y_test_cc) # SEP predicts error rate
        ab_accs.append(test_acc)
        ab_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}b_accs', ab_accs)  # i means IDß
        setattr(D, f'i{var_name}b_aucs', ab_aucs)

        print(f'{D.name.upper()}-{token_type.upper()} trainied on SE and tested on Acc finished')
        aa_accs = []
        aa_aucs = []
        X_train_cc, _, X_test_cc, y_train_cc, _, y_test_cc = concat_Xs_and_ys(layer_ranges[1], *all_Xs_and_ys, no_val=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, y_test_cc)
        aa_accs.append(test_acc)
        aa_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}a_accs', aa_accs)
        setattr(D, f'i{var_name}a_aucs', aa_aucs)
        print(f'{D.name.upper()}-{token_type.upper()} trainied on Acc and tested on Acc finished')

# %%
# ID: train SEPs and Acc. Pr. and test them on Acc. from the same dataset
# import warnings # uncomment to disable convergence warnings
# warnings.filterwarnings('ignore')

for D in Ds:
    train_concat_SE_Acc_test_Acc(D)
# Out:
# Test Loss: 4.4261, Test Accuracy: 0.7083, AUROC: 0.8430
# SQUAD-SLT trainied on SE and tested on Acc finished
# Test Loss: 1.3505, Test Accuracy: 0.8200, AUROC: 0.8819
# SQUAD-SLT trainied on Acc and tested on Acc finished
# Test Loss: 3.0631, Test Accuracy: 0.7383, AUROC: 0.7920
# TRIVIAQA-SLT trainied on SE and tested on Acc finished
# Test Loss: 1.2715, Test Accuracy: 0.8083, AUROC: 0.8721
# TRIVIAQA-SLT trainied on Acc and tested on Acc finished

# %%
# OOD: save model trained on individual datasets for OOD tests
for D in Ds:
    train_concat_SE(D, layer_range=list(range(e1,e2)))
    train_concat_Acc(D, layer_range=list(range(a1,a2)))
# outputs cleared for space concern
# Out:
# SLT trained on squad SE finished
# SLT trained on squad Acc finished
# SLT trained on triviaqa SE finished
# SLT trained on triviaqa Acc finished

# %% [markdown]
# ## Test probes trained with one dataset on others
#
# We generalize SE and Acc. probes to Out-of-Distribution settings (OOD).

# %%
# Train on one's Acc/SE and test on others' Acc
def test_one_on_n(D, token_type='slt', 
                  layer_range1=list(range(e1,e2)), 
                  layer_range2=list(range(a1,a2))):
    var_name = token_type[0]
    other_ids = D.other_ids
    other_names = D.other_names
    metric = 'accuracies'
    a_model = getattr(D, f'{var_name}_amodel')  # Acc. Probe
    b_model = getattr(D, f'{var_name}_bmodel')  # SE Probe

    print(f"Using probes trained on datasets {D.name.upper()}'s {token_type.upper()}-SE/Acc to predict {other_names}'s {token_type.upper()}-Acc")

    oa_accs = {}
    oa_aucs = {}
    ob_accs = {}
    ob_aucs = {}
    
    for id_ in D.other_ids:
        D_id = Ds[id_]
        print(f"Testing on {D_id.name.upper()}'s {token_type.upper()}-{metric.upper()}")
        if metric == 'accuracies':
            y_metric = 1 - getattr(D_id, metric)  # error rate
        else:
            y_metric = getattr(D_id, metric)
        
        ida_accs = []
        ida_aucs = []
        idb_accs = []
        idb_aucs = []

        # create test sets with accuracy labels
        all_Xs_and_ys = create_Xs_and_ys(getattr(D_id, f'{token_type}_dataset'), y_metric, test_only=True)

        # test on Acc. Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range2, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(a_model, X_test_cc, 1-y_test_cc, bootstrap=True)
        ida_accs.append(test_acc)
        ida_aucs.append(test_auc)
        
        # test on SE Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range1, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(b_model, X_test_cc, y_test_cc, bootstrap=True)
        idb_accs.append(test_acc)
        idb_aucs.append(test_auc)

        oa_accs[D_id.name] = ida_accs
        oa_aucs[D_id.name] = ida_aucs
        ob_accs[D_id.name] = idb_accs
        ob_aucs[D_id.name] = idb_aucs

    setattr(D, 'osa_accs', oa_accs) # o means OOD
    setattr(D, 'osa_aucs', oa_aucs)
    setattr(D, 'osb_accs', ob_accs)
    setattr(D, 'osb_aucs', ob_aucs)

    print(f"Using probes trained on dataset {D.name.upper()} testing complete.")

# %%
for D in Ds:
    test_one_on_n(D, 'slt')
# Out:
# Using probes trained on datasets SQUAD's SLT-SE/Acc to predict ['triviaqa']'s SLT-Acc
# Testing on TRIVIAQA's SLT-ACCURACIES
# Test Loss: 2.1088, Test Accuracy: 0.7363, AUROC: 0.8192
# Test Loss: 4.0959, Test Accuracy: 0.7123, AUROC: 0.7736
# Using probes trained on dataset SQUAD testing complete.
# Using probes trained on datasets TRIVIAQA's SLT-SE/Acc to predict ['squad']'s SLT-Acc
# Testing on SQUAD's SLT-ACCURACIES
# Test Loss: 2.2265, Test Accuracy: 0.7478, AUROC: 0.8240
# Test Loss: 4.6974, Test Accuracy: 0.6375, AUROC: 0.7621
# Using probes trained on dataset TRIVIAQA testing complete.

# %%
# compute the OOD average: mean([train on B-> test on A, train on C -> test on A, train on D-> test on A])
b_performances = defaultdict(list)
a_performances = defaultdict(list)
win_rate = []
for D in Ds:
    for name in D.other_names:
        b_performances[name].append(auc(D.osb_aucs[name]))
        a_performances[name].append(auc(D.osa_aucs[name]))
        if auc(D.osb_aucs[name]) > auc(D.osa_aucs[name]):
            win_rate.append(1)
        else:
            win_rate.append(0)

print(f"winning rate: {np.mean(win_rate)*100:.2f}%")

for D in Ds:
    D.sep_ood_avg = np.mean(b_performances[D.name])
    D.ap_ood_avg = np.mean(a_performances[D.name])
    print(f"Average performance on {D.name}: SE Probe - {D.sep_ood_avg}, Acc Probe - {D.ap_ood_avg}")
# Out:
# winning rate: 0.00%
# Average performance on squad: SE Probe - 0.7620929734557654, Acc Probe - 0.8239571875154428
# Average performance on triviaqa: SE Probe - 0.7735712261271218, Acc Probe - 0.8191716713899739

# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("End time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# 记录结束时间
end = time()
# 计算时间间隔，按照小时：分钟：秒的格式输出
elapsed_seconds = end - start
elapsed_hours = int(elapsed_seconds // 3600)
elapsed_minutes = int((elapsed_seconds % 3600) // 60)
elapsed_seconds = int(elapsed_seconds % 60)
print(f"Time elapsed: {elapsed_hours:02d}:{elapsed_minutes:02d}:{elapsed_seconds:02d}")
# Out:
# End time: 2024-12-11 16:25:39
# Time elapsed: 00:12:24
