# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("Start time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# 记录开始时间
from time import time
start = time()
# Out:
# Start time: 2024-12-10 18:12:31

# %% [markdown]
# # without数据单独训练探针

# %%
# 全局变量
# 图片保存文件夹路径
FIG_DIR = "output/data/figures/without"
# 采样类型
SAMPLE_TYPE = "without"
# 模型层数
NUMBER_OF_LAYERS = 28 # Qwen2.5-7B共有28层

# %%
# %load_ext autoreload
# %autoreload 2

import json
import warnings
import os
import pickle
from tqdm import tqdm
import torch
from collections import defaultdict, Counter
import argparse
from core.models.entailment import EntailmentDeberta
from core.data.data_utils import load_ds_from_json
import numpy as np
import pandas as pd
import scipy
from matplotlib import pyplot as plt
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score, mean_squared_error
from sklearn.model_selection import train_test_split

warnings.filterwarnings("ignore")
plt.rcParams.update({'font.size': 12})
rng = np.random.default_rng(42)


def load_pickle_file(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

def save_pickle_file(file_path, data):
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

# %%
# Create Dataset class for easier attribute keeping
class Dataset:
    name = ''
    tbg_dataset = None
    slt_dataset = None
    entropy = None
    accuracies = None

    sample_type = ''
    model_name = ''
    dataset_name = ''
    split = ''
    def __init__(self, name, tbg_dataset, slt_dataset, entropy, accuracies, sample_type, model_name, dataset_name, split):
        self.name = name
        self.tbg_dataset = tbg_dataset
        self.slt_dataset = slt_dataset
        self.entropy = entropy
        self.accuracies = accuracies
        self.sample_type = sample_type
        self.model_name = model_name
        self.dataset_name = dataset_name
        self.split = split

all_data = load_pickle_file("output/data/all_data.pkl")


model_name = "Qwen/Qwen2.5-7B-Instruct"
dataset_names = ["squad", "triviaqa"]
split = "train"
sample_type = SAMPLE_TYPE

Ds = []
for dataset_name in dataset_names:
    ds = all_data[model_name][dataset_name][split][sample_type]
    Ds.append(ds)

for i, D in enumerate(Ds):
    # OOD-related
    D.other_ids = [j for j in range(len(Ds)) if j != i]
    D.other_names = [Ds[j].name for j in D.other_ids]

# 打印数据集信息
for ds in Ds:
    print(f"{ds.model_name} {ds.dataset_name} {ds.split}: {len(ds.accuracies)}")
# Out:
# Qwen/Qwen2.5-7B-Instruct squad train: 2000
# Qwen/Qwen2.5-7B-Instruct triviaqa train: 2000

# %% [markdown]
# ### Helper Methods

# %%
# Create train/val/test splits
def create_Xs_and_ys(datasets, scores, val_test_splits=[0.2, 0.1], test_only=False, no_val=False):
    # Data splitting for sklearn linear models
    X = np.array(datasets)
    y = np.array(scores)

    if test_only:
        X_tests, y_tests = [], []
        
        for i in range(X.shape[0]):
            X_tests.append(X[i])
            y_tests.append(y)
        return (None, None, X_tests, None, None, y_tests)
    
    valid_size = val_test_splits[0]
    test_size = val_test_splits[1]

    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = [], [], [], [], [], []

    for i in range(X.shape[0]):
        # Split data into train, validation, and test sets
        X_train_val, X_test, y_train_val, y_test = train_test_split(X[i], y, test_size=test_size, random_state=42)
        X_tests.append(X_test)
        y_tests.append(y_test)
        if no_val:
            X_trains.append(X_train_val)
            y_trains.append(y_train_val)
            continue
        X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=valid_size, random_state=42) 
        X_trains.append(X_train)
        y_trains.append(y_train)
        X_vals.append(X_val)
        y_vals.append(y_val)

    return X_trains, X_vals, X_tests, y_trains, y_vals, y_tests

# %%
# Bootstrapping methods from ../semantic_entropy/uncertainty/utils/eval_utils.py
def bootstrap_func(y_true, y_score, func):
    y_tuple = (y_true, y_score)
    
    metric_i = func(*y_tuple)
    metric_dict = {}
    metric_dict['mean'] = metric_i
    metric_dict['bootstrap'] = compatible_bootstrap(
        func, rng)(*y_tuple)  # a bit slow to run

    return metric_dict

def bootstrap(function, rng, n_resamples=1000):
    def inner(data):
        bs = scipy.stats.bootstrap(
            (data, ), function, n_resamples=n_resamples, confidence_level=0.9,
            random_state=rng)
        return {
            'std_err': bs.standard_error,
            'low': bs.confidence_interval.low,
            'high': bs.confidence_interval.high
        }
    return inner

def auroc(y_true, y_score):
    fpr, tpr, thresholds = metrics.roc_curve(y_true, y_score)
    del thresholds
    return metrics.auc(fpr, tpr)

def compatible_bootstrap(func, rng):
    def helper(y_true_y_score):
        # this function is called in the bootstrap
        y_true = np.array([i['y_true'] for i in y_true_y_score])
        y_score = np.array([i['y_score'] for i in y_true_y_score])
        out = func(y_true, y_score)
        return out

    def wrap_inputs(y_true, y_score):
        return [{'y_true': i, 'y_score': j} for i, j in zip(y_true, y_score)]

    def converted_func(y_true, y_score):
        y_true_y_score = wrap_inputs(y_true, y_score)
        return bootstrap(helper, rng=rng)(y_true_y_score)
    return converted_func

# %%
# Train and evaluation function.
def sklearn_train_and_evaluate(model, X_train, y_train, X_valid, y_valid, silent=False):
    model.fit(X_train, y_train)
    
    # Calculate training loss and score
    train_probs = model.predict_proba(X_train)
    train_loss = log_loss(y_train, train_probs)

    # Calculate validation loss
    valid_preds = model.predict(X_valid)
    valid_probs = model.predict_proba(X_valid)
    valid_loss = log_loss(y_valid, valid_probs)
    val_accuracy = np.mean((valid_preds == y_valid).astype(int))
    auroc_score = roc_auc_score(y_valid, valid_probs[:,1])
    if not silent:
        print(f"Validation Accuracy: {val_accuracy:.4f}, AUROC: {auroc_score:.4f}")
        print(f"Training Loss: {train_loss:.4f}, Validation Loss: {valid_loss:.4f}")

def sklearn_evaluate_on_test(model, X_test, y_test, silent=False, bootstrap=True):
    test_preds = model.predict(X_test)
    test_probs = model.predict_proba(X_test)
    test_loss = log_loss(y_test, test_probs)
    test_accuracy = np.mean((test_preds == y_test).astype(int))
    
    if bootstrap:
        auroc_score = bootstrap_func(y_test, test_probs[:,1], auroc)
        auroc_score_scalar = auroc_score['mean']
    else:
        auroc_score = auroc_score_scalar = roc_auc_score(y_test, test_probs[:, 1])
    
    if not silent:
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, AUROC: {auroc_score_scalar:.4f}")
    
    return test_loss, test_accuracy, auroc_score

def train_single_metric(D, token_type='tbg', metric='b_entropy'):
    """train and test on single metric (e.g. SE, Acc) on single dataset"""
    var_name = token_type[0] + metric[0] 
    # named as [te, se. ta, sa] for easy identification; t for tbg, s for slt (token positions)
    # e for entropy and a for accuracy (or model faithfulness)
    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = create_Xs_and_ys(
        getattr(D, f'{token_type}_dataset'), getattr(D, metric)
    )

    accs = []
    aucs = []
    models = []
    
    for i, (X_train, X_val, X_test, y_train, y_val, y_test) in enumerate(zip(X_trains, X_vals, X_tests, y_trains, y_vals, y_tests)):
        print(f"Training on {D.name}-{token_type.upper()}-{metric.upper()} {i+1}/{len(X_trains)}")
        model = LogisticRegression()
        sklearn_train_and_evaluate(model, X_train, y_train, X_val, y_val)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        accs.append(test_acc)
        aucs.append(test_auc)
        models.append(model)

    setattr(D, f'{var_name}_accs', accs)
    setattr(D, f'{var_name}_aucs', aucs)
    setattr(D, f'{var_name}_models', models)

# simple get-around for unpacking bootstrapping dicts
auc = lambda aucs : [ac['mean'] for ac in aucs] 
idf = lambda x : x  # identical function

# %%
# Plotting methods
def plot_metrics_ax(ax, test_metrics_list, model_names, title="", prep_func=auc, 
                    use_logarithm=False, preset_layer_indices=None, legend_outside=False):  # some simple gadgets
    """plot metrics along certain axis in a multi-axis plot (plt.subplots)"""
    if len(test_metrics_list) != len(model_names):
        raise ValueError("The length of test_metrics_list and model_names must be the same.")
    
    for test_metrics, model_name in zip(test_metrics_list, model_names):
        test_metrics = torch.tensor(prep_func(test_metrics), dtype=torch.float32)
        if use_logarithm:
            test_metrics = torch.log(test_metrics + 1e-6)
        if preset_layer_indices is not None:
            layer_indices = preset_layer_indices
        else:
            layer_indices = torch.arange(len(test_metrics)) + 1  # +1 if layer indexing starts at 1
        
        ax.plot(layer_indices, test_metrics, marker='o', linestyle='-', linewidth=2, markersize=5, label=model_name)
    
    ax.set_title(f'{title}', fontsize=14)
    ax.set_xlabel('Layer', fontsize=12)
    ax.set_ylabel(f'Test AUROC scores', fontsize=12)
    
    tick_interval = 5  # Change this value to display more or fewer ticks
    ax.set_xticks(layer_indices[::tick_interval].tolist())
    ax.set_xticklabels(layer_indices[::tick_interval].tolist())
    
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    
    if legend_outside:
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12)
    else:
        ax.legend(fontsize=12)

def save_fig(name):
    """save figure with timestamps"""
    dir_path = os.path.expanduser(FIG_DIR)
    os.makedirs(dir_path, exist_ok=True)
    full_path = os.path.join(dir_path, f'{name}.pdf')
    plt.savefig(full_path, format='pdf', dpi=300)

# %%
# Best split for SE binarization.
def best_split(entropy: torch.Tensor, label="Dx"):
    """
    Identify best split for minimizing reconstruction error via low and high SE mean estimates,
    as discussed in Section 4. Binarization of paper (ArXiv: 2406.15927)
    """
    ents = entropy.numpy()
    splits = np.linspace(1e-10, ents.max(), 100)
    split_mses = []
    for split in splits:
        low_idxs, high_idxs = ents < split, ents >= split
    
        low_mean = np.mean(ents[low_idxs])
        high_mean = np.mean(ents[high_idxs])
    
        mse = np.sum((ents[low_idxs] - low_mean)**2) + np.sum((ents[high_idxs] - high_mean)**2)
        mse = np.sum(mse)
    
        split_mses.append(mse)
    
    split_mses = np.array(split_mses)
    
    plt.plot(splits, split_mses, label=label)
    return splits[np.argmin(split_mses)]

def binarize_entropy(entropy, thres=0.0):  # 0.0 means even splits for normalized entropy scores
    """Binarize entropy scores into 0s and 1s"""
    binary_entropy = torch.full_like(entropy, -1, dtype=torch.float)
    binary_entropy[entropy < thres] = 0
    binary_entropy[entropy > thres] = 1

    return binary_entropy

# %% [markdown]
# ### 二值化语义熵

# %%
# Best universal split across datasets
split_method = 'best-universal-split'
all_entropy = torch.cat([D.entropy for D in Ds], dim=0)
split = best_split(all_entropy, "All datasets collective")
plt.legend()
plt.title('Sum of squared errors at different splits')
for D in Ds:
    D.b_entropy = binarize_entropy(D.entropy, split)
    print(f"Dummy accuracy for {D.name}: {max(torch.mean(D.b_entropy).item(), 1-torch.mean(D.b_entropy).item()):.4f}")
# Out:
# Dummy accuracy for squad-without: 0.5490
# Dummy accuracy for triviaqa-without: 0.7395

# %% [markdown]
# ### Train linear probes to predict Binarized SE

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'b_entropy')
    train_single_metric(D, 'slt', 'b_entropy')
# Out:
# Training on squad-without-TBG-B_ENTROPY 1/29
# Validation Accuracy: 0.5500, AUROC: 0.5000
# Training Loss: 0.6862, Validation Loss: 0.6883
# Test Loss: 0.7061, Test Accuracy: 0.4750, AUROC: 0.5000
# Training on squad-without-TBG-B_ENTROPY 2/29
# Validation Accuracy: 0.5694, AUROC: 0.6010
# Training Loss: 0.5827, Validation Loss: 0.6779
# Test Loss: 0.7098, Test Accuracy: 0.5150, AUROC: 0.5682
# Training on squad-without-TBG-B_ENTROPY 3/29
# Validation Accuracy: 0.5806, AUROC: 0.6134
# Training Loss: 0.5389, Validation Loss: 0.6750
# Test Loss: 0.7153, Test Accuracy: 0.5550, AUROC: 0.5765
# Training on squad-without-TBG-B_ENTROPY 4/29
# Validation Accuracy: 0.5889, AUROC: 0.6056
# Training Loss: 0.5093, Validation Loss: 0.7082
# Test Loss: 0.7107, Test Accuracy: 0.5700, AUROC: 0.5972
# Training on squad-without-TBG-B_ENTROPY 5/29
# Validation Accuracy: 0.5778, AUROC: 0.6108
# Training Loss: 0.4864, Validation Loss: 0.7234
# Test Loss: 0.7327, Test Accuracy: 0.5500, AUROC: 0.5952
# Training on squad-without-TBG-B_ENTROPY 6/29
# Validation Accuracy: 0.6056, AUROC: 0.6301
# Training Loss: 0.4492, Validation Loss: 0.7180
# Test Loss: 0.7796, Test Accuracy: 0.5600, AUROC: 0.5813
# Training on squad-without-TBG-B_ENTROPY 7/29
# Validation Accuracy: 0.6250, AUROC: 0.6538
# Training Loss: 0.3991, Validation Loss: 0.7164
# Test Loss: 0.7781, Test Accuracy: 0.5300, AUROC: 0.5801
# Training on squad-without-TBG-B_ENTROPY 8/29
# Validation Accuracy: 0.6194, AUROC: 0.6463
# Training Loss: 0.3834, Validation Loss: 0.7482
# Test Loss: 0.8344, Test Accuracy: 0.5400, AUROC: 0.5700
# Training on squad-without-TBG-B_ENTROPY 9/29
# Validation Accuracy: 0.6083, AUROC: 0.6426
# Training Loss: 0.3407, Validation Loss: 0.7588
# Test Loss: 0.8668, Test Accuracy: 0.5550, AUROC: 0.5608
# Training on squad-without-TBG-B_ENTROPY 10/29
# Validation Accuracy: 0.6083, AUROC: 0.6437
# Training Loss: 0.3244, Validation Loss: 0.8066
# Test Loss: 0.9172, Test Accuracy: 0.5450, AUROC: 0.5752
# Training on squad-without-TBG-B_ENTROPY 11/29
# Validation Accuracy: 0.6222, AUROC: 0.6553
# Training Loss: 0.3276, Validation Loss: 0.8061
# Test Loss: 0.9092, Test Accuracy: 0.5000, AUROC: 0.5615
# Training on squad-without-TBG-B_ENTROPY 12/29
# Validation Accuracy: 0.6028, AUROC: 0.6517
# Training Loss: 0.3543, Validation Loss: 0.8008
# Test Loss: 0.9325, Test Accuracy: 0.5350, AUROC: 0.5739
# Training on squad-without-TBG-B_ENTROPY 13/29
# Validation Accuracy: 0.5917, AUROC: 0.6423
# Training Loss: 0.3015, Validation Loss: 0.8964
# Test Loss: 0.9995, Test Accuracy: 0.5450, AUROC: 0.5823
# Training on squad-without-TBG-B_ENTROPY 14/29
# Validation Accuracy: 0.5861, AUROC: 0.6411
# Training Loss: 0.3053, Validation Loss: 0.9048
# Test Loss: 0.9039, Test Accuracy: 0.5850, AUROC: 0.6308
# Training on squad-without-TBG-B_ENTROPY 15/29
# Validation Accuracy: 0.6194, AUROC: 0.6567
# Training Loss: 0.2964, Validation Loss: 0.8896
# Test Loss: 0.9204, Test Accuracy: 0.5800, AUROC: 0.6231
# Training on squad-without-TBG-B_ENTROPY 16/29
# Validation Accuracy: 0.5944, AUROC: 0.6433
# Training Loss: 0.3137, Validation Loss: 0.9002
# Test Loss: 0.8576, Test Accuracy: 0.5950, AUROC: 0.6425
# Training on squad-without-TBG-B_ENTROPY 17/29
# Validation Accuracy: 0.6139, AUROC: 0.6533
# Training Loss: 0.2929, Validation Loss: 0.9637
# Test Loss: 0.9341, Test Accuracy: 0.5850, AUROC: 0.6374
# Training on squad-without-TBG-B_ENTROPY 18/29
# Validation Accuracy: 0.6389, AUROC: 0.6802
# Training Loss: 0.2747, Validation Loss: 0.9613
# Test Loss: 0.9246, Test Accuracy: 0.5900, AUROC: 0.6526
# Training on squad-without-TBG-B_ENTROPY 19/29
# Validation Accuracy: 0.6417, AUROC: 0.6683
# Training Loss: 0.2420, Validation Loss: 1.1032
# Test Loss: 0.9570, Test Accuracy: 0.6000, AUROC: 0.6931
# Training on squad-without-TBG-B_ENTROPY 20/29
# Validation Accuracy: 0.6083, AUROC: 0.6631
# Training Loss: 0.0747, Validation Loss: 1.7196
# Test Loss: 1.6440, Test Accuracy: 0.6150, AUROC: 0.6674
# Training on squad-without-TBG-B_ENTROPY 21/29
# Validation Accuracy: 0.6417, AUROC: 0.6901
# Training Loss: 0.0276, Validation Loss: 1.6234
# Test Loss: 1.6814, Test Accuracy: 0.6000, AUROC: 0.6513
# Training on squad-without-TBG-B_ENTROPY 22/29
# Validation Accuracy: 0.6889, AUROC: 0.7445
# Training Loss: 0.0113, Validation Loss: 1.4307
# Test Loss: 1.8618, Test Accuracy: 0.5950, AUROC: 0.6585
# Training on squad-without-TBG-B_ENTROPY 23/29
# Validation Accuracy: 0.6861, AUROC: 0.7284
# Training Loss: 0.0048, Validation Loss: 1.8208
# Test Loss: 2.2171, Test Accuracy: 0.6400, AUROC: 0.6753
# Training on squad-without-TBG-B_ENTROPY 24/29
# Validation Accuracy: 0.6861, AUROC: 0.7467
# Training Loss: 0.0020, Validation Loss: 1.6978
# Test Loss: 2.3283, Test Accuracy: 0.6050, AUROC: 0.6739
# Training on squad-without-TBG-B_ENTROPY 25/29
# Validation Accuracy: 0.6722, AUROC: 0.7399
# Training Loss: 0.0010, Validation Loss: 1.8838
# Test Loss: 2.7847, Test Accuracy: 0.5850, AUROC: 0.6523
# Training on squad-without-TBG-B_ENTROPY 26/29
# Validation Accuracy: 0.6694, AUROC: 0.7418
# Training Loss: 0.0006, Validation Loss: 1.9087
# Test Loss: 2.6354, Test Accuracy: 0.6200, AUROC: 0.6561
# Training on squad-without-TBG-B_ENTROPY 27/29
# Validation Accuracy: 0.6639, AUROC: 0.7400
# Training Loss: 0.0004, Validation Loss: 2.0656
# Test Loss: 2.9071, Test Accuracy: 0.5800, AUROC: 0.6461
# Training on squad-without-TBG-B_ENTROPY 28/29
# Validation Accuracy: 0.6806, AUROC: 0.7343
# Training Loss: 0.0003, Validation Loss: 2.1023
# Test Loss: 2.8540, Test Accuracy: 0.5750, AUROC: 0.6377
# Training on squad-without-TBG-B_ENTROPY 29/29
# Validation Accuracy: 0.6667, AUROC: 0.7199
# Training Loss: 0.0005, Validation Loss: 2.1429
# Test Loss: 2.8299, Test Accuracy: 0.5750, AUROC: 0.6052
# Training on squad-without-SLT-B_ENTROPY 1/29
# Validation Accuracy: 0.5528, AUROC: 0.5795
# Training Loss: 0.5831, Validation Loss: 0.6696
# Test Loss: 0.7124, Test Accuracy: 0.5200, AUROC: 0.5482
# Training on squad-without-SLT-B_ENTROPY 2/29
# Validation Accuracy: 0.5639, AUROC: 0.5676
# Training Loss: 0.1454, Validation Loss: 1.1742
# Test Loss: 0.9835, Test Accuracy: 0.5750, AUROC: 0.6313
# Training on squad-without-SLT-B_ENTROPY 3/29
# Validation Accuracy: 0.5889, AUROC: 0.5616
# Training Loss: 0.0995, Validation Loss: 1.3806
# Test Loss: 1.0782, Test Accuracy: 0.6050, AUROC: 0.6449
# Training on squad-without-SLT-B_ENTROPY 4/29
# Validation Accuracy: 0.5833, AUROC: 0.5808
# Training Loss: 0.0589, Validation Loss: 1.6234
# Test Loss: 1.4219, Test Accuracy: 0.6000, AUROC: 0.6318
# Training on squad-without-SLT-B_ENTROPY 5/29
# Validation Accuracy: 0.6306, AUROC: 0.6450
# Training Loss: 0.0411, Validation Loss: 1.5504
# Test Loss: 1.5816, Test Accuracy: 0.6050, AUROC: 0.6412
# Training on squad-without-SLT-B_ENTROPY 6/29
# Validation Accuracy: 0.6806, AUROC: 0.6830
# Training Loss: 0.0276, Validation Loss: 1.4087
# Test Loss: 1.5273, Test Accuracy: 0.5850, AUROC: 0.6101
# Training on squad-without-SLT-B_ENTROPY 7/29
# Validation Accuracy: 0.6667, AUROC: 0.7020
# Training Loss: 0.0225, Validation Loss: 1.3928
# Test Loss: 1.5296, Test Accuracy: 0.5650, AUROC: 0.6276
# Training on squad-without-SLT-B_ENTROPY 8/29
# Validation Accuracy: 0.6500, AUROC: 0.6750
# Training Loss: 0.0168, Validation Loss: 1.6890
# Test Loss: 1.8280, Test Accuracy: 0.6150, AUROC: 0.6382
# Training on squad-without-SLT-B_ENTROPY 9/29
# Validation Accuracy: 0.6417, AUROC: 0.6662
# Training Loss: 0.0134, Validation Loss: 1.6435
# Test Loss: 1.4629, Test Accuracy: 0.6400, AUROC: 0.6917
# Training on squad-without-SLT-B_ENTROPY 10/29
# Validation Accuracy: 0.6139, AUROC: 0.6370
# Training Loss: 0.0088, Validation Loss: 1.8358
# Test Loss: 1.4290, Test Accuracy: 0.6400, AUROC: 0.6917
# Training on squad-without-SLT-B_ENTROPY 11/29
# Validation Accuracy: 0.6278, AUROC: 0.6467
# Training Loss: 0.0086, Validation Loss: 1.8585
# Test Loss: 1.8019, Test Accuracy: 0.5850, AUROC: 0.6175
# Training on squad-without-SLT-B_ENTROPY 12/29
# Validation Accuracy: 0.6222, AUROC: 0.6706
# Training Loss: 0.0080, Validation Loss: 1.6655
# Test Loss: 1.9038, Test Accuracy: 0.5750, AUROC: 0.6212
# Training on squad-without-SLT-B_ENTROPY 13/29
# Validation Accuracy: 0.6306, AUROC: 0.6854
# Training Loss: 0.0072, Validation Loss: 1.5903
# Test Loss: 1.8320, Test Accuracy: 0.5750, AUROC: 0.6334
# Training on squad-without-SLT-B_ENTROPY 14/29
# Validation Accuracy: 0.6444, AUROC: 0.6871
# Training Loss: 0.0073, Validation Loss: 1.7516
# Test Loss: 1.9467, Test Accuracy: 0.6200, AUROC: 0.6490
# Training on squad-without-SLT-B_ENTROPY 15/29
# Validation Accuracy: 0.6389, AUROC: 0.6676
# Training Loss: 0.0064, Validation Loss: 1.8082
# Test Loss: 1.9146, Test Accuracy: 0.5850, AUROC: 0.6457
# Training on squad-without-SLT-B_ENTROPY 16/29
# Validation Accuracy: 0.6639, AUROC: 0.6750
# Training Loss: 0.0063, Validation Loss: 1.7903
# Test Loss: 1.9894, Test Accuracy: 0.6100, AUROC: 0.6410
# Training on squad-without-SLT-B_ENTROPY 17/29
# Validation Accuracy: 0.6778, AUROC: 0.7101
# Training Loss: 0.0058, Validation Loss: 1.6353
# Test Loss: 1.6929, Test Accuracy: 0.6250, AUROC: 0.6903
# Training on squad-without-SLT-B_ENTROPY 18/29
# Validation Accuracy: 0.6778, AUROC: 0.7157
# Training Loss: 0.0049, Validation Loss: 1.6813
# Test Loss: 1.9791, Test Accuracy: 0.6200, AUROC: 0.6645
# Training on squad-without-SLT-B_ENTROPY 19/29
# Validation Accuracy: 0.6750, AUROC: 0.7205
# Training Loss: 0.0041, Validation Loss: 1.7106
# Test Loss: 2.1712, Test Accuracy: 0.5750, AUROC: 0.6458
# Training on squad-without-SLT-B_ENTROPY 20/29
# Validation Accuracy: 0.6556, AUROC: 0.7171
# Training Loss: 0.0036, Validation Loss: 1.6975
# Test Loss: 1.9515, Test Accuracy: 0.5700, AUROC: 0.6658
# Training on squad-without-SLT-B_ENTROPY 21/29
# Validation Accuracy: 0.6889, AUROC: 0.7312
# Training Loss: 0.0031, Validation Loss: 1.6472
# Test Loss: 2.0018, Test Accuracy: 0.6300, AUROC: 0.6783
# Training on squad-without-SLT-B_ENTROPY 22/29
# Validation Accuracy: 0.6833, AUROC: 0.7183
# Training Loss: 0.0022, Validation Loss: 1.7877
# Test Loss: 1.9630, Test Accuracy: 0.6200, AUROC: 0.6855
# Training on squad-without-SLT-B_ENTROPY 23/29
# Validation Accuracy: 0.6750, AUROC: 0.7377
# Training Loss: 0.0015, Validation Loss: 1.7476
# Test Loss: 2.0590, Test Accuracy: 0.6150, AUROC: 0.6869
# Training on squad-without-SLT-B_ENTROPY 24/29
# Validation Accuracy: 0.6639, AUROC: 0.7257
# Training Loss: 0.0010, Validation Loss: 1.8344
# Test Loss: 2.2331, Test Accuracy: 0.5950, AUROC: 0.6725
# Training on squad-without-SLT-B_ENTROPY 25/29
# Validation Accuracy: 0.6361, AUROC: 0.7157
# Training Loss: 0.0006, Validation Loss: 1.9166
# Test Loss: 2.4034, Test Accuracy: 0.5850, AUROC: 0.6446
# Training on squad-without-SLT-B_ENTROPY 26/29
# Validation Accuracy: 0.6389, AUROC: 0.7045
# Training Loss: 0.0004, Validation Loss: 1.9356
# Test Loss: 2.3192, Test Accuracy: 0.6200, AUROC: 0.6867
# Training on squad-without-SLT-B_ENTROPY 27/29
# Validation Accuracy: 0.6889, AUROC: 0.7217
# Training Loss: 0.0003, Validation Loss: 1.9518
# Test Loss: 2.4935, Test Accuracy: 0.6250, AUROC: 0.6972
# Training on squad-without-SLT-B_ENTROPY 28/29
# Validation Accuracy: 0.6833, AUROC: 0.7300
# Training Loss: 0.0002, Validation Loss: 2.0952
# Test Loss: 2.4833, Test Accuracy: 0.6200, AUROC: 0.7024
# Training on squad-without-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.6333, AUROC: 0.6955
# Training Loss: 0.0003, Validation Loss: 2.1319
# Test Loss: 2.4165, Test Accuracy: 0.5850, AUROC: 0.6749
# Training on triviaqa-without-TBG-B_ENTROPY 1/29
# Validation Accuracy: 0.7500, AUROC: 0.5000
# Training Loss: 0.5757, Validation Loss: 0.5627
# Test Loss: 0.5782, Test Accuracy: 0.7350, AUROC: 0.5000
# Training on triviaqa-without-TBG-B_ENTROPY 2/29
# Validation Accuracy: 0.7500, AUROC: 0.7443
# Training Loss: 0.4506, Validation Loss: 0.4932
# Test Loss: 0.5292, Test Accuracy: 0.7400, AUROC: 0.7084
# Training on triviaqa-without-TBG-B_ENTROPY 3/29
# Validation Accuracy: 0.7750, AUROC: 0.7510
# Training Loss: 0.4105, Validation Loss: 0.4833
# Test Loss: 0.5011, Test Accuracy: 0.7700, AUROC: 0.7398
# Training on triviaqa-without-TBG-B_ENTROPY 4/29
# Validation Accuracy: 0.7694, AUROC: 0.7684
# Training Loss: 0.3499, Validation Loss: 0.4737
# Test Loss: 0.5047, Test Accuracy: 0.7550, AUROC: 0.7465
# Training on triviaqa-without-TBG-B_ENTROPY 5/29
# Validation Accuracy: 0.7611, AUROC: 0.7571
# Training on triviaqa-without-SLT-B_ENTROPY 28/29
# Validation Accuracy: 0.7944, AUROC: 0.8294
# Training Loss: 0.0024, Validation Loss: 1.4241
# Test Loss: 1.2798, Test Accuracy: 0.7700, AUROC: 0.8177
# Training on triviaqa-without-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.7694, AUROC: 0.8009
# Training Loss: 0.0025, Validation Loss: 1.4117
# Test Loss: 1.2472, Test Accuracy: 0.8000, AUROC: 0.8181

# %%
# plot se probe
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.tb_aucs), auc(D.sb_aucs)], ["SE Probe on TBG token", "SE Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="se_both_tok")
plt.show()

# %% [markdown]
# ### Train linear probes to predict Accuracy

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'accuracies')
    train_single_metric(D, 'slt', 'accuracies')
# Out:
# Training on squad-without-TBG-ACCURACIES 1/29
# Validation Accuracy: 0.7167, AUROC: 0.5000
# Training Loss: 0.5706, Validation Loss: 0.5978
# Test Loss: 0.5413, Test Accuracy: 0.7700, AUROC: 0.5000
# Training on squad-without-TBG-ACCURACIES 2/29
# Validation Accuracy: 0.7167, AUROC: 0.5886
# Training Loss: 0.4906, Validation Loss: 0.5889
# Test Loss: 0.5678, Test Accuracy: 0.7600, AUROC: 0.5116
# Training on squad-without-TBG-ACCURACIES 3/29
# Validation Accuracy: 0.7083, AUROC: 0.6390
# Training Loss: 0.4543, Validation Loss: 0.5765
# Test Loss: 0.5621, Test Accuracy: 0.7350, AUROC: 0.5600
# Training on squad-without-TBG-ACCURACIES 4/29
# Validation Accuracy: 0.7083, AUROC: 0.6237
# Training Loss: 0.4106, Validation Loss: 0.5956
# Test Loss: 0.5436, Test Accuracy: 0.7300, AUROC: 0.6407
# Training on squad-without-TBG-ACCURACIES 5/29
# Validation Accuracy: 0.7361, AUROC: 0.6178
# Training Loss: 0.4009, Validation Loss: 0.6155
# Test Loss: 0.5734, Test Accuracy: 0.7150, AUROC: 0.6064
# Training on squad-without-TBG-ACCURACIES 6/29
# Validation Accuracy: 0.6889, AUROC: 0.6228
# Training Loss: 0.3307, Validation Loss: 0.6141
# Test Loss: 0.5509, Test Accuracy: 0.7600, AUROC: 0.6337
# Training on squad-without-TBG-ACCURACIES 7/29
# Validation Accuracy: 0.7028, AUROC: 0.6171
# Training Loss: 0.3249, Validation Loss: 0.6406
# Test Loss: 0.5531, Test Accuracy: 0.7450, AUROC: 0.6595
# Training on squad-without-TBG-ACCURACIES 8/29
# Validation Accuracy: 0.6778, AUROC: 0.6043
# Training Loss: 0.3273, Validation Loss: 0.6757
# Test Loss: 0.5505, Test Accuracy: 0.7450, AUROC: 0.6879
# Training on squad-without-TBG-ACCURACIES 9/29
# Validation Accuracy: 0.6861, AUROC: 0.6123
# Training Loss: 0.3117, Validation Loss: 0.6779
# Test Loss: 0.5447, Test Accuracy: 0.7550, AUROC: 0.7016
# Training on squad-without-TBG-ACCURACIES 10/29
# Validation Accuracy: 0.6861, AUROC: 0.6271
# Training on squad-without-TBG-ACCURACIES 24/29
# Validation Accuracy: 0.6917, AUROC: 0.6982
# Training Loss: 0.0013, Validation Loss: 1.6947
# Test Loss: 1.4368, Test Accuracy: 0.7250, AUROC: 0.7199
# Training on squad-without-TBG-ACCURACIES 25/29
# Validation Accuracy: 0.6806, AUROC: 0.6938
# Training Loss: 0.0007, Validation Loss: 1.7868
# Test Loss: 1.5302, Test Accuracy: 0.7500, AUROC: 0.7109
# Training on squad-without-TBG-ACCURACIES 26/29
# Validation Accuracy: 0.6972, AUROC: 0.6833
# Training Loss: 0.0004, Validation Loss: 1.8212
# Test Loss: 1.5020, Test Accuracy: 0.7550, AUROC: 0.7493
# Training on squad-without-TBG-ACCURACIES 27/29
# Validation Accuracy: 0.6667, AUROC: 0.6483
# Training Loss: 0.0002, Validation Loss: 2.0842
# Test Loss: 1.9330, Test Accuracy: 0.7450, AUROC: 0.6726
# Training on squad-without-TBG-ACCURACIES 28/29
# Validation Accuracy: 0.7111, AUROC: 0.6813
# Training Loss: 0.0002, Validation Loss: 1.9215
# Test Loss: 1.6768, Test Accuracy: 0.7600, AUROC: 0.6917
# Training on squad-without-TBG-ACCURACIES 29/29
# Validation Accuracy: 0.6833, AUROC: 0.6566
# Training Loss: 0.0003, Validation Loss: 1.8748
# Test Loss: 1.6006, Test Accuracy: 0.7250, AUROC: 0.6973
# Training on squad-without-SLT-ACCURACIES 1/29
# Validation Accuracy: 0.7167, AUROC: 0.5619
# Training Loss: 0.4925, Validation Loss: 0.5949
# Test Loss: 0.5367, Test Accuracy: 0.7700, AUROC: 0.5632
# Training on squad-without-SLT-ACCURACIES 2/29
# Validation Accuracy: 0.6500, AUROC: 0.5477
# Training Loss: 0.1244, Validation Loss: 1.0559
# Test Loss: 0.9650, Test Accuracy: 0.6600, AUROC: 0.5497
# Training on squad-without-SLT-ACCURACIES 3/29
# Validation Accuracy: 0.6306, AUROC: 0.5556
# Training Loss: 0.0830, Validation Loss: 1.2333
# Test Loss: 1.1816, Test Accuracy: 0.6950, AUROC: 0.5566
# Training on squad-without-SLT-ACCURACIES 4/29
# Validation Accuracy: 0.6583, AUROC: 0.5621
# Training Loss: 0.0516, Validation Loss: 1.3202
# Test Loss: 1.0353, Test Accuracy: 0.6950, AUROC: 0.6290
# Training on squad-without-SLT-ACCURACIES 5/29
# Validation Accuracy: 0.6861, AUROC: 0.5912
# Training Loss: 0.0366, Validation Loss: 1.3550
# Test Loss: 1.1882, Test Accuracy: 0.7350, AUROC: 0.6388
# Training on squad-without-SLT-ACCURACIES 6/29
# Validation Accuracy: 0.6472, AUROC: 0.5443
# Training Loss: 0.0247, Validation Loss: 1.5678
# Test Loss: 1.1169, Test Accuracy: 0.7400, AUROC: 0.6616
# Training on squad-without-SLT-ACCURACIES 7/29
# Validation Accuracy: 0.6333, AUROC: 0.5426
# Training Loss: 0.0211, Validation Loss: 1.6569
# Test Loss: 1.2948, Test Accuracy: 0.7250, AUROC: 0.6129
# Training on squad-without-SLT-ACCURACIES 8/29
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.ta_aucs), auc(D.sa_aucs)], ["Acc Probe on TBG token", "Acc Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="acc_both_tok")
plt.show()

# %% [markdown]
# ### Use linear probe trained on Binarized SE to predict Accuracy
#
# We leverage trained probes on semantic entropy to predict model correctness on the same dataset.
#
# Note that we need to predict the error rate (1 minus accuracy) using SEPs due to the nature of semantic uncertainty.

# %%
for D in Ds:
    r_acc = 1 - D.accuracies
    
    # TBG
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.tbg_dataset, r_acc) 
    tab_accs = []
    tab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-TBG {i+1}/{len(X_tests)}")
        model = D.tb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        tab_accs.append(test_acc)
        tab_aucs.append(test_auc)

    D.tab_accs = tab_accs
    D.tab_aucs = tab_aucs

    # SLT t
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.slt_dataset, r_acc)     
    sab_accs = []
    sab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-SLT {i+1}/{len(X_tests)}")
        model = D.sb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        sab_accs.append(test_acc)
        sab_aucs.append(test_auc)

    D.sab_accs = sab_accs
    D.sab_aucs = sab_aucs
# Out:
# Testing on squad-without-TBG 1/29
# Test Loss: 0.7642, Test Accuracy: 0.2300, AUROC: 0.5000
# Testing on squad-without-TBG 2/29
# Test Loss: 0.8031, Test Accuracy: 0.4200, AUROC: 0.4870
# Testing on squad-without-TBG 3/29
# Test Loss: 0.7900, Test Accuracy: 0.4500, AUROC: 0.5503
# Testing on squad-without-TBG 4/29
# Test Loss: 0.7848, Test Accuracy: 0.4850, AUROC: 0.5902
# Testing on squad-without-TBG 5/29
# Test Loss: 0.8235, Test Accuracy: 0.4650, AUROC: 0.5796
# Testing on squad-without-TBG 6/29
# Test Loss: 0.9210, Test Accuracy: 0.4650, AUROC: 0.5258
# Testing on squad-without-TBG 7/29
# Test Loss: 0.9140, Test Accuracy: 0.4850, AUROC: 0.5442
# Testing on squad-without-TBG 8/29
# Test Loss: 0.9408, Test Accuracy: 0.5050, AUROC: 0.5615
# Testing on squad-without-TBG 9/29
# Test Loss: 1.0312, Test Accuracy: 0.4600, AUROC: 0.4955
# Testing on squad-without-TBG 10/29
# Test Loss: 1.0976, Test Accuracy: 0.4900, AUROC: 0.5617
# Testing on squad-without-TBG 11/29
# Test Loss: 1.1038, Test Accuracy: 0.4950, AUROC: 0.5415
# Testing on squad-without-TBG 12/29
# Test Loss: 1.1181, Test Accuracy: 0.5000, AUROC: 0.5407
# Testing on squad-without-TBG 13/29
# Test Loss: 1.2638, Test Accuracy: 0.5000, AUROC: 0.5251
# Testing on squad-without-TBG 14/29
# Test Loss: 1.2424, Test Accuracy: 0.5100, AUROC: 0.5471
# Testing on squad-without-TBG 15/29
# Test Loss: 1.1991, Test Accuracy: 0.5650, AUROC: 0.6098
# Testing on squad-without-TBG 16/29
# Test Loss: 1.1577, Test Accuracy: 0.5100, AUROC: 0.6220
# Testing on squad-without-TBG 17/29
# Test Loss: 1.2422, Test Accuracy: 0.5200, AUROC: 0.5947
# Testing on squad-without-TBG 18/29
# Test Loss: 1.3458, Test Accuracy: 0.4950, AUROC: 0.5575
# Testing on squad-without-TBG 19/29
# Test Loss: 1.5340, Test Accuracy: 0.4650, AUROC: 0.5906
# Testing on squad-without-TBG 20/29
# Test Loss: 2.4886, Test Accuracy: 0.5600, AUROC: 0.6248
# Testing on squad-without-TBG 21/29
# Test Loss: 2.1524, Test Accuracy: 0.5550, AUROC: 0.6430
# Testing on squad-without-TBG 22/29
# Test Loss: 2.4208, Test Accuracy: 0.5600, AUROC: 0.6551
# Testing on squad-without-TBG 23/29
# Test Loss: 2.9142, Test Accuracy: 0.6050, AUROC: 0.6396
# Testing on squad-without-TBG 24/29
# Test Loss: 3.1469, Test Accuracy: 0.5700, AUROC: 0.6488
# Testing on squad-without-TBG 25/29
# Test Loss: 3.8177, Test Accuracy: 0.5500, AUROC: 0.6326
# Testing on squad-without-TBG 26/29
# Test Loss: 3.7420, Test Accuracy: 0.5150, AUROC: 0.6241
# Testing on squad-without-TBG 27/29
# Test Loss: 3.7090, Test Accuracy: 0.5350, AUROC: 0.6150
# Testing on squad-without-TBG 28/29
# Test Loss: 3.4367, Test Accuracy: 0.5500, AUROC: 0.6615
# Testing on squad-without-TBG 29/29
# Test Loss: 2.9165, Test Accuracy: 0.5800, AUROC: 0.6855
# Testing on squad-without-SLT 1/29
# Test Loss: 0.7875, Test Accuracy: 0.3650, AUROC: 0.4959
# Testing on squad-without-SLT 2/29
# Test Loss: 1.5350, Test Accuracy: 0.4400, AUROC: 0.4205
# Testing on squad-without-SLT 3/29
# Test Loss: 1.5789, Test Accuracy: 0.4800, AUROC: 0.4975
# Testing on squad-without-SLT 4/29
# Test Loss: 1.8682, Test Accuracy: 0.4750, AUROC: 0.5500
# Testing on squad-without-SLT 5/29
# Test Loss: 2.3524, Test Accuracy: 0.4900, AUROC: 0.5316
# Testing on squad-without-SLT 6/29
# Test Loss: 2.2806, Test Accuracy: 0.4600, AUROC: 0.4883
# Testing on squad-without-SLT 7/29
# Test Loss: 2.2014, Test Accuracy: 0.4900, AUROC: 0.5175
# Testing on squad-without-SLT 8/29
# Test Loss: 2.6654, Test Accuracy: 0.4800, AUROC: 0.4970
# Testing on squad-without-SLT 9/29
# Test Loss: 2.2945, Test Accuracy: 0.5150, AUROC: 0.5498
# Testing on squad-without-SLT 10/29
# Test Loss: 2.2553, Test Accuracy: 0.5150, AUROC: 0.5697
# Testing on squad-without-SLT 11/29
# Test Loss: 2.6259, Test Accuracy: 0.4600, AUROC: 0.4760
# Testing on squad-without-SLT 12/29
# Test Loss: 2.6284, Test Accuracy: 0.4800, AUROC: 0.4983
# Testing on squad-without-SLT 13/29
# Test Loss: 2.4620, Test Accuracy: 0.5000, AUROC: 0.6087
# Testing on squad-without-SLT 14/29
# Test Loss: 2.8364, Test Accuracy: 0.5250, AUROC: 0.5710
# Testing on squad-without-SLT 15/29
# Test Loss: 2.7136, Test Accuracy: 0.4800, AUROC: 0.5881
# Testing on squad-without-SLT 16/29
# Test Loss: 2.4612, Test Accuracy: 0.5350, AUROC: 0.6365
# Testing on squad-without-SLT 17/29
# Test Loss: 2.3524, Test Accuracy: 0.5400, AUROC: 0.6364
# Testing on squad-without-SLT 18/29
# Test Loss: 2.8144, Test Accuracy: 0.5050, AUROC: 0.5812
# Testing on squad-without-SLT 19/29
# Test Loss: 2.9945, Test Accuracy: 0.5100, AUROC: 0.5906
# Testing on squad-without-SLT 20/29
# Test Loss: 2.9963, Test Accuracy: 0.4450, AUROC: 0.5378
# Testing on squad-without-SLT 21/29
# Test Loss: 3.1073, Test Accuracy: 0.5150, AUROC: 0.5491
# Testing on squad-without-SLT 22/29
# Test Loss: 2.9943, Test Accuracy: 0.5050, AUROC: 0.5984
# Testing on squad-without-SLT 23/29
# Test Loss: 3.1293, Test Accuracy: 0.5400, AUROC: 0.6362
# Testing on squad-without-SLT 24/29
# Test Loss: 3.3471, Test Accuracy: 0.5100, AUROC: 0.6110
# Testing on squad-without-SLT 25/29
# Test Loss: 3.6975, Test Accuracy: 0.4900, AUROC: 0.5908
# Testing on squad-without-SLT 26/29
# Test Loss: 3.9907, Test Accuracy: 0.4950, AUROC: 0.6119
# Testing on squad-without-SLT 27/29
# Test Loss: 4.4423, Test Accuracy: 0.4800, AUROC: 0.6067
# Testing on squad-without-SLT 28/29
# Test Loss: 4.3405, Test Accuracy: 0.5050, AUROC: 0.6182
# Testing on squad-without-SLT 29/29
# Test Loss: 3.6819, Test Accuracy: 0.4800, AUROC: 0.6259
# Testing on triviaqa-without-TBG 1/29
# Test Loss: 0.7022, Test Accuracy: 0.6150, AUROC: 0.5000
# Testing on triviaqa-without-TBG 2/29
# Test Loss: 0.6286, Test Accuracy: 0.6400, AUROC: 0.7178
# Testing on triviaqa-without-TBG 3/29
# Test Loss: 0.6124, Test Accuracy: 0.6700, AUROC: 0.7281
# Testing on triviaqa-without-TBG 4/29
# Test Loss: 0.6165, Test Accuracy: 0.6950, AUROC: 0.7236
# Testing on triviaqa-without-TBG 5/29
# Test Loss: 0.6220, Test Accuracy: 0.6850, AUROC: 0.7320
# Testing on triviaqa-without-TBG 6/29
# Test Loss: 0.6955, Test Accuracy: 0.6650, AUROC: 0.6935
# Testing on triviaqa-without-TBG 7/29
# Test Loss: 0.7085, Test Accuracy: 0.6500, AUROC: 0.6990
# Testing on triviaqa-without-TBG 8/29
# Test Loss: 0.7519, Test Accuracy: 0.6400, AUROC: 0.7075
# Testing on triviaqa-without-TBG 9/29
# Test Loss: 0.7320, Test Accuracy: 0.6650, AUROC: 0.7219
# Testing on triviaqa-without-TBG 10/29
# Test Loss: 0.7966, Test Accuracy: 0.7000, AUROC: 0.7233
# Testing on triviaqa-without-TBG 11/29
# Test Loss: 1.8861, Test Accuracy: 0.6600, AUROC: 0.6465
# Testing on triviaqa-without-SLT 9/29
# Test Loss: 1.8716, Test Accuracy: 0.6750, AUROC: 0.6634
# Testing on triviaqa-without-SLT 10/29
# Test Loss: 1.8781, Test Accuracy: 0.6800, AUROC: 0.6669
# Testing on triviaqa-without-SLT 11/29
# Test Loss: 1.5898, Test Accuracy: 0.7050, AUROC: 0.7080
# Testing on triviaqa-without-SLT 12/29
# Test Loss: 1.6564, Test Accuracy: 0.6900, AUROC: 0.7149
# Testing on triviaqa-without-SLT 13/29
# Test Loss: 1.5952, Test Accuracy: 0.7050, AUROC: 0.7362
# Testing on triviaqa-without-SLT 14/29
# Test Loss: 1.6962, Test Accuracy: 0.7050, AUROC: 0.7189
# Testing on triviaqa-without-SLT 15/29
# Test Loss: 1.6460, Test Accuracy: 0.7150, AUROC: 0.7321
# Testing on triviaqa-without-SLT 16/29
# Test Loss: 1.7835, Test Accuracy: 0.7250, AUROC: 0.7256
# Testing on triviaqa-without-SLT 17/29
# Test Loss: 1.6396, Test Accuracy: 0.7350, AUROC: 0.7487
# Testing on triviaqa-without-SLT 18/29
# Test Loss: 1.5716, Test Accuracy: 0.7350, AUROC: 0.7575
# Testing on triviaqa-without-SLT 19/29
# Test Loss: 1.5730, Test Accuracy: 0.7350, AUROC: 0.7729
# Testing on triviaqa-without-SLT 20/29
# Test Loss: 1.5595, Test Accuracy: 0.7250, AUROC: 0.7692
# Testing on triviaqa-without-SLT 21/29
# Test Loss: 1.6763, Test Accuracy: 0.7200, AUROC: 0.7579
# Testing on triviaqa-without-SLT 22/29
# Test Loss: 1.7420, Test Accuracy: 0.7000, AUROC: 0.7638
# Testing on triviaqa-without-SLT 23/29
# Test Loss: 1.7353, Test Accuracy: 0.7250, AUROC: 0.7943
# Testing on triviaqa-without-SLT 24/29
# Test Loss: 1.7311, Test Accuracy: 0.7150, AUROC: 0.8050
# Testing on triviaqa-without-SLT 25/29
# Test Loss: 1.8231, Test Accuracy: 0.7150, AUROC: 0.7926
# Testing on triviaqa-without-SLT 26/29
# Test Loss: 2.1897, Test Accuracy: 0.6600, AUROC: 0.7539
# Testing on triviaqa-without-SLT 27/29
# Test Loss: 2.4167, Test Accuracy: 0.6650, AUROC: 0.7452
# Testing on triviaqa-without-SLT 28/29
# Test Loss: 2.1819, Test Accuracy: 0.6600, AUROC: 0.7711
# Testing on triviaqa-without-SLT 29/29
# Test Loss: 2.3332, Test Accuracy: 0.6900, AUROC: 0.7248

# %%
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [D.sa_aucs, D.sab_aucs], ["LR trained and tested on Acc", "LR trained on SE, tested on Acc"], f"AUROC on {D.name.upper()}'s SLT")
plt.tight_layout()
save_fig(name="se_for_acc_slt")
plt.show()

# %%
# select best layer range (SLT)
def decide_layer_range(Ds, metric='entropy', limit=NUMBER_OF_LAYERS+1): # NOTE: set upperbound to be number of layers+1; e.g. for llama2-70b, it is 81.
    """
    simple logic: use ID average test AUROCs across layers to determine 
    which consecutive range of layers did the best. Do separately
    for SEP and Acc. Pr.
    """
    assert hasattr(Ds[0], 'sab_aucs') and hasattr(Ds[0], 'sa_aucs'), 'previous cells need to be run'
    if 'entropy' in metric:
        aucs = [np.array(auc(D.sab_aucs)) for D in Ds]  # test metrics for ID SEPs
    else:
        aucs = [np.array(auc(D.sa_aucs)) for D in Ds]  # test metrics for ID APs
    best_mean = -np.inf
    best_range = []
    average = lambda a,b : np.mean([np.mean(ac[a:b]) for ac in aucs])

    for i in range(limit):
        for j in range(i+1, limit):
            if j - i < 5: # must be more than 5 layers
                continue
            if average(i, j) > best_mean:
                best_mean = average(i, j)
                best_range = [i, j]

    return best_mean, best_range

emean, (e1, e2) = decide_layer_range(Ds, 'entropy')
amean, (a1, a2) = decide_layer_range(Ds, 'acc')
for D in Ds:
    D.sep_layer_range = (e1, e2)
    D.ap_layer_range = (a1, a2)
print(emean, (e1, e2), amean, (a1, a2))
# Out:
# 0.6957896645595478 (21, 26) 0.7789572746094486 (19, 24)

# %%
# BOOTSTRAP: select [xx-xx] layers for bootstrapping
def concat_Xs_and_ys(layer_range, X_trains, X_vals, X_tests, y_trains, y_vals, y_tests, 
                     no_val=False, test_only=False):
    """
    Concatenate @params{layer_range} hidden state layers on train/val/test sets.

    no_val: no validation (training set only).
    test_only: no train/validation set (test set only).
    """
    if not no_val:
        X_val_cc = np.concatenate(np.array(X_vals)[layer_range], axis=1)
        y_val_cc = y_vals[layer_range[0]]
    else:
        X_val_cc = y_val_cc = None

    if not test_only:
        X_train_cc = np.concatenate(np.array(X_trains)[layer_range], axis=1)
        y_train_cc = y_trains[layer_range[0]]
    else:
        X_train_cc = y_train_cc = None
    
    X_test_cc = np.concatenate(np.array(X_tests)[layer_range], axis=1)
    y_test_cc = y_tests[layer_range[0]]
    
    return X_train_cc, X_val_cc, X_test_cc, y_train_cc, y_val_cc, y_test_cc

def train_concat_SE(D, layer_range):
    """train model on single dataset SE with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_bmodel', model)

        print(f'{token_type.upper()} trained on {D.name} SE finished')
    
def train_concat_Acc(D, layer_range):
    """train model on single dataset Accuracy with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_amodel', model)

        print(f'{token_type.upper()} trained on {D.name} Acc finished')

def train_concat_SE_Acc_test_Acc(D, layer_ranges=[list(range(e1,e2)), list(range(a1,a2))]):
    """ID: train and test SEPs and Acc. Pr. on single dataset with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, no_val=True) 
        
        X_train_cc, _, _, y_train_cc, _, _ = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys, no_val=True)
        ab_accs = []
        ab_aucs = []
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)

        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies) 
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys) # fixed random seed ensures no data leakage
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, 1-y_test_cc) # SEP predicts error rate
        ab_accs.append(test_acc)
        ab_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}b_accs', ab_accs)  # i means IDß
        setattr(D, f'i{var_name}b_aucs', ab_aucs)

        print(f'{D.name.upper()}-{token_type.upper()} trainied on SE and tested on Acc finished')
        aa_accs = []
        aa_aucs = []
        X_train_cc, _, X_test_cc, y_train_cc, _, y_test_cc = concat_Xs_and_ys(layer_ranges[1], *all_Xs_and_ys, no_val=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, y_test_cc)
        aa_accs.append(test_acc)
        aa_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}a_accs', aa_accs)
        setattr(D, f'i{var_name}a_aucs', aa_aucs)
        print(f'{D.name.upper()}-{token_type.upper()} trainied on Acc and tested on Acc finished')

# %%
# ID: train SEPs and Acc. Pr. and test them on Acc. from the same dataset
# import warnings # uncomment to disable convergence warnings
# warnings.filterwarnings('ignore')

for D in Ds:
    train_concat_SE_Acc_test_Acc(D)
# Out:
# Test Loss: 3.9048, Test Accuracy: 0.5150, AUROC: 0.6070
# SQUAD-WITHOUT-SLT trainied on SE and tested on Acc finished
# Test Loss: 1.3758, Test Accuracy: 0.7600, AUROC: 0.7120
# SQUAD-WITHOUT-SLT trainied on Acc and tested on Acc finished
# Test Loss: 2.4021, Test Accuracy: 0.7300, AUROC: 0.8153
# TRIVIAQA-WITHOUT-SLT trainied on SE and tested on Acc finished
# Test Loss: 0.9742, Test Accuracy: 0.8300, AUROC: 0.8878
# TRIVIAQA-WITHOUT-SLT trainied on Acc and tested on Acc finished

# %%
# OOD: save model trained on individual datasets for OOD tests
for D in Ds:
    train_concat_SE(D, layer_range=list(range(e1,e2)))
    train_concat_Acc(D, layer_range=list(range(a1,a2)))
# outputs cleared for space concern
# Out:
# SLT trained on squad-without SE finished
# SLT trained on squad-without Acc finished
# SLT trained on triviaqa-without SE finished
# SLT trained on triviaqa-without Acc finished

# %% [markdown]
# ## Test probes trained with one dataset on others
#
# We generalize SE and Acc. probes to Out-of-Distribution settings (OOD).

# %%
# Train on one's Acc/SE and test on others' Acc
def test_one_on_n(D, token_type='slt', 
                  layer_range1=list(range(e1,e2)), 
                  layer_range2=list(range(a1,a2))):
    var_name = token_type[0]
    other_ids = D.other_ids
    other_names = D.other_names
    metric = 'accuracies'
    a_model = getattr(D, f'{var_name}_amodel')  # Acc. Probe
    b_model = getattr(D, f'{var_name}_bmodel')  # SE Probe

    print(f"Using probes trained on datasets {D.name.upper()}'s {token_type.upper()}-SE/Acc to predict {other_names}'s {token_type.upper()}-Acc")

    oa_accs = {}
    oa_aucs = {}
    ob_accs = {}
    ob_aucs = {}
    
    for id_ in D.other_ids:
        D_id = Ds[id_]
        print(f"Testing on {D_id.name.upper()}'s {token_type.upper()}-{metric.upper()}")
        if metric == 'accuracies':
            y_metric = 1 - getattr(D_id, metric)  # error rate
        else:
            y_metric = getattr(D_id, metric)
        
        ida_accs = []
        ida_aucs = []
        idb_accs = []
        idb_aucs = []

        # create test sets with accuracy labels
        all_Xs_and_ys = create_Xs_and_ys(getattr(D_id, f'{token_type}_dataset'), y_metric, test_only=True)

        # test on Acc. Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range2, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(a_model, X_test_cc, 1-y_test_cc, bootstrap=True)
        ida_accs.append(test_acc)
        ida_aucs.append(test_auc)
        
        # test on SE Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range1, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(b_model, X_test_cc, y_test_cc, bootstrap=True)
        idb_accs.append(test_acc)
        idb_aucs.append(test_auc)

        oa_accs[D_id.name] = ida_accs
        oa_aucs[D_id.name] = ida_aucs
        ob_accs[D_id.name] = idb_accs
        ob_aucs[D_id.name] = idb_aucs

    setattr(D, 'osa_accs', oa_accs) # o means OOD
    setattr(D, 'osa_aucs', oa_aucs)
    setattr(D, 'osb_accs', ob_accs)
    setattr(D, 'osb_aucs', ob_aucs)

    print(f"Using probes trained on dataset {D.name.upper()} testing complete.")

# %%
for D in Ds:
    test_one_on_n(D, 'slt')
# Out:
# Using probes trained on datasets SQUAD-WITHOUT's SLT-SE/Acc to predict ['triviaqa-without']'s SLT-Acc
# Testing on TRIVIAQA-WITHOUT's SLT-ACCURACIES
# Test Loss: 1.7615, Test Accuracy: 0.6720, AUROC: 0.7522
# Test Loss: 2.2723, Test Accuracy: 0.6790, AUROC: 0.7260
# Using probes trained on dataset SQUAD-WITHOUT testing complete.
# Using probes trained on datasets TRIVIAQA-WITHOUT's SLT-SE/Acc to predict ['squad-without']'s SLT-Acc
# Testing on SQUAD-WITHOUT's SLT-ACCURACIES
# Test Loss: 2.4217, Test Accuracy: 0.6425, AUROC: 0.7021
# Test Loss: 5.8417, Test Accuracy: 0.4810, AUROC: 0.6726
# Using probes trained on dataset TRIVIAQA-WITHOUT testing complete.

# %%
# compute the OOD average: mean([train on B-> test on A, train on C -> test on A, train on D-> test on A])
b_performances = defaultdict(list)
a_performances = defaultdict(list)
win_rate = []
for D in Ds:
    for name in D.other_names:
        b_performances[name].append(auc(D.osb_aucs[name]))
        a_performances[name].append(auc(D.osa_aucs[name]))
        if auc(D.osb_aucs[name]) > auc(D.osa_aucs[name]):
            win_rate.append(1)
        else:
            win_rate.append(0)

print(f"winning rate: {np.mean(win_rate)*100:.2f}%")

for D in Ds:
    D.sep_ood_avg = np.mean(b_performances[D.name])
    D.ap_ood_avg = np.mean(a_performances[D.name])
    print(f"Average performance on {D.name}: SE Probe - {D.sep_ood_avg}, Acc Probe - {D.ap_ood_avg}")
# Out:
# winning rate: 0.00%
# Average performance on squad-without: SE Probe - 0.6726213476027106, Acc Probe - 0.7021423581160987
# Average performance on triviaqa-without: SE Probe - 0.7259867960769848, Acc Probe - 0.7521995937906792

# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("End time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# 记录结束时间
end = time()
# 计算时间间隔，按照小时：分钟：秒的格式输出
elapsed_seconds = end - start
elapsed_hours = int(elapsed_seconds // 3600)
elapsed_minutes = int((elapsed_seconds % 3600) // 60)
elapsed_seconds = int(elapsed_seconds % 60)
print(f"Time elapsed: {elapsed_hours:02d}:{elapsed_minutes:02d}:{elapsed_seconds:02d}")
# Out:
# End time: 2024-12-10 18:20:25
# Time elapsed: 00:07:54
