# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("Start time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# 记录开始时间
from time import time
start = time()
# Out:
# Start time: 2024-12-10 18:12:22

# %% [markdown]
# # 合并golden、irrelevant、without三种数据一起训练探针
# 各取1/3

# %%
# 全局变量
# 图片保存文件夹路径
FIG_DIR = "output/data/figures/merge_sample_types"
# 模型层数
NUMBER_OF_LAYERS = 28 # Qwen2.5-7B共有28层

# %%
# %load_ext autoreload
# %autoreload 2

import json
import warnings
import os
import pickle
from tqdm import tqdm
import torch
from collections import defaultdict, Counter
import argparse
from core.models.entailment import EntailmentDeberta
from core.data.data_utils import load_ds_from_json
import numpy as np
import pandas as pd
import scipy
from matplotlib import pyplot as plt
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score, mean_squared_error
from sklearn.model_selection import train_test_split

warnings.filterwarnings("ignore")
plt.rcParams.update({'font.size': 12})
rng = np.random.default_rng(42)


def load_pickle_file(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

def save_pickle_file(file_path, data):
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

# %%
# Create Dataset class for easier attribute keeping
class Dataset:
    name = ''
    tbg_dataset = None
    slt_dataset = None
    entropy = None
    accuracies = None

    sample_type = ''
    model_name = ''
    dataset_name = ''
    split = ''
    def __init__(self, name, tbg_dataset, slt_dataset, entropy, accuracies, sample_type, model_name, dataset_name, split):
        self.name = name
        self.tbg_dataset = tbg_dataset
        self.slt_dataset = slt_dataset
        self.entropy = entropy
        self.accuracies = accuracies
        self.sample_type = sample_type
        self.model_name = model_name
        self.dataset_name = dataset_name
        self.split = split

all_data = load_pickle_file("output/data/all_data.pkl")


model_name = "Qwen/Qwen2.5-7B-Instruct"
dataset_names = ["squad", "triviaqa"]
split = "train"
sample_types = ['golden', 'irrelevant', 'without']

Ds = []
for dataset_name in dataset_names:
    Ds_sample_types = [] # 区分不同sample_types
    for sample_type in sample_types:
        Ds_sample_types.append(all_data[model_name][dataset_name][split][sample_type])
    tbg_datasets = [] # torch.Size([29, 2000, 3584])
    slt_datasets = [] # torch.Size([29, 2000, 3584])
    entropies = [] # torch.Size([2000])
    accuracies = [] # torch.Size([2000])
    
    # 合并不同sample_types
    for ds in Ds_sample_types:
        # 获取样本数量
        sample_size = ds.entropy.size(0)
        # 只取前1/3样本
        tbg_datasets.append(ds.tbg_dataset[:, :sample_size//3, :])
        slt_datasets.append(ds.slt_dataset[:, :sample_size//3, :])
        entropies.append(ds.entropy[:sample_size//3])
        accuracies.append(ds.accuracies[:sample_size//3])

    tbg_dataset = torch.cat(tbg_datasets, dim=1)
    slt_dataset = torch.cat(slt_datasets, dim=1)
    entropy = torch.cat(entropies, dim=0)
    accuracy = torch.cat(accuracies, dim=0)
    ds = Dataset(name=dataset_name, 
                 tbg_dataset=tbg_dataset, 
                 slt_dataset=slt_dataset, 
                 entropy=entropy, 
                 accuracies=accuracy, 
                 sample_type="all", 
                 model_name=model_name, 
                 dataset_name=dataset_name, 
                 split=split)
    Ds.append(ds)

for i, D in enumerate(Ds):
    # OOD-related
    D.other_ids = [j for j in range(len(Ds)) if j != i]
    D.other_names = [Ds[j].name for j in D.other_ids]

# 打印数据集信息
for ds in Ds:
    print(f"{ds.model_name} {ds.dataset_name} {ds.split}: {len(ds.accuracies)}")
# Out:
# Qwen/Qwen2.5-7B-Instruct squad train: 1998
# Qwen/Qwen2.5-7B-Instruct triviaqa train: 1998

# %% [markdown]
# ### Helper Methods

# %%
# Create train/val/test splits
def create_Xs_and_ys(datasets, scores, val_test_splits=[0.2, 0.1], test_only=False, no_val=False):
    # Data splitting for sklearn linear models
    X = np.array(datasets)
    y = np.array(scores)

    if test_only:
        X_tests, y_tests = [], []
        
        for i in range(X.shape[0]):
            X_tests.append(X[i])
            y_tests.append(y)
        return (None, None, X_tests, None, None, y_tests)
    
    valid_size = val_test_splits[0]
    test_size = val_test_splits[1]

    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = [], [], [], [], [], []

    for i in range(X.shape[0]):
        # Split data into train, validation, and test sets
        X_train_val, X_test, y_train_val, y_test = train_test_split(X[i], y, test_size=test_size, random_state=42)
        X_tests.append(X_test)
        y_tests.append(y_test)
        if no_val:
            X_trains.append(X_train_val)
            y_trains.append(y_train_val)
            continue
        X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=valid_size, random_state=42) 
        X_trains.append(X_train)
        y_trains.append(y_train)
        X_vals.append(X_val)
        y_vals.append(y_val)

    return X_trains, X_vals, X_tests, y_trains, y_vals, y_tests

# %%
'''
这段代码的变量生命周期有些混乱，需要注意，例如rng是全局变量；
bootstrap_func和auroc方法会被调用，而bootstrap和compatible_bootstrap是内部方法，不会被外部调用
'''

# Bootstrapping methods from ../semantic_entropy/uncertainty/utils/eval_utils.py
def bootstrap_func(y_true, y_score, func):
    y_tuple = (y_true, y_score)
    
    metric_i = func(*y_tuple)
    metric_dict = {}
    metric_dict['mean'] = metric_i
    metric_dict['bootstrap'] = compatible_bootstrap(
        func, rng)(*y_tuple)  # a bit slow to run
    # 这里的rng是全局变量
    # note that the rng is a global variable
    return metric_dict

def bootstrap(function, rng, n_resamples=1000):
    def inner(data):
        bs = scipy.stats.bootstrap(
            (data, ), function, n_resamples=n_resamples, confidence_level=0.9,
            random_state=rng)
        return {
            'std_err': bs.standard_error,
            'low': bs.confidence_interval.low,
            'high': bs.confidence_interval.high
        }
    return inner

def auroc(y_true, y_score):
    fpr, tpr, thresholds = metrics.roc_curve(y_true, y_score)
    del thresholds
    return metrics.auc(fpr, tpr)

def compatible_bootstrap(func, rng):
    def helper(y_true_y_score):
        # this function is called in the bootstrap
        y_true = np.array([i['y_true'] for i in y_true_y_score])
        y_score = np.array([i['y_score'] for i in y_true_y_score])
        out = func(y_true, y_score)
        return out

    def wrap_inputs(y_true, y_score):
        return [{'y_true': i, 'y_score': j} for i, j in zip(y_true, y_score)]

    def converted_func(y_true, y_score):
        y_true_y_score = wrap_inputs(y_true, y_score)
        return bootstrap(helper, rng=rng)(y_true_y_score)
    return converted_func

# %%
# Train and evaluation function.
def sklearn_train_and_evaluate(model, X_train, y_train, X_valid, y_valid, silent=False):
    model.fit(X_train, y_train)
    
    # Calculate training loss and score
    train_probs = model.predict_proba(X_train)
    train_loss = log_loss(y_train, train_probs)

    # Calculate validation loss
    valid_preds = model.predict(X_valid)
    valid_probs = model.predict_proba(X_valid)
    valid_loss = log_loss(y_valid, valid_probs)
    val_accuracy = np.mean((valid_preds == y_valid).astype(int))
    auroc_score = roc_auc_score(y_valid, valid_probs[:,1])
    if not silent:
        print(f"Validation Accuracy: {val_accuracy:.4f}, AUROC: {auroc_score:.4f}")
        print(f"Training Loss: {train_loss:.4f}, Validation Loss: {valid_loss:.4f}")

def sklearn_evaluate_on_test(model, X_test, y_test, silent=False, bootstrap=True):
    test_preds = model.predict(X_test)
    test_probs = model.predict_proba(X_test)
    test_loss = log_loss(y_test, test_probs)
    test_accuracy = np.mean((test_preds == y_test).astype(int))
    
    if bootstrap:
        auroc_score = bootstrap_func(y_test, test_probs[:,1], auroc)
        auroc_score_scalar = auroc_score['mean']
    else:
        auroc_score = auroc_score_scalar = roc_auc_score(y_test, test_probs[:, 1])
    
    if not silent:
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, AUROC: {auroc_score_scalar:.4f}")
    
    return test_loss, test_accuracy, auroc_score

def train_single_metric(D, token_type='tbg', metric='b_entropy'):
    """train and test on single metric (e.g. SE, Acc) on single dataset"""
    var_name = token_type[0] + metric[0] 
    # named as [te, se. ta, sa] for easy identification; t for tbg, s for slt (token positions)
    # e for entropy and a for accuracy (or model faithfulness)
    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = create_Xs_and_ys(
        getattr(D, f'{token_type}_dataset'), getattr(D, metric)
    )

    accs = []
    aucs = []
    models = []
    
    for i, (X_train, X_val, X_test, y_train, y_val, y_test) in enumerate(zip(X_trains, X_vals, X_tests, y_trains, y_vals, y_tests)):
        print(f"Training on {D.name}-{token_type.upper()}-{metric.upper()} {i+1}/{len(X_trains)}")
        model = LogisticRegression()
        sklearn_train_and_evaluate(model, X_train, y_train, X_val, y_val)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        accs.append(test_acc)
        aucs.append(test_auc)
        models.append(model)

    setattr(D, f'{var_name}_accs', accs)
    setattr(D, f'{var_name}_aucs', aucs)
    setattr(D, f'{var_name}_models', models)

# simple get-around for unpacking bootstrapping dicts
auc = lambda aucs : [ac['mean'] for ac in aucs] 
idf = lambda x : x  # identical function

# %%
# Plotting methods
def plot_metrics_ax(ax, test_metrics_list, model_names, title="", prep_func=auc, 
                    use_logarithm=False, preset_layer_indices=None, legend_outside=False):  # some simple gadgets
    """plot metrics along certain axis in a multi-axis plot (plt.subplots)"""
    if len(test_metrics_list) != len(model_names):
        raise ValueError("The length of test_metrics_list and model_names must be the same.")
    
    for test_metrics, model_name in zip(test_metrics_list, model_names):
        test_metrics = torch.tensor(prep_func(test_metrics), dtype=torch.float32)
        if use_logarithm:
            test_metrics = torch.log(test_metrics + 1e-6)
        if preset_layer_indices is not None:
            layer_indices = preset_layer_indices
        else:
            layer_indices = torch.arange(len(test_metrics)) + 1  # +1 if layer indexing starts at 1
        
        ax.plot(layer_indices, test_metrics, marker='o', linestyle='-', linewidth=2, markersize=5, label=model_name)
    
    ax.set_title(f'{title}', fontsize=14)
    ax.set_xlabel('Layer', fontsize=12)
    ax.set_ylabel(f'Test AUROC scores', fontsize=12)
    
    tick_interval = 5  # Change this value to display more or fewer ticks
    ax.set_xticks(layer_indices[::tick_interval].tolist())
    ax.set_xticklabels(layer_indices[::tick_interval].tolist())
    
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    
    if legend_outside:
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12)
    else:
        ax.legend(fontsize=12)

def save_fig(name):
    """save figure with timestamps"""
    dir_path = os.path.expanduser(FIG_DIR)
    os.makedirs(dir_path, exist_ok=True)
    full_path = os.path.join(dir_path, f'{name}.pdf')
    plt.savefig(full_path, format='pdf', dpi=300)

# %%
# Best split for SE binarization.
def best_split(entropy: torch.Tensor, label="Dx"):
    """
    Identify best split for minimizing reconstruction error via low and high SE mean estimates,
    as discussed in Section 4. Binarization of paper (ArXiv: 2406.15927)
    """
    ents = entropy.numpy()
    splits = np.linspace(1e-10, ents.max(), 100)
    split_mses = []
    for split in splits:
        low_idxs, high_idxs = ents < split, ents >= split
    
        low_mean = np.mean(ents[low_idxs])
        high_mean = np.mean(ents[high_idxs])
    
        mse = np.sum((ents[low_idxs] - low_mean)**2) + np.sum((ents[high_idxs] - high_mean)**2)
        mse = np.sum(mse)
    
        split_mses.append(mse)
    
    split_mses = np.array(split_mses)
    
    plt.plot(splits, split_mses, label=label)
    return splits[np.argmin(split_mses)]

def binarize_entropy(entropy, thres=0.0):  # 0.0 means even splits for normalized entropy scores
    """Binarize entropy scores into 0s and 1s"""
    binary_entropy = torch.full_like(entropy, -1, dtype=torch.float)
    binary_entropy[entropy < thres] = 0
    binary_entropy[entropy > thres] = 1
    binary_entropy[entropy == thres] = 0  # fix by song: 或者根据需求设置为 1

    return binary_entropy

# %% [markdown]
# ### 二值化语义熵

# %%
# Best universal split across datasets
split_method = 'best-universal-split'
all_entropy = torch.cat([D.entropy for D in Ds], dim=0)
split = best_split(all_entropy, "All datasets collective")
plt.legend()
plt.title('Sum of squared errors at different splits')
for D in Ds:
    D.b_entropy = binarize_entropy(D.entropy, split)
    print(f"Dummy accuracy for {D.name}: {max(torch.mean(D.b_entropy).item(), 1-torch.mean(D.b_entropy).item()):.4f}")
# Out:
# Dummy accuracy for squad: 0.6201
# Dummy accuracy for triviaqa: 0.6597

# %% [markdown]
# ### Train linear probes to predict Binarized SE

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'b_entropy')
    train_single_metric(D, 'slt', 'b_entropy')
# Out:
# Training on squad-TBG-B_ENTROPY 1/29
# Validation Accuracy: 0.6056, AUROC: 0.5000
# Training Loss: 0.6649, Validation Loss: 0.6710
# Test Loss: 0.6448, Test Accuracy: 0.6600, AUROC: 0.5000
# Training on squad-TBG-B_ENTROPY 2/29
# Validation Accuracy: 0.5667, AUROC: 0.5066
# Training Loss: 0.5757, Validation Loss: 0.6935
# Test Loss: 0.6416, Test Accuracy: 0.6350, AUROC: 0.5890
# Training on squad-TBG-B_ENTROPY 3/29
# Validation Accuracy: 0.6472, AUROC: 0.7106
# Training Loss: 0.4634, Validation Loss: 0.5967
# Test Loss: 0.5319, Test Accuracy: 0.7150, AUROC: 0.7824
# Training on squad-TBG-B_ENTROPY 4/29
# Validation Accuracy: 0.6583, AUROC: 0.7108
# Training Loss: 0.4135, Validation Loss: 0.6012
# Test Loss: 0.5575, Test Accuracy: 0.6900, AUROC: 0.7415
# Training on squad-TBG-B_ENTROPY 5/29
# Validation Accuracy: 0.6444, AUROC: 0.7323
# Training Loss: 0.3665, Validation Loss: 0.5904
# Test Loss: 0.5344, Test Accuracy: 0.7050, AUROC: 0.7747
# Training on squad-TBG-B_ENTROPY 6/29
# Validation Accuracy: 0.6806, AUROC: 0.7707
# Training Loss: 0.3080, Validation Loss: 0.5973
# Test Loss: 0.5407, Test Accuracy: 0.7300, AUROC: 0.8021
# Training on squad-TBG-B_ENTROPY 7/29
# Validation Accuracy: 0.6889, AUROC: 0.7759
# Training Loss: 0.2687, Validation Loss: 0.6142
# Test Loss: 0.5702, Test Accuracy: 0.7400, AUROC: 0.7967
# Training on squad-TBG-B_ENTROPY 8/29
# Validation Accuracy: 0.7111, AUROC: 0.7710
# Training Loss: 0.2469, Validation Loss: 0.6392
# Test Loss: 0.6006, Test Accuracy: 0.7400, AUROC: 0.7894
# Training on squad-TBG-B_ENTROPY 9/29
# Validation Accuracy: 0.7000, AUROC: 0.7697
# Training Loss: 0.2057, Validation Loss: 0.6814
# Test Loss: 0.6851, Test Accuracy: 0.7150, AUROC: 0.7753
# Training on squad-TBG-B_ENTROPY 10/29
# Validation Accuracy: 0.7111, AUROC: 0.7723
# Training Loss: 0.1899, Validation Loss: 0.7349
# Test Loss: 0.8012, Test Accuracy: 0.6850, AUROC: 0.7479
# Training on squad-TBG-B_ENTROPY 11/29
# Validation Accuracy: 0.6944, AUROC: 0.7679
# Training Loss: 0.1937, Validation Loss: 0.8039
# Test Loss: 0.7736, Test Accuracy: 0.7200, AUROC: 0.7687
# Training on squad-TBG-B_ENTROPY 12/29
# Validation Accuracy: 0.6972, AUROC: 0.7801
# Training Loss: 0.1759, Validation Loss: 0.7479
# Test Loss: 0.7362, Test Accuracy: 0.7150, AUROC: 0.7794
# Training on squad-TBG-B_ENTROPY 13/29
# Validation Accuracy: 0.7194, AUROC: 0.7841
# Training Loss: 0.1386, Validation Loss: 0.7922
# Test Loss: 0.8314, Test Accuracy: 0.7200, AUROC: 0.7626
# Training on squad-TBG-B_ENTROPY 14/29
# Validation Accuracy: 0.7306, AUROC: 0.7962
# Training Loss: 0.1593, Validation Loss: 0.7599
# Test Loss: 0.9000, Test Accuracy: 0.6900, AUROC: 0.7447
# Training on squad-TBG-B_ENTROPY 15/29
# Validation Accuracy: 0.7306, AUROC: 0.7987
# Training Loss: 0.1399, Validation Loss: 0.7545
# Test Loss: 0.8675, Test Accuracy: 0.6950, AUROC: 0.7531
# Training on squad-TBG-B_ENTROPY 16/29
# Validation Accuracy: 0.7167, AUROC: 0.7804
# Training Loss: 0.1480, Validation Loss: 0.7699
# Test Loss: 0.8500, Test Accuracy: 0.6800, AUROC: 0.7510
# Training on squad-TBG-B_ENTROPY 17/29
# Validation Accuracy: 0.7167, AUROC: 0.7990
# Training Loss: 0.1365, Validation Loss: 0.7608
# Test Loss: 0.7226, Test Accuracy: 0.7450, AUROC: 0.8048
# Training on squad-TBG-B_ENTROPY 18/29
# Validation Accuracy: 0.7333, AUROC: 0.8070
# Training Loss: 0.1071, Validation Loss: 0.7887
# Test Loss: 0.7150, Test Accuracy: 0.7950, AUROC: 0.8277
# Training on squad-TBG-B_ENTROPY 19/29
# Validation Accuracy: 0.7333, AUROC: 0.8250
# Training Loss: 0.1130, Validation Loss: 0.7613
# Test Loss: 0.7500, Test Accuracy: 0.7650, AUROC: 0.8336
# Training on squad-TBG-B_ENTROPY 20/29
# Validation Accuracy: 0.7056, AUROC: 0.8145
# Training Loss: 0.0312, Validation Loss: 0.9860
# Test Loss: 1.0990, Test Accuracy: 0.7600, AUROC: 0.8309
# Training on squad-TBG-B_ENTROPY 21/29
# Validation Accuracy: 0.7194, AUROC: 0.8217
# Training Loss: 0.0180, Validation Loss: 1.1334
# Test Loss: 1.2804, Test Accuracy: 0.7650, AUROC: 0.8204
# Training on squad-TBG-B_ENTROPY 22/29
# Validation Accuracy: 0.7444, AUROC: 0.8320
# Training Loss: 0.0090, Validation Loss: 1.2552
# Test Loss: 1.3657, Test Accuracy: 0.7500, AUROC: 0.8209
# Training on squad-TBG-B_ENTROPY 23/29
# Validation Accuracy: 0.7444, AUROC: 0.8043
# Training Loss: 0.0040, Validation Loss: 1.5041
# Test Loss: 1.2777, Test Accuracy: 0.7500, AUROC: 0.8250
# Training on squad-TBG-B_ENTROPY 24/29
# Validation Accuracy: 0.7111, AUROC: 0.8020
# Training Loss: 0.0021, Validation Loss: 1.7452
# Test Loss: 1.6755, Test Accuracy: 0.7550, AUROC: 0.7970
# Training on squad-TBG-B_ENTROPY 25/29
# Validation Accuracy: 0.7278, AUROC: 0.8022
# Training Loss: 0.0015, Validation Loss: 1.7495
# Test Loss: 1.8116, Test Accuracy: 0.7400, AUROC: 0.8053
# Training on squad-TBG-B_ENTROPY 26/29
# Validation Accuracy: 0.7056, AUROC: 0.7996
# Training Loss: 0.0010, Validation Loss: 1.7609
# Test Loss: 1.7661, Test Accuracy: 0.7050, AUROC: 0.8002
# Training on squad-TBG-B_ENTROPY 27/29
# Validation Accuracy: 0.7139, AUROC: 0.7848
# Training Loss: 0.0006, Validation Loss: 2.0443
# Test Loss: 1.6659, Test Accuracy: 0.7450, AUROC: 0.8151
# Training on squad-TBG-B_ENTROPY 28/29
# Validation Accuracy: 0.7222, AUROC: 0.7990
# Training Loss: 0.0005, Validation Loss: 1.9886
# Test Loss: 2.1375, Test Accuracy: 0.7150, AUROC: 0.7887
# Training on squad-TBG-B_ENTROPY 29/29
# Validation Accuracy: 0.7139, AUROC: 0.7959
# Training Loss: 0.0006, Validation Loss: 1.9808
# Test Loss: 1.9694, Test Accuracy: 0.7550, AUROC: 0.7950
# Training on squad-SLT-B_ENTROPY 1/29
# Validation Accuracy: 0.6528, AUROC: 0.6590
# Training Loss: 0.5546, Validation Loss: 0.6314
# Test Loss: 0.5968, Test Accuracy: 0.7050, AUROC: 0.6897
# Training on squad-SLT-B_ENTROPY 2/29
# Validation Accuracy: 0.6806, AUROC: 0.7104
# Training Loss: 0.1240, Validation Loss: 0.8551
# Test Loss: 0.9156, Test Accuracy: 0.6900, AUROC: 0.6830
# Training on squad-SLT-B_ENTROPY 3/29
# Validation Accuracy: 0.7028, AUROC: 0.7429
# Training Loss: 0.0757, Validation Loss: 0.9724
# Test Loss: 0.9493, Test Accuracy: 0.6850, AUROC: 0.7149
# Training on squad-SLT-B_ENTROPY 4/29
# Validation Accuracy: 0.6944, AUROC: 0.7372
# Training Loss: 0.0540, Validation Loss: 1.0592
# Test Loss: 0.9051, Test Accuracy: 0.7600, AUROC: 0.7818
# Training on squad-SLT-B_ENTROPY 5/29
# Validation Accuracy: 0.6861, AUROC: 0.7651
# Training Loss: 0.0367, Validation Loss: 1.0765
# Test Loss: 0.9845, Test Accuracy: 0.7600, AUROC: 0.7989
# Training on squad-SLT-B_ENTROPY 6/29
# Validation Accuracy: 0.7000, AUROC: 0.7618
# Training Loss: 0.0253, Validation Loss: 1.1621
# Test Loss: 1.0591, Test Accuracy: 0.7600, AUROC: 0.7774
# Training on squad-SLT-B_ENTROPY 7/29
# Validation Accuracy: 0.6972, AUROC: 0.7484
# Training Loss: 0.0223, Validation Loss: 1.2508
# Test Loss: 1.3656, Test Accuracy: 0.7250, AUROC: 0.7312
# Training on squad-SLT-B_ENTROPY 8/29
# Validation Accuracy: 0.7111, AUROC: 0.7558
# Training Loss: 0.0168, Validation Loss: 1.3765
# Test Loss: 1.2497, Test Accuracy: 0.7400, AUROC: 0.7644
# Training on squad-SLT-B_ENTROPY 9/29
# Validation Accuracy: 0.7000, AUROC: 0.7549
# Training Loss: 0.0134, Validation Loss: 1.3606
# Test Loss: 1.2524, Test Accuracy: 0.7050, AUROC: 0.7564
# Training on squad-SLT-B_ENTROPY 10/29
# Validation Accuracy: 0.7417, AUROC: 0.7868
# Training Loss: 0.0094, Validation Loss: 1.2918
# Test Loss: 1.3780, Test Accuracy: 0.6600, AUROC: 0.7491
# Training on squad-SLT-B_ENTROPY 11/29
# Validation Accuracy: 0.7000, AUROC: 0.7583
# Training Loss: 0.0095, Validation Loss: 1.3489
# Test Loss: 1.2206, Test Accuracy: 0.7000, AUROC: 0.7755
# Training on squad-SLT-B_ENTROPY 12/29
# Validation Accuracy: 0.7250, AUROC: 0.7941
# Training Loss: 0.0093, Validation Loss: 1.2270
# Test Loss: 1.2307, Test Accuracy: 0.7000, AUROC: 0.7740
# Training on squad-SLT-B_ENTROPY 13/29
# Validation Accuracy: 0.7361, AUROC: 0.8158
# Training Loss: 0.0082, Validation Loss: 1.1619
# Test Loss: 1.2457, Test Accuracy: 0.7200, AUROC: 0.7723
# Training on squad-SLT-B_ENTROPY 14/29
# Validation Accuracy: 0.7306, AUROC: 0.7910
# Training Loss: 0.0076, Validation Loss: 1.2599
# Test Loss: 1.2562, Test Accuracy: 0.6950, AUROC: 0.7670
# Training on squad-SLT-B_ENTROPY 15/29
# Validation Accuracy: 0.7222, AUROC: 0.7921
# Training Loss: 0.0068, Validation Loss: 1.3593
# Test Loss: 1.1721, Test Accuracy: 0.7300, AUROC: 0.7931
# Training on squad-SLT-B_ENTROPY 16/29
# Validation Accuracy: 0.7250, AUROC: 0.7951
# Training Loss: 0.0062, Validation Loss: 1.3900
# Test Loss: 1.2990, Test Accuracy: 0.6600, AUROC: 0.7748
# Training on squad-SLT-B_ENTROPY 17/29
# Validation Accuracy: 0.7417, AUROC: 0.8089
# Training Loss: 0.0054, Validation Loss: 1.3460
# Test Loss: 1.4592, Test Accuracy: 0.6950, AUROC: 0.7627
# Training on squad-SLT-B_ENTROPY 18/29
# Validation Accuracy: 0.7417, AUROC: 0.8056
# Training Loss: 0.0046, Validation Loss: 1.4586
# Test Loss: 1.3474, Test Accuracy: 0.7500, AUROC: 0.7931
# Training on squad-SLT-B_ENTROPY 19/29
# Validation Accuracy: 0.7583, AUROC: 0.8154
# Training Loss: 0.0040, Validation Loss: 1.3997
# Test Loss: 1.4439, Test Accuracy: 0.7200, AUROC: 0.7916
# Training on squad-SLT-B_ENTROPY 20/29
# Validation Accuracy: 0.7389, AUROC: 0.8017
# Training Loss: 0.0033, Validation Loss: 1.4907
# Test Loss: 1.3468, Test Accuracy: 0.7200, AUROC: 0.7962
# Training on squad-SLT-B_ENTROPY 21/29
# Validation Accuracy: 0.7333, AUROC: 0.8111
# Training Loss: 0.0026, Validation Loss: 1.5197
# Test Loss: 1.4739, Test Accuracy: 0.7150, AUROC: 0.7867
# Training on squad-SLT-B_ENTROPY 22/29
# Validation Accuracy: 0.7500, AUROC: 0.8170
# Training Loss: 0.0019, Validation Loss: 1.4861
# Test Loss: 1.5198, Test Accuracy: 0.7450, AUROC: 0.7955
# Training on squad-SLT-B_ENTROPY 23/29
# Validation Accuracy: 0.7611, AUROC: 0.8198
# Training Loss: 0.0013, Validation Loss: 1.6487
# Test Loss: 1.5597, Test Accuracy: 0.7400, AUROC: 0.8074
# Training on squad-SLT-B_ENTROPY 24/29
# Validation Accuracy: 0.7500, AUROC: 0.8063
# Training Loss: 0.0009, Validation Loss: 1.8457
# Test Loss: 1.6821, Test Accuracy: 0.7150, AUROC: 0.7899
# Training on squad-SLT-B_ENTROPY 25/29
# Validation Accuracy: 0.7333, AUROC: 0.7905
# Training Loss: 0.0006, Validation Loss: 1.8911
# Test Loss: 1.7233, Test Accuracy: 0.7400, AUROC: 0.8000
# Training on squad-SLT-B_ENTROPY 26/29
# Validation Accuracy: 0.7389, AUROC: 0.7770
# Training Loss: 0.0004, Validation Loss: 2.1392
# Test Loss: 1.8452, Test Accuracy: 0.7200, AUROC: 0.7922
# Training on squad-SLT-B_ENTROPY 27/29
# Validation Accuracy: 0.7111, AUROC: 0.7889
# Training Loss: 0.0003, Validation Loss: 1.9465
# Test Loss: 1.9864, Test Accuracy: 0.7050, AUROC: 0.7649
# Training on squad-SLT-B_ENTROPY 28/29
# Validation Accuracy: 0.7389, AUROC: 0.7873
# Training Loss: 0.0002, Validation Loss: 2.0965
# Test Loss: 2.0865, Test Accuracy: 0.7150, AUROC: 0.7678
# Training on squad-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.7111, AUROC: 0.7631
# Test Loss: 1.2914, Test Accuracy: 0.6900, AUROC: 0.7549
# Training on triviaqa-SLT-B_ENTROPY 11/29
# Validation Accuracy: 0.7139, AUROC: 0.7289
# Training Loss: 0.0100, Validation Loss: 1.4814
# Test Loss: 1.6636, Test Accuracy: 0.6950, AUROC: 0.7166
# Training on triviaqa-SLT-B_ENTROPY 12/29
# Validation Accuracy: 0.7333, AUROC: 0.7611
# Training Loss: 0.0102, Validation Loss: 1.3855
# Test Loss: 1.7254, Test Accuracy: 0.7050, AUROC: 0.7122
# Training on triviaqa-SLT-B_ENTROPY 13/29
# Validation Accuracy: 0.7472, AUROC: 0.7761
# Training Loss: 0.0094, Validation Loss: 1.3372
# Test Loss: 1.6750, Test Accuracy: 0.7100, AUROC: 0.7177
# Training on triviaqa-SLT-B_ENTROPY 14/29
# Validation Accuracy: 0.7611, AUROC: 0.7869
# Training Loss: 0.0086, Validation Loss: 1.2367
# Test Loss: 1.6568, Test Accuracy: 0.6900, AUROC: 0.7149
# Training on triviaqa-SLT-B_ENTROPY 15/29
# Validation Accuracy: 0.7667, AUROC: 0.8073
# Training Loss: 0.0080, Validation Loss: 1.1514
# Test Loss: 1.7608, Test Accuracy: 0.7050, AUROC: 0.7157
# Training on triviaqa-SLT-B_ENTROPY 16/29
# Validation Accuracy: 0.7333, AUROC: 0.8002
# Training Loss: 0.0072, Validation Loss: 1.3143
# Test Loss: 1.6658, Test Accuracy: 0.7150, AUROC: 0.7269
# Training on triviaqa-SLT-B_ENTROPY 17/29
# Validation Accuracy: 0.7333, AUROC: 0.7924
# Training Loss: 0.0067, Validation Loss: 1.3106
# Test Loss: 1.6273, Test Accuracy: 0.7150, AUROC: 0.7364
# Training on triviaqa-SLT-B_ENTROPY 18/29
# Validation Accuracy: 0.7444, AUROC: 0.8071
# Training Loss: 0.0055, Validation Loss: 1.2413
# Test Loss: 1.5842, Test Accuracy: 0.7350, AUROC: 0.7508
# Training on triviaqa-SLT-B_ENTROPY 19/29
# Validation Accuracy: 0.7472, AUROC: 0.7936
# Training Loss: 0.0049, Validation Loss: 1.3559
# Test Loss: 1.4645, Test Accuracy: 0.7850, AUROC: 0.7699
# Training on triviaqa-SLT-B_ENTROPY 20/29
# Validation Accuracy: 0.7472, AUROC: 0.8065
# Training Loss: 0.0045, Validation Loss: 1.2836
# Test Loss: 1.5090, Test Accuracy: 0.7550, AUROC: 0.7812
# Training on triviaqa-SLT-B_ENTROPY 21/29
# Validation Accuracy: 0.7361, AUROC: 0.7925
# Training Loss: 0.0036, Validation Loss: 1.3524
# Test Loss: 1.6209, Test Accuracy: 0.7250, AUROC: 0.7654
# Training on triviaqa-SLT-B_ENTROPY 22/29
# Validation Accuracy: 0.7167, AUROC: 0.7979
# Training Loss: 0.0030, Validation Loss: 1.4160
# Test Loss: 1.5359, Test Accuracy: 0.7600, AUROC: 0.7968
# Training on triviaqa-SLT-B_ENTROPY 23/29
# Validation Accuracy: 0.7389, AUROC: 0.7850
# Training Loss: 0.0024, Validation Loss: 1.6099
# Test Loss: 1.8041, Test Accuracy: 0.7300, AUROC: 0.7665
# Training on triviaqa-SLT-B_ENTROPY 24/29
# Validation Accuracy: 0.6944, AUROC: 0.7688
# Training Loss: 0.0019, Validation Loss: 1.7973
# Test Loss: 2.1403, Test Accuracy: 0.7150, AUROC: 0.7500
# Training on triviaqa-SLT-B_ENTROPY 25/29
# Validation Accuracy: 0.7111, AUROC: 0.8000
# Training Loss: 0.0016, Validation Loss: 1.6082
# Test Loss: 2.3874, Test Accuracy: 0.7400, AUROC: 0.7387
# Training on triviaqa-SLT-B_ENTROPY 26/29
# Validation Accuracy: 0.7250, AUROC: 0.7900
# Training Loss: 0.0014, Validation Loss: 1.6836
# Test Loss: 2.3235, Test Accuracy: 0.7300, AUROC: 0.7540
# Training on triviaqa-SLT-B_ENTROPY 27/29
# Validation Accuracy: 0.7194, AUROC: 0.7609
# Training Loss: 0.0013, Validation Loss: 2.0421
# Test Loss: 2.4622, Test Accuracy: 0.7050, AUROC: 0.7457
# Training on triviaqa-SLT-B_ENTROPY 28/29
# Validation Accuracy: 0.7111, AUROC: 0.7499
# Training Loss: 0.0013, Validation Loss: 2.1133
# Test Loss: 2.4902, Test Accuracy: 0.6950, AUROC: 0.7412
# Training on triviaqa-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.7000, AUROC: 0.7369
# Training Loss: 0.0013, Validation Loss: 1.9650
# Test Loss: 2.2874, Test Accuracy: 0.7050, AUROC: 0.7249

# %%
# plot se probe
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.tb_aucs), auc(D.sb_aucs)], ["SE Probe on TBG token", "SE Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="se_both_tok")
plt.show()

# %% [markdown]
# ### Train linear probes to predict Accuracy

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'accuracies')
    train_single_metric(D, 'slt', 'accuracies')
# Out:
# Training on squad-TBG-ACCURACIES 1/29
# Validation Accuracy: 0.5833, AUROC: 0.5000
# Training Loss: 0.6789, Validation Loss: 0.6792
# Test Loss: 0.6820, Test Accuracy: 0.5750, AUROC: 0.5000
# Training on squad-TBG-ACCURACIES 2/29
# Validation Accuracy: 0.6000, AUROC: 0.6306
# Training Loss: 0.5612, Validation Loss: 0.6543
# Test Loss: 0.6711, Test Accuracy: 0.6000, AUROC: 0.6176
# Training on squad-TBG-ACCURACIES 3/29
# Validation Accuracy: 0.7500, AUROC: 0.7960
# Training Loss: 0.4119, Validation Loss: 0.5303
# Test Loss: 0.5339, Test Accuracy: 0.7600, AUROC: 0.8002
# Training on squad-TBG-ACCURACIES 4/29
# Validation Accuracy: 0.7833, AUROC: 0.8109
# Training Loss: 0.3505, Validation Loss: 0.5218
# Test Loss: 0.5434, Test Accuracy: 0.7500, AUROC: 0.7931
# Training on squad-TBG-ACCURACIES 5/29
# Validation Accuracy: 0.7861, AUROC: 0.8347
# Training Loss: 0.2934, Validation Loss: 0.4953
# Test Loss: 0.5151, Test Accuracy: 0.7900, AUROC: 0.8209
# Training on squad-TBG-ACCURACIES 6/29
# Validation Accuracy: 0.8222, AUROC: 0.8762
# Training Loss: 0.2212, Validation Loss: 0.4531
# Test Loss: 0.5335, Test Accuracy: 0.8000, AUROC: 0.8392
# Training on squad-TBG-ACCURACIES 7/29
# Validation Accuracy: 0.8056, AUROC: 0.8652
# Training Loss: 0.1975, Validation Loss: 0.4998
# Test Loss: 0.5700, Test Accuracy: 0.8300, AUROC: 0.8373
# Training on squad-TBG-ACCURACIES 8/29
# Validation Accuracy: 0.8028, AUROC: 0.8638
# Training Loss: 0.1798, Validation Loss: 0.5301
# Test Loss: 0.5804, Test Accuracy: 0.8300, AUROC: 0.8414
# Training on squad-TBG-ACCURACIES 9/29
# Validation Accuracy: 0.8028, AUROC: 0.8619
# Training Loss: 0.1595, Validation Loss: 0.5472
# Test Loss: 0.5817, Test Accuracy: 0.8300, AUROC: 0.8469
# Training on squad-TBG-ACCURACIES 10/29
# Validation Accuracy: 0.8167, AUROC: 0.8554
# Training Loss: 0.1268, Validation Loss: 0.5679
# Test Loss: 0.5982, Test Accuracy: 0.8100, AUROC: 0.8515
# Training on squad-TBG-ACCURACIES 11/29
# Validation Accuracy: 0.7972, AUROC: 0.8448
# Training Loss: 0.1209, Validation Loss: 0.6015
# Test Loss: 0.5505, Test Accuracy: 0.8100, AUROC: 0.8599
# Training on squad-TBG-ACCURACIES 12/29
# Validation Accuracy: 0.7917, AUROC: 0.8574
# Training Loss: 0.1219, Validation Loss: 0.5936
# Test Loss: 0.5336, Test Accuracy: 0.8350, AUROC: 0.8697
# Training on squad-TBG-ACCURACIES 13/29
# Validation Accuracy: 0.8111, AUROC: 0.8585
# Training Loss: 0.1209, Validation Loss: 0.6230
# Test Loss: 0.5647, Test Accuracy: 0.8000, AUROC: 0.8691
# Training on squad-TBG-ACCURACIES 14/29
# Validation Accuracy: 0.8111, AUROC: 0.8628
# Training Loss: 0.0980, Validation Loss: 0.5982
# Test Loss: 0.5976, Test Accuracy: 0.8050, AUROC: 0.8629
# Training on squad-TBG-ACCURACIES 15/29
# Validation Accuracy: 0.8444, AUROC: 0.8739
# Training Loss: 0.0739, Validation Loss: 0.5744
# Test Loss: 0.6537, Test Accuracy: 0.8000, AUROC: 0.8581
# Training on squad-TBG-ACCURACIES 16/29
# Validation Accuracy: 0.8167, AUROC: 0.8747
# Training Loss: 0.1131, Validation Loss: 0.5885
# Test Loss: 0.6441, Test Accuracy: 0.8050, AUROC: 0.8703
# Training on squad-TBG-ACCURACIES 17/29
# Validation Accuracy: 0.8111, AUROC: 0.8786
# Training Loss: 0.0872, Validation Loss: 0.6362
# Test Loss: 0.6840, Test Accuracy: 0.8400, AUROC: 0.8697
# Training on squad-TBG-ACCURACIES 18/29
# Validation Accuracy: 0.8250, AUROC: 0.8914
# Training Loss: 0.0518, Validation Loss: 0.5870
# Test Loss: 0.6912, Test Accuracy: 0.8500, AUROC: 0.8710
# Training on squad-TBG-ACCURACIES 19/29
# Validation Accuracy: 0.8028, AUROC: 0.8896
# Training Loss: 0.0369, Validation Loss: 0.6453
# Test Loss: 0.7324, Test Accuracy: 0.8250, AUROC: 0.8731
# Training on squad-TBG-ACCURACIES 20/29
# Validation Accuracy: 0.8056, AUROC: 0.8934
# Training Loss: 0.0166, Validation Loss: 0.6666
# Test Loss: 0.7439, Test Accuracy: 0.8050, AUROC: 0.8909
# Training on squad-TBG-ACCURACIES 21/29
# Validation Accuracy: 0.8111, AUROC: 0.8878
# Training Loss: 0.0099, Validation Loss: 0.8652
# Test Loss: 0.8217, Test Accuracy: 0.8200, AUROC: 0.8892
# Training on squad-TBG-ACCURACIES 22/29
# Validation Accuracy: 0.8083, AUROC: 0.8729
# Training Loss: 0.0050, Validation Loss: 0.9441
# Test Loss: 0.8604, Test Accuracy: 0.8350, AUROC: 0.8936
# Training on squad-TBG-ACCURACIES 23/29
# Validation Accuracy: 0.8278, AUROC: 0.8734
# Training Loss: 0.0021, Validation Loss: 0.9661
# Test Loss: 0.8935, Test Accuracy: 0.8250, AUROC: 0.8841
# Training on squad-TBG-ACCURACIES 24/29
# Validation Accuracy: 0.8222, AUROC: 0.8893
# Training Loss: 0.0011, Validation Loss: 0.9320
# Test Loss: 1.0409, Test Accuracy: 0.8400, AUROC: 0.8819
# Training on squad-TBG-ACCURACIES 25/29
# Validation Accuracy: 0.8278, AUROC: 0.8939
# Training Loss: 0.0006, Validation Loss: 0.9529
# Test Loss: 1.1113, Test Accuracy: 0.8550, AUROC: 0.8807
# Training on squad-TBG-ACCURACIES 26/29
# Validation Accuracy: 0.7944, AUROC: 0.8759
# Training Loss: 0.0004, Validation Loss: 1.1146
# Test Loss: 1.2736, Test Accuracy: 0.8150, AUROC: 0.8737
# Training on squad-TBG-ACCURACIES 27/29
# Validation Accuracy: 0.8167, AUROC: 0.8746
# Training Loss: 0.0003, Validation Loss: 1.2622
# Test Loss: 1.1336, Test Accuracy: 0.8150, AUROC: 0.8785
# Training on squad-TBG-ACCURACIES 28/29
# Validation Accuracy: 0.8028, AUROC: 0.8619
# Training Loss: 0.0002, Validation Loss: 1.3448
# Test Loss: 1.1400, Test Accuracy: 0.8300, AUROC: 0.8866
# Training on squad-TBG-ACCURACIES 29/29
# Validation Accuracy: 0.7944, AUROC: 0.8741
# Training Loss: 0.0003, Validation Loss: 1.1916
# Test Loss: 1.0647, Test Accuracy: 0.8250, AUROC: 0.8866
# Training on squad-SLT-ACCURACIES 1/29
# Validation Accuracy: 0.6583, AUROC: 0.7179
# Training Loss: 0.5400, Validation Loss: 0.6080
# Test Loss: 0.6274, Test Accuracy: 0.6350, AUROC: 0.6878
# Training on squad-SLT-ACCURACIES 2/29
# Validation Accuracy: 0.7000, AUROC: 0.7610
# Training Loss: 0.0946, Validation Loss: 0.7489
# Test Loss: 0.7845, Test Accuracy: 0.6650, AUROC: 0.7574
# Training on squad-SLT-ACCURACIES 3/29
# Validation Accuracy: 0.7528, AUROC: 0.8238
# Training Loss: 0.0515, Validation Loss: 0.6830
# Test Loss: 0.8373, Test Accuracy: 0.7350, AUROC: 0.7925
# Training on squad-SLT-ACCURACIES 4/29
# Validation Accuracy: 0.7472, AUROC: 0.8201
# Training Loss: 0.0347, Validation Loss: 0.7986
# Test Loss: 1.0693, Test Accuracy: 0.7200, AUROC: 0.7705
# Training on squad-SLT-ACCURACIES 5/29
# Validation Accuracy: 0.7694, AUROC: 0.8186
# Training Loss: 0.0213, Validation Loss: 0.8880
# Test Loss: 0.9809, Test Accuracy: 0.7500, AUROC: 0.8169
# Training on squad-SLT-ACCURACIES 6/29
# Validation Accuracy: 0.7722, AUROC: 0.8233
# Training Loss: 0.0136, Validation Loss: 0.8837
# Test Loss: 0.9918, Test Accuracy: 0.7600, AUROC: 0.8086
# Training on squad-SLT-ACCURACIES 7/29
# Validation Accuracy: 0.7639, AUROC: 0.8268
# Training Loss: 0.0116, Validation Loss: 0.9022
# Test Loss: 0.9037, Test Accuracy: 0.7450, AUROC: 0.8219
# Training on squad-SLT-ACCURACIES 8/29
# Validation Accuracy: 0.7278, AUROC: 0.8070
# Training Loss: 0.0087, Validation Loss: 1.0916
# Test Loss: 1.0416, Test Accuracy: 0.7600, AUROC: 0.8201
# Training on squad-SLT-ACCURACIES 9/29
# Validation Accuracy: 0.7556, AUROC: 0.8262
# Training Loss: 0.0071, Validation Loss: 1.0012
# Test Loss: 1.0592, Test Accuracy: 0.7650, AUROC: 0.8179
# Training on squad-SLT-ACCURACIES 10/29
# Validation Accuracy: 0.7806, AUROC: 0.8510
# Training Loss: 0.0051, Validation Loss: 0.9267
# Test Loss: 1.0754, Test Accuracy: 0.7300, AUROC: 0.8191
# Training on squad-SLT-ACCURACIES 11/29
# Validation Accuracy: 0.7694, AUROC: 0.8374
# Training Loss: 0.0049, Validation Loss: 0.9291
# Test Loss: 1.0478, Test Accuracy: 0.7450, AUROC: 0.8266
# Training on squad-SLT-ACCURACIES 12/29
# Validation Accuracy: 0.7833, AUROC: 0.8513
# Training Loss: 0.0051, Validation Loss: 0.9262
# Test Loss: 1.0665, Test Accuracy: 0.7750, AUROC: 0.8259
# Training on squad-SLT-ACCURACIES 13/29
# Validation Accuracy: 0.7889, AUROC: 0.8640
# Training Loss: 0.0044, Validation Loss: 0.8765
# Test Loss: 0.9757, Test Accuracy: 0.7850, AUROC: 0.8548
# Training on squad-SLT-ACCURACIES 14/29
# Validation Accuracy: 0.8194, AUROC: 0.8896
# Training Loss: 0.0041, Validation Loss: 0.7348
# Test Loss: 0.8380, Test Accuracy: 0.8350, AUROC: 0.8791
# Training on squad-SLT-ACCURACIES 15/29
# Validation Accuracy: 0.8083, AUROC: 0.8938
# Training Loss: 0.0036, Validation Loss: 0.7338
# Test Loss: 0.9394, Test Accuracy: 0.8100, AUROC: 0.8655
# Training on squad-SLT-ACCURACIES 16/29
# Validation Accuracy: 0.8444, AUROC: 0.8994
# Training Loss: 0.0036, Validation Loss: 0.7286
# Test Loss: 0.9246, Test Accuracy: 0.8000, AUROC: 0.8739
# Training on squad-SLT-ACCURACIES 17/29
# Validation Accuracy: 0.8444, AUROC: 0.9060
# Training Loss: 0.0031, Validation Loss: 0.6951
# Test Loss: 0.9544, Test Accuracy: 0.8000, AUROC: 0.8748
# Training on squad-SLT-ACCURACIES 18/29
# Validation Accuracy: 0.8333, AUROC: 0.9068
# Training Loss: 0.0025, Validation Loss: 0.7152
# Test Loss: 0.9769, Test Accuracy: 0.8150, AUROC: 0.8749
# Training on squad-SLT-ACCURACIES 19/29
# Validation Accuracy: 0.8389, AUROC: 0.9066
# Training Loss: 0.0022, Validation Loss: 0.7015
# Test Loss: 0.9150, Test Accuracy: 0.8050, AUROC: 0.8861
# Training on squad-SLT-ACCURACIES 20/29
# Validation Accuracy: 0.8333, AUROC: 0.9064
# Training Loss: 0.0019, Validation Loss: 0.6944
# Test Loss: 0.7881, Test Accuracy: 0.8350, AUROC: 0.8933
# Training on squad-SLT-ACCURACIES 21/29
# Validation Accuracy: 0.8361, AUROC: 0.9097
# Training Loss: 0.0016, Validation Loss: 0.7133
# Test Loss: 0.8057, Test Accuracy: 0.8500, AUROC: 0.8925
# Training on squad-SLT-ACCURACIES 22/29
# Validation Accuracy: 0.8278, AUROC: 0.8982
# Training Loss: 0.0012, Validation Loss: 0.8206
# Test Loss: 0.8880, Test Accuracy: 0.7950, AUROC: 0.8890
# Training on squad-SLT-ACCURACIES 23/29
# Validation Accuracy: 0.8194, AUROC: 0.8934
# Training Loss: 0.0009, Validation Loss: 0.8531
# Test Loss: 0.9559, Test Accuracy: 0.8150, AUROC: 0.8873
# Training on squad-SLT-ACCURACIES 24/29
# Validation Accuracy: 0.8139, AUROC: 0.8942
# Training Loss: 0.0006, Validation Loss: 0.9098
# Test Loss: 1.1142, Test Accuracy: 0.8300, AUROC: 0.8642
# Training on squad-SLT-ACCURACIES 25/29
# Validation Accuracy: 0.8111, AUROC: 0.8701
# Training Loss: 0.0004, Validation Loss: 1.1403
# Test Loss: 1.2242, Test Accuracy: 0.8100, AUROC: 0.8639
# Training on squad-SLT-ACCURACIES 26/29
# Validation Accuracy: 0.8083, AUROC: 0.8732
# Training Loss: 0.0003, Validation Loss: 1.1638
# Test Loss: 1.2958, Test Accuracy: 0.7650, AUROC: 0.8553
# Training on squad-SLT-ACCURACIES 27/29
# Validation Accuracy: 0.8083, AUROC: 0.8796
# Training Loss: 0.0002, Validation Loss: 1.1050
# Test Loss: 1.2059, Test Accuracy: 0.7850, AUROC: 0.8638
# Training on squad-SLT-ACCURACIES 28/29
# Validation Accuracy: 0.7722, AUROC: 0.8651
# Training Loss: 0.0001, Validation Loss: 1.1960
# Test Loss: 1.3354, Test Accuracy: 0.7600, AUROC: 0.8563
# Training on squad-SLT-ACCURACIES 29/29
# Validation Accuracy: 0.7639, AUROC: 0.8547
# Training Loss: 0.0003, Validation Loss: 1.1016
# Test Loss: 1.3103, Test Accuracy: 0.7700, AUROC: 0.8468
# Training on triviaqa-TBG-ACCURACIES 1/29
# Validation Accuracy: 0.6083, AUROC: 0.5000
# Training Loss: 0.6718, Validation Loss: 0.6695
# Test Loss: 0.6647, Test Accuracy: 0.6200, AUROC: 0.5000
# Training on triviaqa-TBG-ACCURACIES 2/29
# Validation Accuracy: 0.6528, AUROC: 0.6652
# Validation Accuracy: 0.7806, AUROC: 0.8724
# Training Loss: 0.0003, Validation Loss: 0.8943
# Test Loss: 1.5806, Test Accuracy: 0.7550, AUROC: 0.7992
# Training on triviaqa-SLT-ACCURACIES 27/29
# Validation Accuracy: 0.7889, AUROC: 0.8671
# Training Loss: 0.0002, Validation Loss: 0.9673
# Test Loss: 1.6463, Test Accuracy: 0.7550, AUROC: 0.8018
# Training on triviaqa-SLT-ACCURACIES 28/29
# Validation Accuracy: 0.8028, AUROC: 0.8560
# Training Loss: 0.0002, Validation Loss: 1.1213
# Test Loss: 1.8284, Test Accuracy: 0.7200, AUROC: 0.7840
# Training on triviaqa-SLT-ACCURACIES 29/29
# Validation Accuracy: 0.7778, AUROC: 0.8295
# Training Loss: 0.0003, Validation Loss: 1.2623
# Test Loss: 1.6651, Test Accuracy: 0.7300, AUROC: 0.7897

# %%
# plot acc probe
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.ta_aucs), auc(D.sa_aucs)], ["Acc Probe on TBG token", "Acc Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="acc_both_tok")
plt.show()

# %% [markdown]
# ### Use linear probe trained on Binarized SE to predict Accuracy
#
# We leverage trained probes on semantic entropy to predict model correctness on the same dataset.
#
# Note that we need to predict the error rate (1 minus accuracy) using SEPs due to the nature of semantic uncertainty.

# %%
for D in Ds:
    r_acc = 1 - D.accuracies
    
    # TBG
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.tbg_dataset, r_acc) 
    tab_accs = []
    tab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-TBG {i+1}/{len(X_tests)}")
        model = D.tb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        tab_accs.append(test_acc)
        tab_aucs.append(test_auc)

    D.tab_accs = tab_accs
    D.tab_aucs = tab_aucs

    # SLT t
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.slt_dataset, r_acc)     
    sab_accs = []
    sab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-SLT {i+1}/{len(X_tests)}")
        model = D.sb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        sab_accs.append(test_acc)
        sab_aucs.append(test_auc)

    D.sab_accs = sab_accs
    D.sab_aucs = sab_aucs
# Out:
# Testing on squad-TBG 1/29
# Test Loss: 0.7581, Test Accuracy: 0.4250, AUROC: 0.5000
# Testing on squad-TBG 2/29
# Test Loss: 0.7453, Test Accuracy: 0.4800, AUROC: 0.6114
# Testing on squad-TBG 3/29
# Test Loss: 0.6325, Test Accuracy: 0.5800, AUROC: 0.7766
# Testing on squad-TBG 4/29
# Test Loss: 0.6441, Test Accuracy: 0.6150, AUROC: 0.7789
# Testing on squad-TBG 5/29
# Test Loss: 0.6166, Test Accuracy: 0.6200, AUROC: 0.8218
# Testing on squad-TBG 6/29
# Test Loss: 0.6740, Test Accuracy: 0.7050, AUROC: 0.8497
# Testing on squad-TBG 7/29
# Test Loss: 0.7165, Test Accuracy: 0.6650, AUROC: 0.8318
# Testing on squad-TBG 8/29
# Test Loss: 0.7600, Test Accuracy: 0.6650, AUROC: 0.8232
# Testing on squad-TBG 9/29
# Test Loss: 0.8582, Test Accuracy: 0.6700, AUROC: 0.8255
# Testing on squad-TBG 10/29
# Test Loss: 0.8744, Test Accuracy: 0.7100, AUROC: 0.8225
# Testing on squad-TBG 11/29
# Test Loss: 0.9382, Test Accuracy: 0.6750, AUROC: 0.8318
# Testing on squad-TBG 12/29
# Test Loss: 0.8487, Test Accuracy: 0.6600, AUROC: 0.8327
# Testing on squad-TBG 13/29
# Test Loss: 0.9182, Test Accuracy: 0.6550, AUROC: 0.8311
# Testing on squad-TBG 14/29
# Test Loss: 0.9921, Test Accuracy: 0.6550, AUROC: 0.8186
# Testing on squad-TBG 15/29
# Test Loss: 1.0155, Test Accuracy: 0.6400, AUROC: 0.7959
# Testing on squad-TBG 16/29
# Test Loss: 0.9508, Test Accuracy: 0.6650, AUROC: 0.8034
# Testing on squad-TBG 17/29
# Test Loss: 1.0344, Test Accuracy: 0.6600, AUROC: 0.8059
# Testing on squad-TBG 18/29
# Test Loss: 1.1206, Test Accuracy: 0.6800, AUROC: 0.8150
# Testing on squad-TBG 19/29
# Test Loss: 1.2918, Test Accuracy: 0.6500, AUROC: 0.8223
# Testing on squad-TBG 20/29
# Test Loss: 1.7982, Test Accuracy: 0.6750, AUROC: 0.8386
# Testing on squad-TBG 21/29
# Test Loss: 2.0025, Test Accuracy: 0.6800, AUROC: 0.8318
# Testing on squad-TBG 22/29
# Test Loss: 2.1946, Test Accuracy: 0.6750, AUROC: 0.8450
# Testing on squad-TBG 23/29
# Test Loss: 2.3769, Test Accuracy: 0.6650, AUROC: 0.8295
# Testing on squad-TBG 24/29
# Test Loss: 2.6086, Test Accuracy: 0.6700, AUROC: 0.8317
# Testing on squad-TBG 25/29
# Test Loss: 2.9219, Test Accuracy: 0.6750, AUROC: 0.8355
# Testing on squad-TBG 26/29
# Test Loss: 3.1344, Test Accuracy: 0.6600, AUROC: 0.8262
# Testing on squad-TBG 27/29
# Test Loss: 2.9452, Test Accuracy: 0.6700, AUROC: 0.8254
# Testing on squad-TBG 28/29
# Test Loss: 3.3335, Test Accuracy: 0.6500, AUROC: 0.8146
# Testing on squad-TBG 29/29
# Test Loss: 3.1354, Test Accuracy: 0.7000, AUROC: 0.8144
# Testing on squad-SLT 1/29
# Test Loss: 0.7587, Test Accuracy: 0.4900, AUROC: 0.6034
# Testing on squad-SLT 2/29
# Test Loss: 1.2037, Test Accuracy: 0.5950, AUROC: 0.6651
# Testing on squad-SLT 3/29
# Test Loss: 1.2720, Test Accuracy: 0.6100, AUROC: 0.7425
# Testing on squad-SLT 4/29
# Test Loss: 1.4925, Test Accuracy: 0.6250, AUROC: 0.7363
# Testing on squad-SLT 5/29
# Test Loss: 1.7074, Test Accuracy: 0.6350, AUROC: 0.7458
# Testing on squad-SLT 6/29
# Test Loss: 1.6542, Test Accuracy: 0.6350, AUROC: 0.7647
# Testing on squad-SLT 7/29
# Test Loss: 1.7679, Test Accuracy: 0.6300, AUROC: 0.7417
# Testing on squad-SLT 8/29
# Test Loss: 1.8089, Test Accuracy: 0.6350, AUROC: 0.7601
# Testing on squad-SLT 9/29
# Test Loss: 1.8544, Test Accuracy: 0.6300, AUROC: 0.7545
# Testing on squad-SLT 10/29
# Test Loss: 1.8553, Test Accuracy: 0.6250, AUROC: 0.7733
# Testing on squad-SLT 11/29
# Test Loss: 1.8103, Test Accuracy: 0.6650, AUROC: 0.7713
# Testing on squad-SLT 12/29
# Test Loss: 1.6409, Test Accuracy: 0.6750, AUROC: 0.7957
# Testing on squad-SLT 13/29
# Test Loss: 1.7915, Test Accuracy: 0.6750, AUROC: 0.7966
# Testing on squad-SLT 14/29
# Test Loss: 1.7509, Test Accuracy: 0.6200, AUROC: 0.7890
# Testing on squad-SLT 15/29
# Test Loss: 1.7330, Test Accuracy: 0.6650, AUROC: 0.8081
# Testing on squad-SLT 16/29
# Test Loss: 1.7341, Test Accuracy: 0.6650, AUROC: 0.8203
# Testing on squad-SLT 17/29
# Test Loss: 1.9207, Test Accuracy: 0.6600, AUROC: 0.8163
# Testing on squad-SLT 18/29
# Test Loss: 1.8707, Test Accuracy: 0.6750, AUROC: 0.8252
# Testing on squad-SLT 19/29
# Test Loss: 1.8007, Test Accuracy: 0.6650, AUROC: 0.8346
# Testing on squad-SLT 20/29
# Test Loss: 1.5810, Test Accuracy: 0.6850, AUROC: 0.8591
# Testing on squad-SLT 21/29
# Test Loss: 1.7888, Test Accuracy: 0.6900, AUROC: 0.8519
# Testing on squad-SLT 22/29
# Test Loss: 1.8197, Test Accuracy: 0.7100, AUROC: 0.8539
# Testing on squad-SLT 23/29
# Test Loss: 2.2173, Test Accuracy: 0.6950, AUROC: 0.8285
# Testing on squad-SLT 24/29
# Test Loss: 2.1441, Test Accuracy: 0.6600, AUROC: 0.8229
# Testing on squad-SLT 25/29
# Test Loss: 2.4568, Test Accuracy: 0.6450, AUROC: 0.8088
# Testing on squad-SLT 26/29
# Test Loss: 2.6766, Test Accuracy: 0.6550, AUROC: 0.8065
# Testing on squad-SLT 27/29
# Test Loss: 2.5774, Test Accuracy: 0.6600, AUROC: 0.8107
# Testing on squad-SLT 28/29
# Test Loss: 2.6240, Test Accuracy: 0.6700, AUROC: 0.8282
# Testing on squad-SLT 29/29
# Test Loss: 2.3968, Test Accuracy: 0.6600, AUROC: 0.8126
# Testing on triviaqa-TBG 1/29
# Test Loss: 0.6671, Test Accuracy: 0.6200, AUROC: 0.5000
# Testing on triviaqa-TBG 2/29
# Test Loss: 0.6830, Test Accuracy: 0.6150, AUROC: 0.5871
# Testing on triviaqa-TBG 3/29
# Test Loss: 0.6543, Test Accuracy: 0.6700, AUROC: 0.6544
# Testing on triviaqa-TBG 4/29
# Test Loss: 0.6599, Test Accuracy: 0.6800, AUROC: 0.6723
# Testing on triviaqa-TBG 5/29
# Test Loss: 0.6400, Test Accuracy: 0.7100, AUROC: 0.7147
# Testing on triviaqa-TBG 6/29
# Test Loss: 0.7370, Test Accuracy: 0.6950, AUROC: 0.6878
# Testing on triviaqa-TBG 7/29
# Test Loss: 0.8000, Test Accuracy: 0.6750, AUROC: 0.6831
# Testing on triviaqa-TBG 8/29
# Test Loss: 0.8543, Test Accuracy: 0.6800, AUROC: 0.6822
# Testing on triviaqa-TBG 9/29
# Test Loss: 0.7731, Test Accuracy: 0.7000, AUROC: 0.7166
# Testing on triviaqa-TBG 10/29
# Test Loss: 0.8399, Test Accuracy: 0.7050, AUROC: 0.7309
# Testing on triviaqa-TBG 11/29
# Test Loss: 0.8464, Test Accuracy: 0.7250, AUROC: 0.7539
# Testing on triviaqa-TBG 12/29
# Test Loss: 0.7413, Test Accuracy: 0.7400, AUROC: 0.7650
# Testing on triviaqa-TBG 13/29
# Test Loss: 0.8958, Test Accuracy: 0.7200, AUROC: 0.7323
# Testing on triviaqa-TBG 14/29
# Test Loss: 0.7803, Test Accuracy: 0.7150, AUROC: 0.7774
# Testing on triviaqa-TBG 15/29
# Test Loss: 0.7887, Test Accuracy: 0.7200, AUROC: 0.7853
# Testing on triviaqa-TBG 16/29
# Test Loss: 0.7577, Test Accuracy: 0.7200, AUROC: 0.7828
# Testing on triviaqa-TBG 17/29
# Test Loss: 0.8171, Test Accuracy: 0.7250, AUROC: 0.7863
# Testing on triviaqa-TBG 18/29
# Test Loss: 0.8850, Test Accuracy: 0.7450, AUROC: 0.7841
# Testing on triviaqa-TBG 19/29
# Test Loss: 0.9239, Test Accuracy: 0.7100, AUROC: 0.7841
# Testing on triviaqa-TBG 20/29
# Test Loss: 1.3134, Test Accuracy: 0.6950, AUROC: 0.7574
# Testing on triviaqa-TBG 21/29
# Test Loss: 1.4683, Test Accuracy: 0.6550, AUROC: 0.7450
# Testing on triviaqa-TBG 22/29
# Test Loss: 1.5586, Test Accuracy: 0.7000, AUROC: 0.7584
# Testing on triviaqa-TBG 23/29
# Test Loss: 1.6639, Test Accuracy: 0.6950, AUROC: 0.7775
# Testing on triviaqa-TBG 24/29
# Test Loss: 1.6841, Test Accuracy: 0.7350, AUROC: 0.7883
# Testing on triviaqa-TBG 25/29
# Test Loss: 2.1069, Test Accuracy: 0.7250, AUROC: 0.7787
# Testing on triviaqa-TBG 26/29
# Test Loss: 2.2822, Test Accuracy: 0.6900, AUROC: 0.7475
# Testing on triviaqa-TBG 27/29
# Test Loss: 2.5969, Test Accuracy: 0.6850, AUROC: 0.7272
# Testing on triviaqa-TBG 28/29
# Test Loss: 2.7783, Test Accuracy: 0.7150, AUROC: 0.7539
# Testing on triviaqa-TBG 29/29
# Test Loss: 2.2096, Test Accuracy: 0.6850, AUROC: 0.7520
# Testing on triviaqa-SLT 1/29
# Test Loss: 0.6193, Test Accuracy: 0.6350, AUROC: 0.6994
# Testing on triviaqa-SLT 2/29
# Test Loss: 0.8837, Test Accuracy: 0.7050, AUROC: 0.7233
# Testing on triviaqa-SLT 3/29
# Test Loss: 0.9488, Test Accuracy: 0.7050, AUROC: 0.7423
# Testing on triviaqa-SLT 4/29
# Test Loss: 1.1582, Test Accuracy: 0.7250, AUROC: 0.7295
# Testing on triviaqa-SLT 5/29
# Test Loss: 1.1407, Test Accuracy: 0.7200, AUROC: 0.7618
# Testing on triviaqa-SLT 6/29
# Test Loss: 1.2728, Test Accuracy: 0.7050, AUROC: 0.7608
# Testing on triviaqa-SLT 7/29
# Test Loss: 1.3293, Test Accuracy: 0.7250, AUROC: 0.7545
# Testing on triviaqa-SLT 8/29
# Test Loss: 1.3449, Test Accuracy: 0.7000, AUROC: 0.7423
# Testing on triviaqa-SLT 9/29
# Test Loss: 1.4962, Test Accuracy: 0.7200, AUROC: 0.7275
# Testing on triviaqa-SLT 10/29
# Test Loss: 1.3702, Test Accuracy: 0.7100, AUROC: 0.7599
# Testing on triviaqa-SLT 11/29
# Test Loss: 1.5896, Test Accuracy: 0.7150, AUROC: 0.7521
# Testing on triviaqa-SLT 12/29
# Test Loss: 1.5782, Test Accuracy: 0.7450, AUROC: 0.7639
# Testing on triviaqa-SLT 13/29
# Test Loss: 1.6105, Test Accuracy: 0.7100, AUROC: 0.7572
# Testing on triviaqa-SLT 14/29
# Test Loss: 1.5538, Test Accuracy: 0.6900, AUROC: 0.7675
# Testing on triviaqa-SLT 15/29
# Test Loss: 1.7061, Test Accuracy: 0.6950, AUROC: 0.7550
# Testing on triviaqa-SLT 16/29
# Test Loss: 1.6606, Test Accuracy: 0.7050, AUROC: 0.7496
# Testing on triviaqa-SLT 17/29
# Test Loss: 1.5358, Test Accuracy: 0.7250, AUROC: 0.7638
# Testing on triviaqa-SLT 18/29
# Test Loss: 1.6735, Test Accuracy: 0.7350, AUROC: 0.7528
# Testing on triviaqa-SLT 19/29
# Test Loss: 1.6593, Test Accuracy: 0.7350, AUROC: 0.7641
# Testing on triviaqa-SLT 20/29
# Test Loss: 1.6058, Test Accuracy: 0.7650, AUROC: 0.7949
# Testing on triviaqa-SLT 21/29
# Test Loss: 1.5640, Test Accuracy: 0.7350, AUROC: 0.8075
# Testing on triviaqa-SLT 22/29
# Test Loss: 1.6187, Test Accuracy: 0.7500, AUROC: 0.8085
# Testing on triviaqa-SLT 23/29
# Test Loss: 1.8218, Test Accuracy: 0.7400, AUROC: 0.7834
# Testing on triviaqa-SLT 24/29
# Test Loss: 1.8766, Test Accuracy: 0.7450, AUROC: 0.8065
# Testing on triviaqa-SLT 25/29
# Test Loss: 1.9769, Test Accuracy: 0.7500, AUROC: 0.8118
# Testing on triviaqa-SLT 26/29
# Test Loss: 1.9061, Test Accuracy: 0.7300, AUROC: 0.8237
# Testing on triviaqa-SLT 27/29
# Test Loss: 2.0752, Test Accuracy: 0.7150, AUROC: 0.8040
# Testing on triviaqa-SLT 28/29
# Test Loss: 1.9860, Test Accuracy: 0.7250, AUROC: 0.8115
# Testing on triviaqa-SLT 29/29
# Test Loss: 1.8014, Test Accuracy: 0.7350, AUROC: 0.8000

# %%
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [D.sa_aucs, D.sab_aucs], ["LR trained and tested on Acc", "LR trained on SE, tested on Acc"], f"AUROC on {D.name.upper()}'s SLT")
plt.tight_layout()
save_fig(name="se_for_acc_slt")
plt.show()

# %%
# select best layer range (SLT)
def decide_layer_range(Ds, metric='entropy', limit=NUMBER_OF_LAYERS+1): # NOTE: set upperbound to be number of layers+1; e.g. for llama2-70b, it is 81.
    """
    simple logic: use ID average test AUROCs across layers to determine 
    which consecutive range of layers did the best. Do separately
    for SEP and Acc. Pr.
    """
    assert hasattr(Ds[0], 'sab_aucs') and hasattr(Ds[0], 'sa_aucs'), 'previous cells need to be run'
    if 'entropy' in metric:
        aucs = [np.array(auc(D.sab_aucs)) for D in Ds]  # test metrics for ID SEPs
    else:
        aucs = [np.array(auc(D.sa_aucs)) for D in Ds]  # test metrics for ID APs
    best_mean = -np.inf
    best_range = []
    average = lambda a,b : np.mean([np.mean(ac[a:b]) for ac in aucs])

    for i in range(limit):
        for j in range(i+1, limit):
            if j - i < 5: # must be more than 5 layers
                continue
            if average(i, j) > best_mean:
                best_mean = average(i, j)
                best_range = [i, j]

    return best_mean, best_range

emean, (e1, e2) = decide_layer_range(Ds, 'entropy')
amean, (a1, a2) = decide_layer_range(Ds, 'acc')
for D in Ds:
    D.sep_layer_range = (e1, e2)
    D.ap_layer_range = (a1, a2)
print(emean, (e1, e2), amean, (a1, a2))
# Out:
# 0.8217111070825318 (19, 24) 0.8523808538030994 (19, 24)

# %%
# BOOTSTRAP: select [xx-xx] layers for bootstrapping
def concat_Xs_and_ys(layer_range, X_trains, X_vals, X_tests, y_trains, y_vals, y_tests, 
                     no_val=False, test_only=False):
    """
    Concatenate @params{layer_range} hidden state layers on train/val/test sets.

    no_val: no validation (training set only).
    test_only: no train/validation set (test set only).
    """
    if not no_val:
        X_val_cc = np.concatenate(np.array(X_vals)[layer_range], axis=1)
        y_val_cc = y_vals[layer_range[0]]
    else:
        X_val_cc = y_val_cc = None

    if not test_only:
        X_train_cc = np.concatenate(np.array(X_trains)[layer_range], axis=1)
        y_train_cc = y_trains[layer_range[0]]
    else:
        X_train_cc = y_train_cc = None
    
    X_test_cc = np.concatenate(np.array(X_tests)[layer_range], axis=1)
    y_test_cc = y_tests[layer_range[0]]
    
    return X_train_cc, X_val_cc, X_test_cc, y_train_cc, y_val_cc, y_test_cc

def train_concat_SE(D, layer_range):
    """train model on single dataset SE with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_bmodel', model)

        print(f'{token_type.upper()} trained on {D.name} SE finished')
    
def train_concat_Acc(D, layer_range):
    """train model on single dataset Accuracy with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_amodel', model)

        print(f'{token_type.upper()} trained on {D.name} Acc finished')

def train_concat_SE_Acc_test_Acc(D, layer_ranges=[list(range(e1,e2)), list(range(a1,a2))]):
    """ID: train and test SEPs and Acc. Pr. on single dataset with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, no_val=True) 
        
        X_train_cc, _, _, y_train_cc, _, _ = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys, no_val=True)
        ab_accs = []
        ab_aucs = []
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)

        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies) 
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys) # fixed random seed ensures no data leakage
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, 1-y_test_cc) # SEP predicts error rate
        ab_accs.append(test_acc)
        ab_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}b_accs', ab_accs)  # i means IDß
        setattr(D, f'i{var_name}b_aucs', ab_aucs)

        print(f'{D.name.upper()}-{token_type.upper()} trainied on SE and tested on Acc finished')
        aa_accs = []
        aa_aucs = []
        X_train_cc, _, X_test_cc, y_train_cc, _, y_test_cc = concat_Xs_and_ys(layer_ranges[1], *all_Xs_and_ys, no_val=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, y_test_cc)
        aa_accs.append(test_acc)
        aa_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}a_accs', aa_accs)
        setattr(D, f'i{var_name}a_aucs', aa_aucs)
        print(f'{D.name.upper()}-{token_type.upper()} trainied on Acc and tested on Acc finished')

# %%
# ID: train SEPs and Acc. Pr. and test them on Acc. from the same dataset
# import warnings # uncomment to disable convergence warnings
# warnings.filterwarnings('ignore')

for D in Ds:
    train_concat_SE_Acc_test_Acc(D)
# Out:
# Test Loss: 2.4170, Test Accuracy: 0.6900, AUROC: 0.8330
# SQUAD-SLT trainied on SE and tested on Acc finished
# Test Loss: 0.9811, Test Accuracy: 0.8350, AUROC: 0.8901
# SQUAD-SLT trainied on Acc and tested on Acc finished
# Test Loss: 2.0655, Test Accuracy: 0.7650, AUROC: 0.8103
# TRIVIAQA-SLT trainied on SE and tested on Acc finished
# Test Loss: 1.3166, Test Accuracy: 0.7550, AUROC: 0.8368
# TRIVIAQA-SLT trainied on Acc and tested on Acc finished

# %%
# OOD: save model trained on individual datasets for OOD tests
for D in Ds:
    train_concat_SE(D, layer_range=list(range(e1,e2)))
    train_concat_Acc(D, layer_range=list(range(a1,a2)))
# outputs cleared for space concern
# Out:
# SLT trained on squad SE finished
# SLT trained on squad Acc finished
# SLT trained on triviaqa SE finished
# SLT trained on triviaqa Acc finished

# %% [markdown]
# ## Test probes trained with one dataset on others
#
# We generalize SE and Acc. probes to Out-of-Distribution settings (OOD).

# %%
# Train on one's Acc/SE and test on others' Acc
def test_one_on_n(D, token_type='slt', 
                  layer_range1=list(range(e1,e2)), 
                  layer_range2=list(range(a1,a2))):
    var_name = token_type[0]
    other_ids = D.other_ids
    other_names = D.other_names
    metric = 'accuracies'
    a_model = getattr(D, f'{var_name}_amodel')  # Acc. Probe
    b_model = getattr(D, f'{var_name}_bmodel')  # SE Probe

    print(f"Using probes trained on datasets {D.name.upper()}'s {token_type.upper()}-SE/Acc to predict {other_names}'s {token_type.upper()}-Acc")

    oa_accs = {}
    oa_aucs = {}
    ob_accs = {}
    ob_aucs = {}
    
    for id_ in D.other_ids:
        D_id = Ds[id_]
        print(f"Testing on {D_id.name.upper()}'s {token_type.upper()}-{metric.upper()}")
        if metric == 'accuracies':
            y_metric = 1 - getattr(D_id, metric)  # error rate
        else:
            y_metric = getattr(D_id, metric)
        
        ida_accs = []
        ida_aucs = []
        idb_accs = []
        idb_aucs = []

        # create test sets with accuracy labels
        all_Xs_and_ys = create_Xs_and_ys(getattr(D_id, f'{token_type}_dataset'), y_metric, test_only=True)

        # test on Acc. Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range2, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(a_model, X_test_cc, 1-y_test_cc, bootstrap=True)
        ida_accs.append(test_acc)
        ida_aucs.append(test_auc)
        
        # test on SE Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range1, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(b_model, X_test_cc, y_test_cc, bootstrap=True)
        idb_accs.append(test_acc)
        idb_aucs.append(test_auc)

        oa_accs[D_id.name] = ida_accs
        oa_aucs[D_id.name] = ida_aucs
        ob_accs[D_id.name] = idb_accs
        ob_aucs[D_id.name] = idb_aucs

    setattr(D, 'osa_accs', oa_accs) # o means OOD
    setattr(D, 'osa_aucs', oa_aucs)
    setattr(D, 'osb_accs', ob_accs)
    setattr(D, 'osb_aucs', ob_aucs)

    print(f"Using probes trained on dataset {D.name.upper()} testing complete.")

# %%
for D in Ds:
    test_one_on_n(D, 'slt')
# Out:
# Using probes trained on datasets SQUAD's SLT-SE/Acc to predict ['triviaqa']'s SLT-Acc
# Testing on TRIVIAQA's SLT-ACCURACIES
# Test Loss: 1.6054, Test Accuracy: 0.7212, AUROC: 0.7972
# Test Loss: 2.3076, Test Accuracy: 0.6932, AUROC: 0.7693
# Using probes trained on dataset SQUAD testing complete.
# Using probes trained on datasets TRIVIAQA's SLT-SE/Acc to predict ['squad']'s SLT-Acc
# Testing on SQUAD's SLT-ACCURACIES
# Test Loss: 1.4062, Test Accuracy: 0.7407, AUROC: 0.8194
# Test Loss: 3.4571, Test Accuracy: 0.6186, AUROC: 0.7373
# Using probes trained on dataset TRIVIAQA testing complete.

# %%
# compute the OOD average: mean([train on B-> test on A, train on C -> test on A, train on D-> test on A])
b_performances = defaultdict(list)
a_performances = defaultdict(list)
win_rate = []
for D in Ds:
    for name in D.other_names:
        b_performances[name].append(auc(D.osb_aucs[name]))
        a_performances[name].append(auc(D.osa_aucs[name]))
        if auc(D.osb_aucs[name]) > auc(D.osa_aucs[name]):
            win_rate.append(1)
        else:
            win_rate.append(0)

print(f"winning rate: {np.mean(win_rate)*100:.2f}%")

for D in Ds:
    D.sep_ood_avg = np.mean(b_performances[D.name])
    D.ap_ood_avg = np.mean(a_performances[D.name])
    print(f"Average performance on {D.name}: SE Probe - {D.sep_ood_avg}, Acc Probe - {D.ap_ood_avg}")
# Out:
# winning rate: 0.00%
# Average performance on squad: SE Probe - 0.7372597107512533, Acc Probe - 0.8194178959137303
# Average performance on triviaqa: SE Probe - 0.7692767546251624, Acc Probe - 0.7972060242480178

# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("End time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# 记录结束时间
end = time()
# 计算时间间隔，按照小时：分钟：秒的格式输出
elapsed_seconds = end - start
elapsed_hours = int(elapsed_seconds // 3600)
elapsed_minutes = int((elapsed_seconds % 3600) // 60)
elapsed_seconds = int(elapsed_seconds % 60)
print(f"Time elapsed: {elapsed_hours:02d}:{elapsed_minutes:02d}:{elapsed_seconds:02d}")
# Out:
# End time: 2024-12-10 18:20:23
# Time elapsed: 00:08:01
