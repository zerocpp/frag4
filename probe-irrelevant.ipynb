# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("Start time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# 记录开始时间
from time import time
start = time()
# Out:
# Start time: 2024-12-10 16:31:55

# %% [markdown]
# # irrelevant数据单独训练探针

# %%
# 全局变量
# 图片保存文件夹路径
FIG_DIR = "output/data/figures/irrelevant"
# 采样类型
SAMPLE_TYPE = "irrelevant"
# 模型层数
NUMBER_OF_LAYERS = 28 # Qwen2.5-7B共有28层

# %%
# %load_ext autoreload
# %autoreload 2

import json
import warnings
import os
import pickle
from tqdm import tqdm
import torch
from collections import defaultdict, Counter
import argparse
from core.models.entailment import EntailmentDeberta
from core.data.data_utils import load_ds_from_json
import numpy as np
import pandas as pd
import scipy
from matplotlib import pyplot as plt
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score, mean_squared_error
from sklearn.model_selection import train_test_split

warnings.filterwarnings("ignore")
plt.rcParams.update({'font.size': 12})
rng = np.random.default_rng(42)


def load_pickle_file(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

def save_pickle_file(file_path, data):
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

# %%
# Create Dataset class for easier attribute keeping
class Dataset:
    name = ''
    tbg_dataset = None
    slt_dataset = None
    entropy = None
    accuracies = None

    sample_type = ''
    model_name = ''
    dataset_name = ''
    split = ''
    def __init__(self, name, tbg_dataset, slt_dataset, entropy, accuracies, sample_type, model_name, dataset_name, split):
        self.name = name
        self.tbg_dataset = tbg_dataset
        self.slt_dataset = slt_dataset
        self.entropy = entropy
        self.accuracies = accuracies
        self.sample_type = sample_type
        self.model_name = model_name
        self.dataset_name = dataset_name
        self.split = split

all_data = load_pickle_file("output/data/all_data.pkl")


model_name = "Qwen/Qwen2.5-7B-Instruct"
dataset_names = ["squad", "triviaqa"]
split = "train"
sample_type = SAMPLE_TYPE

Ds = []
for dataset_name in dataset_names:
    ds = all_data[model_name][dataset_name][split][sample_type]
    Ds.append(ds)

for i, D in enumerate(Ds):
    # OOD-related
    D.other_ids = [j for j in range(len(Ds)) if j != i]
    D.other_names = [Ds[j].name for j in D.other_ids]

# 打印数据集信息
for ds in Ds:
    print(f"{ds.model_name} {ds.dataset_name} {ds.split}: {len(ds.accuracies)}")
# Out:
# Qwen/Qwen2.5-7B-Instruct squad train: 2000
# Qwen/Qwen2.5-7B-Instruct triviaqa train: 1999

# %%
def print_ds_info(ds):
    print(ds.tbg_dataset.shape)
    print(ds.slt_dataset.shape)
    print(ds.entropy.shape)
    print(ds.accuracies.shape)

for ds in Ds:
    print_ds_info(ds)
# Out:
# torch.Size([29, 2000, 3584])
# torch.Size([29, 2000, 3584])
# torch.Size([2000])
# torch.Size([2000])
# torch.Size([29, 1999, 3584])
# torch.Size([29, 1999, 3584])
# torch.Size([1999])
# torch.Size([1999])

# %% [markdown]
# ### Helper Methods

# %%
# Create train/val/test splits
def create_Xs_and_ys(datasets, scores, val_test_splits=[0.2, 0.1], test_only=False, no_val=False):
    # Data splitting for sklearn linear models
    X = np.array(datasets)
    y = np.array(scores)

    if test_only:
        X_tests, y_tests = [], []
        
        for i in range(X.shape[0]):
            X_tests.append(X[i])
            y_tests.append(y)
        return (None, None, X_tests, None, None, y_tests)
    
    valid_size = val_test_splits[0]
    test_size = val_test_splits[1]

    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = [], [], [], [], [], []

    for i in range(X.shape[0]):
        # Split data into train, validation, and test sets
        X_train_val, X_test, y_train_val, y_test = train_test_split(X[i], y, test_size=test_size, random_state=42)
        X_tests.append(X_test)
        y_tests.append(y_test)
        if no_val:
            X_trains.append(X_train_val)
            y_trains.append(y_train_val)
            continue
        X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=valid_size, random_state=42) 
        X_trains.append(X_train)
        y_trains.append(y_train)
        X_vals.append(X_val)
        y_vals.append(y_val)

    return X_trains, X_vals, X_tests, y_trains, y_vals, y_tests

# %%
# Bootstrapping methods from ../semantic_entropy/uncertainty/utils/eval_utils.py
def bootstrap_func(y_true, y_score, func):
    y_tuple = (y_true, y_score)
    
    metric_i = func(*y_tuple)
    metric_dict = {}
    metric_dict['mean'] = metric_i
    metric_dict['bootstrap'] = compatible_bootstrap(
        func, rng)(*y_tuple)  # a bit slow to run

    return metric_dict

def bootstrap(function, rng, n_resamples=1000):
    def inner(data):
        bs = scipy.stats.bootstrap(
            (data, ), function, n_resamples=n_resamples, confidence_level=0.9,
            random_state=rng)
        return {
            'std_err': bs.standard_error,
            'low': bs.confidence_interval.low,
            'high': bs.confidence_interval.high
        }
    return inner

def auroc(y_true, y_score):
    fpr, tpr, thresholds = metrics.roc_curve(y_true, y_score)
    del thresholds
    return metrics.auc(fpr, tpr)

def compatible_bootstrap(func, rng):
    def helper(y_true_y_score):
        # this function is called in the bootstrap
        y_true = np.array([i['y_true'] for i in y_true_y_score])
        y_score = np.array([i['y_score'] for i in y_true_y_score])
        out = func(y_true, y_score)
        return out

    def wrap_inputs(y_true, y_score):
        return [{'y_true': i, 'y_score': j} for i, j in zip(y_true, y_score)]

    def converted_func(y_true, y_score):
        y_true_y_score = wrap_inputs(y_true, y_score)
        return bootstrap(helper, rng=rng)(y_true_y_score)
    return converted_func

# %%
# Train and evaluation function.
def sklearn_train_and_evaluate(model, X_train, y_train, X_valid, y_valid, silent=False):
    model.fit(X_train, y_train)
    
    # Calculate training loss and score
    train_probs = model.predict_proba(X_train)
    train_loss = log_loss(y_train, train_probs)

    # Calculate validation loss
    valid_preds = model.predict(X_valid)
    valid_probs = model.predict_proba(X_valid)
    valid_loss = log_loss(y_valid, valid_probs)
    val_accuracy = np.mean((valid_preds == y_valid).astype(int))
    auroc_score = roc_auc_score(y_valid, valid_probs[:,1])
    if not silent:
        print(f"Validation Accuracy: {val_accuracy:.4f}, AUROC: {auroc_score:.4f}")
        print(f"Training Loss: {train_loss:.4f}, Validation Loss: {valid_loss:.4f}")

def sklearn_evaluate_on_test(model, X_test, y_test, silent=False, bootstrap=True):
    test_preds = model.predict(X_test)
    test_probs = model.predict_proba(X_test)
    test_loss = log_loss(y_test, test_probs)
    test_accuracy = np.mean((test_preds == y_test).astype(int))
    
    if bootstrap:
        auroc_score = bootstrap_func(y_test, test_probs[:,1], auroc)
        auroc_score_scalar = auroc_score['mean']
    else:
        auroc_score = auroc_score_scalar = roc_auc_score(y_test, test_probs[:, 1])
    
    if not silent:
        print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, AUROC: {auroc_score_scalar:.4f}")
    
    return test_loss, test_accuracy, auroc_score

def train_single_metric(D, token_type='tbg', metric='b_entropy'):
    """train and test on single metric (e.g. SE, Acc) on single dataset"""
    var_name = token_type[0] + metric[0] 
    # named as [te, se. ta, sa] for easy identification; t for tbg, s for slt (token positions)
    # e for entropy and a for accuracy (or model faithfulness)
    X_trains, X_vals, X_tests, y_trains, y_vals, y_tests = create_Xs_and_ys(
        getattr(D, f'{token_type}_dataset'), getattr(D, metric)
    )

    accs = []
    aucs = []
    models = []
    
    for i, (X_train, X_val, X_test, y_train, y_val, y_test) in enumerate(zip(X_trains, X_vals, X_tests, y_trains, y_vals, y_tests)):
        print(f"Training on {D.name}-{token_type.upper()}-{metric.upper()} {i+1}/{len(X_trains)}")
        model = LogisticRegression()
        sklearn_train_and_evaluate(model, X_train, y_train, X_val, y_val)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        accs.append(test_acc)
        aucs.append(test_auc)
        models.append(model)

    setattr(D, f'{var_name}_accs', accs)
    setattr(D, f'{var_name}_aucs', aucs)
    setattr(D, f'{var_name}_models', models)

# simple get-around for unpacking bootstrapping dicts
auc = lambda aucs : [ac['mean'] for ac in aucs] 
idf = lambda x : x  # identical function

# %%
# Plotting methods
def plot_metrics_ax(ax, test_metrics_list, model_names, title="", prep_func=auc, 
                    use_logarithm=False, preset_layer_indices=None, legend_outside=False):  # some simple gadgets
    """plot metrics along certain axis in a multi-axis plot (plt.subplots)"""
    if len(test_metrics_list) != len(model_names):
        raise ValueError("The length of test_metrics_list and model_names must be the same.")
    
    for test_metrics, model_name in zip(test_metrics_list, model_names):
        test_metrics = torch.tensor(prep_func(test_metrics), dtype=torch.float32)
        if use_logarithm:
            test_metrics = torch.log(test_metrics + 1e-6)
        if preset_layer_indices is not None:
            layer_indices = preset_layer_indices
        else:
            layer_indices = torch.arange(len(test_metrics)) + 1  # +1 if layer indexing starts at 1
        
        ax.plot(layer_indices, test_metrics, marker='o', linestyle='-', linewidth=2, markersize=5, label=model_name)
    
    ax.set_title(f'{title}', fontsize=14)
    ax.set_xlabel('Layer', fontsize=12)
    ax.set_ylabel(f'Test AUROC scores', fontsize=12)
    
    tick_interval = 5  # Change this value to display more or fewer ticks
    ax.set_xticks(layer_indices[::tick_interval].tolist())
    ax.set_xticklabels(layer_indices[::tick_interval].tolist())
    
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    
    if legend_outside:
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=12)
    else:
        ax.legend(fontsize=12)

def save_fig(name):
    """save figure with timestamps"""
    dir_path = os.path.expanduser(FIG_DIR)
    os.makedirs(dir_path, exist_ok=True)
    full_path = os.path.join(dir_path, f'{name}.pdf')
    plt.savefig(full_path, format='pdf', dpi=300)

# %%
# Best split for SE binarization.
def best_split(entropy: torch.Tensor, label="Dx"):
    """
    Identify best split for minimizing reconstruction error via low and high SE mean estimates,
    as discussed in Section 4. Binarization of paper (ArXiv: 2406.15927)
    """
    ents = entropy.numpy()
    splits = np.linspace(1e-10, ents.max(), 100)
    split_mses = []
    for split in splits:
        low_idxs, high_idxs = ents < split, ents >= split
    
        low_mean = np.mean(ents[low_idxs])
        high_mean = np.mean(ents[high_idxs])
    
        mse = np.sum((ents[low_idxs] - low_mean)**2) + np.sum((ents[high_idxs] - high_mean)**2)
        mse = np.sum(mse)
    
        split_mses.append(mse)
    
    split_mses = np.array(split_mses)
    
    plt.plot(splits, split_mses, label=label)
    return splits[np.argmin(split_mses)]

def binarize_entropy(entropy, thres=0.0):  # 0.0 means even splits for normalized entropy scores
    """Binarize entropy scores into 0s and 1s"""
    binary_entropy = torch.full_like(entropy, -1, dtype=torch.float)
    binary_entropy[entropy < thres] = 0
    binary_entropy[entropy > thres] = 1

    return binary_entropy

# %% [markdown]
# ### 二值化语义熵

# %%
# Best universal split across datasets
split_method = 'best-universal-split'
all_entropy = torch.cat([D.entropy for D in Ds], dim=0)
split = best_split(all_entropy, "All datasets collective")
plt.legend()
plt.title('Sum of squared errors at different splits')
for D in Ds:
    D.b_entropy = binarize_entropy(D.entropy, split)
    print(f"Dummy accuracy for {D.name}: {max(torch.mean(D.b_entropy).item(), 1-torch.mean(D.b_entropy).item()):.4f}")
# Out:
# Dummy accuracy for squad-irrelevant: 0.6265
# Dummy accuracy for triviaqa-irrelevant: 0.5478

# %% [markdown]
# ### Train linear probes to predict Binarized SE

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'b_entropy')
    train_single_metric(D, 'slt', 'b_entropy')
# Out:
# Training on squad-irrelevant-TBG-B_ENTROPY 1/29
# Validation Accuracy: 0.6278, AUROC: 0.5000
# Training Loss: 0.6643, Validation Loss: 0.6603
# Test Loss: 0.6373, Test Accuracy: 0.6750, AUROC: 0.5000
# Training on squad-irrelevant-TBG-B_ENTROPY 2/29
# Validation Accuracy: 0.6139, AUROC: 0.4965
# Training Loss: 0.5808, Validation Loss: 0.6929
# Test Loss: 0.6410, Test Accuracy: 0.6500, AUROC: 0.5616
# Training on squad-irrelevant-TBG-B_ENTROPY 3/29
# Validation Accuracy: 0.5889, AUROC: 0.4858
# Training Loss: 0.5281, Validation Loss: 0.7115
# Test Loss: 0.6462, Test Accuracy: 0.6550, AUROC: 0.5738
# Training on squad-irrelevant-TBG-B_ENTROPY 4/29
# Validation Accuracy: 0.5694, AUROC: 0.5222
# Training Loss: 0.4996, Validation Loss: 0.7328
# Test Loss: 0.6418, Test Accuracy: 0.6650, AUROC: 0.6170
# Training on squad-irrelevant-TBG-B_ENTROPY 5/29
# Validation Accuracy: 0.5861, AUROC: 0.5139
# Training Loss: 0.4690, Validation Loss: 0.7695
# Test Loss: 0.6708, Test Accuracy: 0.6900, AUROC: 0.5932
# Training on squad-irrelevant-TBG-B_ENTROPY 6/29
# Validation Accuracy: 0.5444, AUROC: 0.4881
# Training Loss: 0.3792, Validation Loss: 0.8667
# Test Loss: 0.7024, Test Accuracy: 0.6350, AUROC: 0.5960
# Training on squad-irrelevant-TBG-B_ENTROPY 7/29
# Validation Accuracy: 0.5361, AUROC: 0.4873
# Training Loss: 0.3446, Validation Loss: 0.9567
# Test Loss: 0.7325, Test Accuracy: 0.6250, AUROC: 0.6091
# Training on squad-irrelevant-TBG-B_ENTROPY 8/29
# Validation Accuracy: 0.5083, AUROC: 0.4409
# Training Loss: 0.3305, Validation Loss: 1.0121
# Test Loss: 0.7617, Test Accuracy: 0.6150, AUROC: 0.5854
# Training on squad-irrelevant-TBG-B_ENTROPY 9/29
# Validation Accuracy: 0.5417, AUROC: 0.4793
# Training Loss: 0.2811, Validation Loss: 1.0131
# Test Loss: 0.8384, Test Accuracy: 0.5950, AUROC: 0.5712
# Training on squad-irrelevant-TBG-B_ENTROPY 10/29
# Validation Accuracy: 0.5583, AUROC: 0.5009
# Training Loss: 0.2741, Validation Loss: 1.0527
# Test Loss: 0.9247, Test Accuracy: 0.5600, AUROC: 0.5606
# Training on squad-irrelevant-TBG-B_ENTROPY 11/29
# Validation Accuracy: 0.5583, AUROC: 0.5254
# Training Loss: 0.3107, Validation Loss: 0.9456
# Test Loss: 0.8599, Test Accuracy: 0.6300, AUROC: 0.5781
# Training on squad-irrelevant-TBG-B_ENTROPY 12/29
# Validation Accuracy: 0.5361, AUROC: 0.4846
# Training Loss: 0.2549, Validation Loss: 1.0329
# Test Loss: 0.8599, Test Accuracy: 0.6000, AUROC: 0.5755
# Training on squad-irrelevant-TBG-B_ENTROPY 13/29
# Validation Accuracy: 0.5611, AUROC: 0.5149
# Training Loss: 0.2758, Validation Loss: 1.0473
# Test Loss: 0.8656, Test Accuracy: 0.5900, AUROC: 0.5960
# Training on squad-irrelevant-TBG-B_ENTROPY 14/29
# Validation Accuracy: 0.5417, AUROC: 0.5155
# Training Loss: 0.3046, Validation Loss: 1.0463
# Test Loss: 0.8155, Test Accuracy: 0.6100, AUROC: 0.6050
# Training on squad-irrelevant-TBG-B_ENTROPY 15/29
# Validation Accuracy: 0.5694, AUROC: 0.5416
# Training Loss: 0.2787, Validation Loss: 0.9907
# Test Loss: 0.8359, Test Accuracy: 0.5800, AUROC: 0.5825
# Training on squad-irrelevant-TBG-B_ENTROPY 16/29
# Validation Accuracy: 0.5778, AUROC: 0.5367
# Training Loss: 0.2959, Validation Loss: 1.1175
# Test Loss: 1.0209, Test Accuracy: 0.5700, AUROC: 0.5274
# Training on squad-irrelevant-TBG-B_ENTROPY 17/29
# Validation Accuracy: 0.5389, AUROC: 0.5175
# Training Loss: 0.2381, Validation Loss: 1.1838
# Test Loss: 0.9320, Test Accuracy: 0.5950, AUROC: 0.5895
# Training on squad-irrelevant-TBG-B_ENTROPY 18/29
# Validation Accuracy: 0.5639, AUROC: 0.5065
# Training Loss: 0.2341, Validation Loss: 1.3450
# Test Loss: 1.0431, Test Accuracy: 0.5800, AUROC: 0.5650
# Training on squad-irrelevant-TBG-B_ENTROPY 19/29
# Validation Accuracy: 0.5556, AUROC: 0.5481
# Training Loss: 0.1675, Validation Loss: 1.4218
# Test Loss: 1.1647, Test Accuracy: 0.5600, AUROC: 0.5836
# Training on squad-irrelevant-TBG-B_ENTROPY 20/29
# Validation Accuracy: 0.5806, AUROC: 0.5789
# Training Loss: 0.1058, Validation Loss: 1.7422
# Test Loss: 1.5466, Test Accuracy: 0.5600, AUROC: 0.5362
# Training on squad-irrelevant-TBG-B_ENTROPY 21/29
# Validation Accuracy: 0.5833, AUROC: 0.5628
# Training Loss: 0.1002, Validation Loss: 1.8147
# Test Loss: 1.5472, Test Accuracy: 0.6250, AUROC: 0.6067
# Training on squad-irrelevant-TBG-B_ENTROPY 22/29
# Validation Accuracy: 0.5694, AUROC: 0.5683
# Training Loss: 0.0324, Validation Loss: 2.2870
# Test Loss: 2.3019, Test Accuracy: 0.5750, AUROC: 0.5488
# Training on squad-irrelevant-TBG-B_ENTROPY 23/29
# Validation Accuracy: 0.5611, AUROC: 0.5555
# Training Loss: 0.0264, Validation Loss: 2.8473
# Test Loss: 2.3355, Test Accuracy: 0.5900, AUROC: 0.5791
# Training on squad-irrelevant-TBG-B_ENTROPY 24/29
# Validation Accuracy: 0.5750, AUROC: 0.5255
# Training Loss: 0.0100, Validation Loss: 3.6156
# Test Loss: 2.8405, Test Accuracy: 0.5350, AUROC: 0.5633
# Training on squad-irrelevant-TBG-B_ENTROPY 25/29
# Validation Accuracy: 0.5667, AUROC: 0.5586
# Training Loss: 0.0064, Validation Loss: 3.2965
# Test Loss: 3.0711, Test Accuracy: 0.5750, AUROC: 0.5603
# Training on squad-irrelevant-TBG-B_ENTROPY 26/29
# Validation Accuracy: 0.5778, AUROC: 0.5644
# Training Loss: 0.0052, Validation Loss: 3.4507
# Test Loss: 3.1746, Test Accuracy: 0.5750, AUROC: 0.5810
# Training on squad-irrelevant-TBG-B_ENTROPY 27/29
# Validation Accuracy: 0.5306, AUROC: 0.5218
# Training Loss: 0.0021, Validation Loss: 3.8067
# Test Loss: 3.3587, Test Accuracy: 0.6050, AUROC: 0.5861
# Training on squad-irrelevant-TBG-B_ENTROPY 28/29
# Validation Accuracy: 0.5722, AUROC: 0.5627
# Training Loss: 0.0019, Validation Loss: 3.8900
# Test Loss: 3.6079, Test Accuracy: 0.5950, AUROC: 0.5783
# Training on squad-irrelevant-TBG-B_ENTROPY 29/29
# Validation Accuracy: 0.5667, AUROC: 0.5461
# Training Loss: 0.0013, Validation Loss: 3.2537
# Test Loss: 3.3306, Test Accuracy: 0.5550, AUROC: 0.5570
# Training on squad-irrelevant-SLT-B_ENTROPY 1/29
# Validation Accuracy: 0.6167, AUROC: 0.5543
# Training Loss: 0.5923, Validation Loss: 0.6628
# Test Loss: 0.6554, Test Accuracy: 0.6350, AUROC: 0.4891
# Training on squad-irrelevant-SLT-B_ENTROPY 2/29
# Validation Accuracy: 0.5694, AUROC: 0.5432
# Training Loss: 0.2202, Validation Loss: 1.0554
# Test Loss: 1.0009, Test Accuracy: 0.5750, AUROC: 0.5464
# Training on squad-irrelevant-SLT-B_ENTROPY 3/29
# Validation Accuracy: 0.5750, AUROC: 0.5520
# Training Loss: 0.1731, Validation Loss: 1.1840
# Test Loss: 1.0450, Test Accuracy: 0.5600, AUROC: 0.5662
# Training on squad-irrelevant-SLT-B_ENTROPY 4/29
# Validation Accuracy: 0.5694, AUROC: 0.5198
# Training Loss: 0.1338, Validation Loss: 1.4310
# Test Loss: 1.2236, Test Accuracy: 0.5900, AUROC: 0.5532
# Training on squad-irrelevant-SLT-B_ENTROPY 5/29
# Validation Accuracy: 0.6028, AUROC: 0.5449
# Training Loss: 0.1020, Validation Loss: 1.4905
# Test Loss: 1.2867, Test Accuracy: 0.5500, AUROC: 0.5610
# Training on squad-irrelevant-SLT-B_ENTROPY 6/29
# Validation Accuracy: 0.5833, AUROC: 0.5276
# Training Loss: 0.0741, Validation Loss: 1.8945
# Test Loss: 1.3978, Test Accuracy: 0.5900, AUROC: 0.5950
# Training on squad-irrelevant-SLT-B_ENTROPY 7/29
# Validation Accuracy: 0.5833, AUROC: 0.5369
# Training Loss: 0.0695, Validation Loss: 1.8649
# Test Loss: 1.5107, Test Accuracy: 0.5800, AUROC: 0.5738
# Training on squad-irrelevant-SLT-B_ENTROPY 8/29
# Validation Accuracy: 0.5472, AUROC: 0.5530
# Training Loss: 0.0548, Validation Loss: 1.8598
# Test Loss: 1.7232, Test Accuracy: 0.5600, AUROC: 0.5813
# Training on squad-irrelevant-SLT-B_ENTROPY 9/29
# Validation Accuracy: 0.6167, AUROC: 0.6004
# Training Loss: 0.0430, Validation Loss: 1.9833
# Test Loss: 1.7604, Test Accuracy: 0.5550, AUROC: 0.5919
# Training on squad-irrelevant-SLT-B_ENTROPY 10/29
# Validation Accuracy: 0.6361, AUROC: 0.5945
# Training Loss: 0.0322, Validation Loss: 2.3820
# Test Loss: 1.9547, Test Accuracy: 0.6200, AUROC: 0.6065
# Training on squad-irrelevant-SLT-B_ENTROPY 11/29
# Validation Accuracy: 0.5972, AUROC: 0.5778
# Training Loss: 0.0436, Validation Loss: 2.2632
# Test Loss: 1.8062, Test Accuracy: 0.6300, AUROC: 0.6065
# Training on squad-irrelevant-SLT-B_ENTROPY 12/29
# Validation Accuracy: 0.5722, AUROC: 0.5794
# Training Loss: 0.0363, Validation Loss: 2.5557
# Test Loss: 2.2379, Test Accuracy: 0.6050, AUROC: 0.6203
# Training on squad-irrelevant-SLT-B_ENTROPY 13/29
# Validation Accuracy: 0.5750, AUROC: 0.5711
# Training Loss: 0.0333, Validation Loss: 2.3813
# Test Loss: 2.2296, Test Accuracy: 0.6000, AUROC: 0.6244
# Training on squad-irrelevant-SLT-B_ENTROPY 14/29
# Validation Accuracy: 0.5944, AUROC: 0.5574
# Training Loss: 0.0302, Validation Loss: 2.5226
# Test Loss: 1.9428, Test Accuracy: 0.6250, AUROC: 0.6374
# Training on squad-irrelevant-SLT-B_ENTROPY 15/29
# Validation Accuracy: 0.5778, AUROC: 0.5576
# Training Loss: 0.0234, Validation Loss: 2.8099
# Test Loss: 2.0232, Test Accuracy: 0.6100, AUROC: 0.6344
# Training on squad-irrelevant-SLT-B_ENTROPY 16/29
# Validation Accuracy: 0.5917, AUROC: 0.5619
# Training Loss: 0.0236, Validation Loss: 2.9083
# Test Loss: 2.0751, Test Accuracy: 0.6100, AUROC: 0.6318
# Training on squad-irrelevant-SLT-B_ENTROPY 17/29
# Validation Accuracy: 0.5972, AUROC: 0.5701
# Training Loss: 0.0168, Validation Loss: 2.9789
# Test Loss: 2.1060, Test Accuracy: 0.6100, AUROC: 0.6481
# Training on squad-irrelevant-SLT-B_ENTROPY 18/29
# Validation Accuracy: 0.5972, AUROC: 0.5767
# Training Loss: 0.0142, Validation Loss: 2.6318
# Test Loss: 1.9695, Test Accuracy: 0.5850, AUROC: 0.6320
# Training on squad-irrelevant-SLT-B_ENTROPY 19/29
# Validation Accuracy: 0.5750, AUROC: 0.5772
# Training Loss: 0.0124, Validation Loss: 2.3806
# Test Loss: 1.9299, Test Accuracy: 0.6150, AUROC: 0.6506
# Training on squad-irrelevant-SLT-B_ENTROPY 20/29
# Validation Accuracy: 0.5694, AUROC: 0.5886
# Training Loss: 0.0117, Validation Loss: 2.5033
# Test Loss: 1.8952, Test Accuracy: 0.5950, AUROC: 0.6471
# Training on squad-irrelevant-SLT-B_ENTROPY 21/29
# Validation Accuracy: 0.6056, AUROC: 0.6031
# Training Loss: 0.0069, Validation Loss: 3.0354
# Test Loss: 2.5361, Test Accuracy: 0.5850, AUROC: 0.6645
# Training on squad-irrelevant-SLT-B_ENTROPY 22/29
# Validation Accuracy: 0.5972, AUROC: 0.6163
# Training Loss: 0.0053, Validation Loss: 2.5826
# Test Loss: 1.9050, Test Accuracy: 0.6400, AUROC: 0.6983
# Training on squad-irrelevant-SLT-B_ENTROPY 23/29
# Validation Accuracy: 0.5778, AUROC: 0.6055
# Training Loss: 0.0041, Validation Loss: 2.8176
# Test Loss: 2.2780, Test Accuracy: 0.6150, AUROC: 0.6620
# Training on squad-irrelevant-SLT-B_ENTROPY 24/29
# Validation Accuracy: 0.5889, AUROC: 0.6145
# Training Loss: 0.0039, Validation Loss: 2.8775
# Test Loss: 2.4240, Test Accuracy: 0.6150, AUROC: 0.6562
# Training on squad-irrelevant-SLT-B_ENTROPY 25/29
# Validation Accuracy: 0.6028, AUROC: 0.6138
# Training Loss: 0.0038, Validation Loss: 3.5862
# Test Loss: 2.8330, Test Accuracy: 0.6150, AUROC: 0.6566
# Training on squad-irrelevant-SLT-B_ENTROPY 26/29
# Validation Accuracy: 0.6389, AUROC: 0.6533
# Training Loss: 0.0030, Validation Loss: 3.2047
# Test Loss: 3.1663, Test Accuracy: 0.6750, AUROC: 0.6547
# Training on squad-irrelevant-SLT-B_ENTROPY 27/29
# Validation Accuracy: 0.6250, AUROC: 0.6451
# Training Loss: 0.0018, Validation Loss: 3.1425
# Test Loss: 2.9122, Test Accuracy: 0.6400, AUROC: 0.6512
# Training on squad-irrelevant-SLT-B_ENTROPY 28/29
# Validation Accuracy: 0.6222, AUROC: 0.6458
# Training Loss: 0.0019, Validation Loss: 3.6086
# Test Loss: 3.7484, Test Accuracy: 0.6350, AUROC: 0.6541
# Training on squad-irrelevant-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.6028, AUROC: 0.6134
# Training Loss: 0.0020, Validation Loss: 3.8015
# Test Loss: 3.6678, Test Accuracy: 0.6350, AUROC: 0.6361
# Training on triviaqa-irrelevant-TBG-B_ENTROPY
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 19/29
# Validation Accuracy: 0.6139, AUROC: 0.6344
# Training Loss: 0.0099, Validation Loss: 2.1410
# Test Loss: 2.0995, Test Accuracy: 0.5700, AUROC: 0.6379
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 20/29
# Validation Accuracy: 0.5889, AUROC: 0.6098
# Training Loss: 0.0072, Validation Loss: 2.5419
# Test Loss: 2.0110, Test Accuracy: 0.6500, AUROC: 0.6586
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 21/29
# Validation Accuracy: 0.6000, AUROC: 0.6169
# Training Loss: 0.0062, Validation Loss: 2.5323
# Test Loss: 1.9529, Test Accuracy: 0.6450, AUROC: 0.6682
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 22/29
# Validation Accuracy: 0.5806, AUROC: 0.6049
# Training Loss: 0.0047, Validation Loss: 2.5683
# Test Loss: 1.8089, Test Accuracy: 0.6750, AUROC: 0.6961
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 23/29
# Validation Accuracy: 0.5778, AUROC: 0.6078
# Training Loss: 0.0029, Validation Loss: 2.8582
# Test Loss: 2.3319, Test Accuracy: 0.6150, AUROC: 0.6674
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 24/29
# Validation Accuracy: 0.5639, AUROC: 0.5993
# Training Loss: 0.0019, Validation Loss: 3.0071
# Test Loss: 2.3893, Test Accuracy: 0.6400, AUROC: 0.6633
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 25/29
# Validation Accuracy: 0.5806, AUROC: 0.6015
# Training Loss: 0.0018, Validation Loss: 3.5165
# Test Loss: 2.3496, Test Accuracy: 0.6250, AUROC: 0.6997
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 26/29
# Validation Accuracy: 0.5639, AUROC: 0.5992
# Training Loss: 0.0013, Validation Loss: 3.6421
# Test Loss: 2.7774, Test Accuracy: 0.6000, AUROC: 0.6340
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 27/29
# Validation Accuracy: 0.5806, AUROC: 0.6243
# Training Loss: 0.0013, Validation Loss: 3.9837
# Test Loss: 3.2735, Test Accuracy: 0.5650, AUROC: 0.6435
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 28/29
# Validation Accuracy: 0.5833, AUROC: 0.6205
# Training Loss: 0.0009, Validation Loss: 3.6237
# Test Loss: 2.8877, Test Accuracy: 0.6000, AUROC: 0.6763
# Training on triviaqa-irrelevant-SLT-B_ENTROPY 29/29
# Validation Accuracy: 0.5750, AUROC: 0.6180
# Training Loss: 0.0011, Validation Loss: 3.2175
# Test Loss: 2.4867, Test Accuracy: 0.6200, AUROC: 0.6559

# %%
# plot se probe
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.tb_aucs), auc(D.sb_aucs)], ["SE Probe on TBG token", "SE Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="se_both_tok")
plt.show()

# %% [markdown]
# ### Train linear probes to predict Accuracy

# %%
for D in Ds:
    train_single_metric(D, 'tbg', 'accuracies')
    train_single_metric(D, 'slt', 'accuracies')
# Out:
# Training on squad-irrelevant-TBG-ACCURACIES 1/29
# Validation Accuracy: 0.8472, AUROC: 0.5000
# Training Loss: 0.3266, Validation Loss: 0.4406
# Test Loss: 0.3360, Test Accuracy: 0.8950, AUROC: 0.5000
# Training on squad-irrelevant-TBG-ACCURACIES 2/29
# Validation Accuracy: 0.8444, AUROC: 0.5766
# Training Loss: 0.2702, Validation Loss: 0.4441
# Test Loss: 0.3594, Test Accuracy: 0.8950, AUROC: 0.4679
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [auc(D.ta_aucs), auc(D.sa_aucs)], ["Acc Probe on TBG token", "Acc Probe on SLT token"], 
                    f"AUROC on {D.name.upper()}", prep_func=idf)
plt.tight_layout()
save_fig(name="acc_both_tok")
plt.show()

# %% [markdown]
# ### Use linear probe trained on Binarized SE to predict Accuracy
#
# We leverage trained probes on semantic entropy to predict model correctness on the same dataset.
#
# Note that we need to predict the error rate (1 minus accuracy) using SEPs due to the nature of semantic uncertainty.

# %%
for D in Ds:
    r_acc = 1 - D.accuracies
    
    # TBG
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.tbg_dataset, r_acc) 
    tab_accs = []
    tab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-TBG {i+1}/{len(X_tests)}")
        model = D.tb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        tab_accs.append(test_acc)
        tab_aucs.append(test_auc)

    D.tab_accs = tab_accs
    D.tab_aucs = tab_aucs

    # SLT t
    _, _, X_tests, _, _, y_tests = create_Xs_and_ys(D.slt_dataset, r_acc)     
    sab_accs = []
    sab_aucs = []
    
    for i, (X_test, y_test) in enumerate(zip(X_tests, y_tests)):
        print(f"Testing on {D.name}-SLT {i+1}/{len(X_tests)}")
        model = D.sb_models[i]
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test, y_test)
        sab_accs.append(test_acc)
        sab_aucs.append(test_auc)

    D.sab_accs = sab_accs
    D.sab_aucs = sab_aucs
# Out:
# Testing on squad-irrelevant-TBG 1/29
# Test Loss: 0.5301, Test Accuracy: 0.8950, AUROC: 0.5000
# Testing on squad-irrelevant-TBG 2/29
# Test Loss: 0.5558, Test Accuracy: 0.8000, AUROC: 0.4794
# Testing on squad-irrelevant-TBG 3/29
# Test Loss: 0.5940, Test Accuracy: 0.7050, AUROC: 0.4456
# Testing on squad-irrelevant-TBG 4/29
# Test Loss: 0.5816, Test Accuracy: 0.6650, AUROC: 0.5211
# Testing on squad-irrelevant-TBG 5/29
# Test Loss: 0.6169, Test Accuracy: 0.6700, AUROC: 0.4589
# Testing on squad-irrelevant-TBG 6/29
# Test Loss: 0.6276, Test Accuracy: 0.6850, AUROC: 0.5283
# Testing on squad-irrelevant-TBG 7/29
# Test Loss: 0.6699, Test Accuracy: 0.6450, AUROC: 0.5100
# Testing on squad-irrelevant-TBG 8/29
# Test Loss: 0.7391, Test Accuracy: 0.6150, AUROC: 0.4698
# Testing on squad-irrelevant-TBG 9/29
# Test Loss: 0.7790, Test Accuracy: 0.6350, AUROC: 0.5315
# Testing on squad-irrelevant-TBG 10/29
# Test Loss: 0.8295, Test Accuracy: 0.5900, AUROC: 0.5847
# Testing on squad-irrelevant-TBG 11/29
# Test Loss: 0.8364, Test Accuracy: 0.6100, AUROC: 0.5124
# Testing on squad-irrelevant-TBG 12/29
# Test Loss: 0.8166, Test Accuracy: 0.6200, AUROC: 0.4935
# Testing on squad-irrelevant-TBG 13/29
# Test Loss: 0.7888, Test Accuracy: 0.6300, AUROC: 0.5616
# Testing on squad-irrelevant-TBG 14/29
# Test Loss: 0.7459, Test Accuracy: 0.6200, AUROC: 0.5738
# Testing on squad-irrelevant-TBG 15/29
# Test Loss: 0.7764, Test Accuracy: 0.6300, AUROC: 0.5839
# Testing on squad-irrelevant-TBG 16/29
# Test Loss: 0.8118, Test Accuracy: 0.6700, AUROC: 0.5858
# Testing on squad-irrelevant-TBG 17/29
# Test Loss: 0.8443, Test Accuracy: 0.6350, AUROC: 0.5536
# Testing on squad-irrelevant-TBG 18/29
# Test Loss: 0.8765, Test Accuracy: 0.6400, AUROC: 0.5994
# Testing on squad-irrelevant-TBG 19/29
# Test Loss: 1.0351, Test Accuracy: 0.6100, AUROC: 0.6068
# Testing on squad-irrelevant-TBG 20/29
# Test Loss: 1.1726, Test Accuracy: 0.6600, AUROC: 0.6084
# Testing on squad-irrelevant-TBG 21/29
# Test Loss: 1.3323, Test Accuracy: 0.6550, AUROC: 0.6377
# Testing on squad-irrelevant-TBG 22/29
# Test Loss: 1.8844, Test Accuracy: 0.6250, AUROC: 0.5903
# Testing on squad-irrelevant-TBG 23/29
# Test Loss: 2.0379, Test Accuracy: 0.6300, AUROC: 0.6010
# Testing on squad-irrelevant-TBG 24/29
# Test Loss: 2.4776, Test Accuracy: 0.6250, AUROC: 0.5823
# Testing on squad-irrelevant-TBG 25/29
# Test Loss: 2.5304, Test Accuracy: 0.6450, AUROC: 0.6244
# Testing on squad-irrelevant-TBG 26/29
# Test Loss: 2.7103, Test Accuracy: 0.6250, AUROC: 0.5975
# Testing on squad-irrelevant-TBG 27/29
# Test Loss: 2.9413, Test Accuracy: 0.6050, AUROC: 0.5185
# Testing on squad-irrelevant-TBG 28/29
# Test Loss: 3.2300, Test Accuracy: 0.6350, AUROC: 0.6081
# Testing on squad-irrelevant-TBG 29/29
# Test Loss: 2.7915, Test Accuracy: 0.6450, AUROC: 0.5549
# Testing on squad-irrelevant-SLT 1/29
# Test Loss: 0.5342, Test Accuracy: 0.8450, AUROC: 0.5451
# Testing on squad-irrelevant-SLT 2/29
# Test Loss: 0.8009, Test Accuracy: 0.6650, AUROC: 0.6031
# Testing on squad-irrelevant-SLT 3/29
# Test Loss: 0.9061, Test Accuracy: 0.6500, AUROC: 0.5483
# Testing on squad-irrelevant-SLT 4/29
# Test Loss: 1.1374, Test Accuracy: 0.6600, AUROC: 0.5172
# Testing on squad-irrelevant-SLT 5/29
# Test Loss: 1.2357, Test Accuracy: 0.6000, AUROC: 0.5070
# Testing on squad-irrelevant-SLT 6/29
# Test Loss: 1.3698, Test Accuracy: 0.6300, AUROC: 0.5757
# Testing on squad-irrelevant-SLT 7/29
# Test Loss: 1.5027, Test Accuracy: 0.6200, AUROC: 0.5579
# Testing on squad-irrelevant-SLT 8/29
# Test Loss: 1.8002, Test Accuracy: 0.5500, AUROC: 0.5352
# Testing on squad-irrelevant-SLT 9/29
# Test Loss: 2.0760, Test Accuracy: 0.5750, AUROC: 0.5078
# Testing on squad-irrelevant-SLT 10/29
# Test Loss: 2.2317, Test Accuracy: 0.6100, AUROC: 0.4796
# Testing on squad-irrelevant-SLT 11/29
# Test Loss: 1.8974, Test Accuracy: 0.6100, AUROC: 0.5419
# Testing on squad-irrelevant-SLT 12/29
# Test Loss: 2.7278, Test Accuracy: 0.5950, AUROC: 0.4834
# Testing on squad-irrelevant-SLT 13/29
# Test Loss: 2.6311, Test Accuracy: 0.6000, AUROC: 0.4789
# Testing on squad-irrelevant-SLT 14/29
# Test Loss: 2.2008, Test Accuracy: 0.5750, AUROC: 0.4820
# Testing on squad-irrelevant-SLT 15/29
# Test Loss: 2.3888, Test Accuracy: 0.6100, AUROC: 0.5073
# Testing on squad-irrelevant-SLT 16/29
# Test Loss: 2.3599, Test Accuracy: 0.5900, AUROC: 0.4690
# Testing on squad-irrelevant-SLT 17/29
# Test Loss: 2.4655, Test Accuracy: 0.6300, AUROC: 0.4935
# Testing on squad-irrelevant-SLT 18/29
# Test Loss: 2.4751, Test Accuracy: 0.5850, AUROC: 0.4908
# Testing on squad-irrelevant-SLT 19/29
# Test Loss: 2.5204, Test Accuracy: 0.6150, AUROC: 0.5608
# Testing on squad-irrelevant-SLT 20/29
# Test Loss: 2.5862, Test Accuracy: 0.5850, AUROC: 0.5315
# Testing on squad-irrelevant-SLT 21/29
# Test Loss: 3.2890, Test Accuracy: 0.5650, AUROC: 0.5440
# Testing on squad-irrelevant-SLT 22/29
# Test Loss: 2.6714, Test Accuracy: 0.5700, AUROC: 0.5201
# Testing on squad-irrelevant-SLT 23/29
# Test Loss: 3.0038, Test Accuracy: 0.5950, AUROC: 0.4679
# Testing on squad-irrelevant-SLT 24/29
# Test Loss: 2.6551, Test Accuracy: 0.6050, AUROC: 0.5839
# Testing on squad-irrelevant-SLT 25/29
# Test Loss: 3.1504, Test Accuracy: 0.5950, AUROC: 0.5306
# Testing on squad-irrelevant-SLT 26/29
# Test Loss: 3.4357, Test Accuracy: 0.6450, AUROC: 0.4953
# Testing on squad-irrelevant-SLT 27/29
# Test Loss: 3.1251, Test Accuracy: 0.6300, AUROC: 0.5452
# Testing on squad-irrelevant-SLT 28/29
# Test Loss: 3.7219, Test Accuracy: 0.6350, AUROC: 0.5549
# Testing on squad-irrelevant-SLT 29/29
# Test Loss: 3.3510, Test Accuracy: 0.6950, AUROC: 0.5887
# Testing on triviaqa-irrelevant-TBG 1/29
# Test Loss: 0.6856, Test Accuracy: 0.5650, AUROC: 0.5000
# Testing on triviaqa-irrelevant-TBG 2/29
# Test Loss: 0.7113, Test Accuracy: 0.5150, AUROC: 0.5055
# Testing on triviaqa-irrelevant-TBG 3/29
# Test Loss: 0.7366, Test Accuracy: 0.5250, AUROC: 0.5007
# Testing on triviaqa-irrelevant-TBG 4/29
# Test Loss: 0.7717, Test Accuracy: 0.5500, AUROC: 0.5070
# Testing on triviaqa-irrelevant-TBG 5/29
# Test Loss: 0.7720, Test Accuracy: 0.5250, AUROC: 0.5315
# Testing on triviaqa-irrelevant-TBG 6/29
# Test Loss: 0.8291, Test Accuracy: 0.5450, AUROC: 0.5420
# Testing on triviaqa-irrelevant-TBG 7/29
# Test Loss: 0.9233, Test Accuracy: 0.5050, AUROC: 0.5368
# Testing on triviaqa-irrelevant-TBG 8/29
# Testing on triviaqa-irrelevant-SLT 4/29
# Test Loss: 1.3320, Test Accuracy: 0.5650, AUROC: 0.5734
# Testing on triviaqa-irrelevant-SLT 5/29
# Test Loss: 1.5234, Test Accuracy: 0.5850, AUROC: 0.6072
# Testing on triviaqa-irrelevant-SLT 6/29
# Test Loss: 1.6267, Test Accuracy: 0.5800, AUROC: 0.6146
# Testing on triviaqa-irrelevant-SLT 7/29
# Test Loss: 1.6761, Test Accuracy: 0.5750, AUROC: 0.6242
# Testing on triviaqa-irrelevant-SLT 8/29
# Test Loss: 1.3551, Test Accuracy: 0.6350, AUROC: 0.6923
# Testing on triviaqa-irrelevant-SLT 9/29
# Test Loss: 1.4400, Test Accuracy: 0.6250, AUROC: 0.6988
# Testing on triviaqa-irrelevant-SLT 10/29
# Test Loss: 1.6784, Test Accuracy: 0.6300, AUROC: 0.6599
# Testing on triviaqa-irrelevant-SLT 11/29
# Test Loss: 1.7354, Test Accuracy: 0.6000, AUROC: 0.6508
# Testing on triviaqa-irrelevant-SLT 12/29
# Test Loss: 1.5767, Test Accuracy: 0.6050, AUROC: 0.6478
# Testing on triviaqa-irrelevant-SLT 13/29
# Test Loss: 1.8632, Test Accuracy: 0.5800, AUROC: 0.6271
# Testing on triviaqa-irrelevant-SLT 14/29
# Test Loss: 1.8609, Test Accuracy: 0.6150, AUROC: 0.6289
# Testing on triviaqa-irrelevant-SLT 15/29
# Test Loss: 2.0200, Test Accuracy: 0.6000, AUROC: 0.6286
# Testing on triviaqa-irrelevant-SLT 16/29
# Test Loss: 1.9460, Test Accuracy: 0.5800, AUROC: 0.6403
# Testing on triviaqa-irrelevant-SLT 17/29
# Test Loss: 1.9633, Test Accuracy: 0.6100, AUROC: 0.6539
# Testing on triviaqa-irrelevant-SLT 18/29
# Test Loss: 1.8780, Test Accuracy: 0.6100, AUROC: 0.6691
# Testing on triviaqa-irrelevant-SLT 19/29
# Test Loss: 1.8245, Test Accuracy: 0.6200, AUROC: 0.6812
# Testing on triviaqa-irrelevant-SLT 20/29
# Test Loss: 2.0131, Test Accuracy: 0.6200, AUROC: 0.6603
# Testing on triviaqa-irrelevant-SLT 21/29
# Test Loss: 2.2185, Test Accuracy: 0.6050, AUROC: 0.6349
# Testing on triviaqa-irrelevant-SLT 22/29
# Test Loss: 2.1808, Test Accuracy: 0.6350, AUROC: 0.6465
# Testing on triviaqa-irrelevant-SLT 23/29
# Test Loss: 2.7804, Test Accuracy: 0.5850, AUROC: 0.6166
# Testing on triviaqa-irrelevant-SLT 24/29
# Test Loss: 2.6790, Test Accuracy: 0.5800, AUROC: 0.6286
# Testing on triviaqa-irrelevant-SLT 25/29
# Test Loss: 2.8564, Test Accuracy: 0.6050, AUROC: 0.6365
# Testing on triviaqa-irrelevant-SLT 26/29
# Test Loss: 3.1981, Test Accuracy: 0.5700, AUROC: 0.5835
# Testing on triviaqa-irrelevant-SLT 27/29
# Test Loss: 3.4581, Test Accuracy: 0.5950, AUROC: 0.6222
# Testing on triviaqa-irrelevant-SLT 28/29
# Test Loss: 3.1491, Test Accuracy: 0.5900, AUROC: 0.6544
# Testing on triviaqa-irrelevant-SLT 29/29
# Test Loss: 3.0721, Test Accuracy: 0.6000, AUROC: 0.6066

# %%
fig, axs = plt.subplots(1, len(Ds), figsize=(5 * len(Ds), 4.5))
for i, D in enumerate(Ds):
    plot_metrics_ax(axs[i], [D.sa_aucs, D.sab_aucs], ["LR trained and tested on Acc", "LR trained on SE, tested on Acc"], f"AUROC on {D.name.upper()}'s SLT")
plt.tight_layout()
save_fig(name="se_for_acc_slt")
plt.show()

# %%
# select best layer range (SLT)
def decide_layer_range(Ds, metric='entropy', limit=NUMBER_OF_LAYERS+1): # NOTE: set upperbound to be number of layers+1; e.g. for llama2-70b, it is 81.
    """
    simple logic: use ID average test AUROCs across layers to determine 
    which consecutive range of layers did the best. Do separately
    for SEP and Acc. Pr.
    """
    assert hasattr(Ds[0], 'sab_aucs') and hasattr(Ds[0], 'sa_aucs'), 'previous cells need to be run'
    if 'entropy' in metric:
        aucs = [np.array(auc(D.sab_aucs)) for D in Ds]  # test metrics for ID SEPs
    else:
        aucs = [np.array(auc(D.sa_aucs)) for D in Ds]  # test metrics for ID APs
    best_mean = -np.inf
    best_range = []
    average = lambda a,b : np.mean([np.mean(ac[a:b]) for ac in aucs])

    for i in range(limit):
        for j in range(i+1, limit):
            if j - i < 5: # must be more than 5 layers
                continue
            if average(i, j) > best_mean:
                best_mean = average(i, j)
                best_range = [i, j]

    return best_mean, best_range

emean, (e1, e2) = decide_layer_range(Ds, 'entropy')
amean, (a1, a2) = decide_layer_range(Ds, 'acc')
for D in Ds:
    D.sep_layer_range = (e1, e2)
    D.ap_layer_range = (a1, a2)
print(emean, (e1, e2), amean, (a1, a2))
# Out:
# 0.6011538638261966 (27, 32) 0.838617617788511 (17, 22)

# %%
# BOOTSTRAP: select [xx-xx] layers for bootstrapping
def concat_Xs_and_ys(layer_range, X_trains, X_vals, X_tests, y_trains, y_vals, y_tests, 
                     no_val=False, test_only=False):
    """
    Concatenate @params{layer_range} hidden state layers on train/val/test sets.

    no_val: no validation (training set only).
    test_only: no train/validation set (test set only).
    """
    if not no_val:
        X_val_cc = np.concatenate(np.array(X_vals)[layer_range], axis=1)
        y_val_cc = y_vals[layer_range[0]]
    else:
        X_val_cc = y_val_cc = None

    if not test_only:
        X_train_cc = np.concatenate(np.array(X_trains)[layer_range], axis=1)
        y_train_cc = y_trains[layer_range[0]]
    else:
        X_train_cc = y_train_cc = None
    
    X_test_cc = np.concatenate(np.array(X_tests)[layer_range], axis=1)
    y_test_cc = y_tests[layer_range[0]]
    
    return X_train_cc, X_val_cc, X_test_cc, y_train_cc, y_val_cc, y_test_cc

def train_concat_SE(D, layer_range):
    """train model on single dataset SE with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_bmodel', model)

        print(f'{token_type.upper()} trained on {D.name} SE finished')
    
def train_concat_Acc(D, layer_range):
    """train model on single dataset Accuracy with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies, test_only=True) # train on all data
        _, _, X_train_cc, _, _, y_train_cc = concat_Xs_and_ys(layer_range, *all_Xs_and_ys, no_val=True, test_only=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        setattr(D, f'{var_name}_amodel', model)

        print(f'{token_type.upper()} trained on {D.name} Acc finished')

def train_concat_SE_Acc_test_Acc(D, layer_ranges=[list(range(e1,e2)), list(range(a1,a2))]):
    """ID: train and test SEPs and Acc. Pr. on single dataset with concatenated layers"""
    for token_type in ['slt']: # optionally, ['slt', 'tbg']
        var_name = token_type[0]
        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, no_val=True) 
        
        X_train_cc, _, _, y_train_cc, _, _ = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys, no_val=True)
        ab_accs = []
        ab_aucs = []
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)

        all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.accuracies) 
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys) # fixed random seed ensures no data leakage
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, 1-y_test_cc) # SEP predicts error rate
        ab_accs.append(test_acc)
        ab_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}b_accs', ab_accs)  # i means IDß
        setattr(D, f'i{var_name}b_aucs', ab_aucs)

        print(f'{D.name.upper()}-{token_type.upper()} trainied on SE and tested on Acc finished')
        aa_accs = []
        aa_aucs = []
        X_train_cc, _, X_test_cc, y_train_cc, _, y_test_cc = concat_Xs_and_ys(layer_ranges[1], *all_Xs_and_ys, no_val=True)
        model = LogisticRegression()
        model.fit(X_train_cc, y_train_cc)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(model, X_test_cc, y_test_cc)
        aa_accs.append(test_acc)
        aa_aucs.append(test_auc)
    
        setattr(D, f'i{var_name}a_accs', aa_accs)
        setattr(D, f'i{var_name}a_aucs', aa_aucs)
        print(f'{D.name.upper()}-{token_type.upper()} trainied on Acc and tested on Acc finished')

# %%
# ID: train SEPs and Acc. Pr. and test them on Acc. from the same dataset
# import warnings # uncomment to disable convergence warnings
# warnings.filterwarnings('ignore')

for D in Ds:
    train_concat_SE_Acc_test_Acc(D)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 6
#       1 # ID: train SEPs and Acc. Pr. and test them on Acc. from the same dataset
#       2 # import warnings # uncomment to disable convergence warnings
#       3 # warnings.filterwarnings('ignore')
#       5 for D in Ds:
# ----> 6     train_concat_SE_Acc_test_Acc(D)
#
# Cell In[18], line 57, in train_concat_SE_Acc_test_Acc(D, layer_ranges)
#      54 var_name = token_type[0]
#      55 all_Xs_and_ys = create_Xs_and_ys(getattr(D, f'{token_type}_dataset'), D.b_entropy, no_val=True)
# ---> 57 X_train_cc, _, _, y_train_cc, _, _ = concat_Xs_and_ys(layer_ranges[0], *all_Xs_and_ys, no_val=True)
#      58 ab_accs = []
#      59 ab_aucs = []
#
# Cell In[18], line 17, in concat_Xs_and_ys(layer_range, X_trains, X_vals, X_tests, y_trains, y_vals, y_tests, no_val, test_only)
#      14     X_val_cc = y_val_cc = None
#      16 if not test_only:
# ---> 17     X_train_cc = np.concatenate(np.array(X_trains)[layer_range], axis=1)
#      18     y_train_cc = y_trains[layer_range[0]]
#      19 else:
#
# IndexError: index 29 is out of bounds for axis 0 with size 29

# %%
D

# %%
# OOD: save model trained on individual datasets for OOD tests
for D in Ds:
    train_concat_SE(D, layer_range=list(range(e1,e2)))
    train_concat_Acc(D, layer_range=list(range(a1,a2)))
# outputs cleared for space concern

# %% [markdown]
# ## Test probes trained with one dataset on others
#
# We generalize SE and Acc. probes to Out-of-Distribution settings (OOD).

# %%
# Train on one's Acc/SE and test on others' Acc
def test_one_on_n(D, token_type='slt', 
                  layer_range1=list(range(e1,e2)), 
                  layer_range2=list(range(a1,a2))):
    var_name = token_type[0]
    other_ids = D.other_ids
    other_names = D.other_names
    metric = 'accuracies'
    a_model = getattr(D, f'{var_name}_amodel')  # Acc. Probe
    b_model = getattr(D, f'{var_name}_bmodel')  # SE Probe

    print(f"Using probes trained on datasets {D.name.upper()}'s {token_type.upper()}-SE/Acc to predict {other_names}'s {token_type.upper()}-Acc")

    oa_accs = {}
    oa_aucs = {}
    ob_accs = {}
    ob_aucs = {}
    
    for id_ in D.other_ids:
        D_id = Ds[id_]
        print(f"Testing on {D_id.name.upper()}'s {token_type.upper()}-{metric.upper()}")
        if metric == 'accuracies':
            y_metric = 1 - getattr(D_id, metric)  # error rate
        else:
            y_metric = getattr(D_id, metric)
        
        ida_accs = []
        ida_aucs = []
        idb_accs = []
        idb_aucs = []

        # create test sets with accuracy labels
        all_Xs_and_ys = create_Xs_and_ys(getattr(D_id, f'{token_type}_dataset'), y_metric, test_only=True)

        # test on Acc. Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range2, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(a_model, X_test_cc, 1-y_test_cc, bootstrap=True)
        ida_accs.append(test_acc)
        ida_aucs.append(test_auc)
        
        # test on SE Probes
        _, _, X_test_cc, _, _, y_test_cc = concat_Xs_and_ys(layer_range1, *all_Xs_and_ys, no_val=True, test_only=True)
        test_loss, test_acc, test_auc = sklearn_evaluate_on_test(b_model, X_test_cc, y_test_cc, bootstrap=True)
        idb_accs.append(test_acc)
        idb_aucs.append(test_auc)

        oa_accs[D_id.name] = ida_accs
        oa_aucs[D_id.name] = ida_aucs
        ob_accs[D_id.name] = idb_accs
        ob_aucs[D_id.name] = idb_aucs

    setattr(D, 'osa_accs', oa_accs) # o means OOD
    setattr(D, 'osa_aucs', oa_aucs)
    setattr(D, 'osb_accs', ob_accs)
    setattr(D, 'osb_aucs', ob_aucs)

    print(f"Using probes trained on dataset {D.name.upper()} testing complete.")

# %%
for D in Ds:
    test_one_on_n(D, 'slt')

# %%
# compute the OOD average: mean([train on B-> test on A, train on C -> test on A, train on D-> test on A])
b_performances = defaultdict(list)
a_performances = defaultdict(list)
win_rate = []
for D in Ds:
    for name in D.other_names:
        b_performances[name].append(auc(D.osb_aucs[name]))
        a_performances[name].append(auc(D.osa_aucs[name]))
        if auc(D.osb_aucs[name]) > auc(D.osa_aucs[name]):
            win_rate.append(1)
        else:
            win_rate.append(0)

print(f"winning rate: {np.mean(win_rate)*100:.2f}%")

for D in Ds:
    D.sep_ood_avg = np.mean(b_performances[D.name])
    D.ap_ood_avg = np.mean(a_performances[D.name])
    print(f"Average performance on {D.name}: SE Probe - {D.sep_ood_avg}, Acc Probe - {D.ap_ood_avg}")

# %%
from datetime import datetime
# 打印当前时间，按照年-月-日 小时:分钟:秒的格式
print("End time:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# 记录结束时间
end = time()
# 计算时间间隔，按照小时：分钟：秒的格式输出
elapsed_seconds = end - start
elapsed_hours = int(elapsed_seconds // 3600)
elapsed_minutes = int((elapsed_seconds % 3600) // 60)
elapsed_seconds = int(elapsed_seconds % 60)
print(f"Time elapsed: {elapsed_hours:02d}:{elapsed_minutes:02d}:{elapsed_seconds:02d}")
